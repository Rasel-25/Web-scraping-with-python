# %% [markdown]
# # Installing a Parser
# By default, Beautiful Soup supports the HTML parser included in Python’s standard library, however it also supports many external third party python parsers like lxml parser or html5lib parser.
#
# $pip install lxml
#
# $pip install html5lib

# %% [markdown]
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://www.tutorialspoint.com/index.htm"
req = requests.get(url)

# %%
req.status_code
req.text
print(req.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <title>Online Tutorials Library</title>
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
# <meta name="Description" content="Online Tutorials Library - The Best Content on latest technologies including C, C++, Java, Python, PHP, Machine Learning, Data Science, AppML, AI with Python, Behave, Java16, Spacy."/>
# <meta name="Keywords" content="HTML, Python, CSS, SQL, JavaScript, How to, PHP, Java, C++, jQuery, Bootstrap, C#, XML, MySQL, NodeJS, React, Angular, R, AI, Git, Data Science, Code Game, Tutorials, Programming, Web Development, Training, Learning, Quiz, Courses, Lessons, References, Examples, Source code, Demos, Tips"/>
# <link rel="canonical" href="https://www.tutorialspoint.com" />
# <link rel="shortcut icon" href="favicon.ico">
# <link rel="preconnect" href="https://fonts.googleapis.com">
# <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>
# <link rel="stylesheet" href="https://fonts.googleapis.com/css2?family=Heebo:wght@400;500;700&family=Roboto:wght@400;500;700&display=swap">
# <link rel="stylesheet" type="text/css" href="static/vendor/font-awesome/css/fontawesome-custom.min.css">
# <link rel="stylesheet" type="text/css" href="static/vendor/tiny-slider/tiny-slider.css">
# <link id="style-switch" rel="stylesheet" type="text/css" href="static/css/style.css">
# <link rel="stylesheet" rel="stylesheet" type="text/css" href="static/css/custom.css">
# <script src="/static/js/jquery-3.3.1.min.js"></script>
# <style>
# .lh-7{background-color:#fff!important; min-height:58px; border:2px solid #59bb4d!important;}
# </style>
# </head>
#
# <body>
#
# <!-- Top header START -->
# <div class="navbar-top navbar-dark bg-light d-xl-block py-2 mx-2 mx-md-4 rounded-bottom-4">
# 	<div class="container-fluid px-3 px-xl-3">
# 		<div class="d-lg-flex justify-content-lg-between align-items-center top-nav-links">
# 			<!-- Top info -->
# 			<ul class="nav align-items-center justify-content-center">
# 				<li class="nav-item" data-bs-toggle="tooltip" data-bs-animation="false" data-bs-placement="bottom" data-bs-original-title="Home Page">
# 					<a class="nav-link" href="https://www.tutorialspoint.com/index.htm"><i class="fal fa-home me-1"></i> Home</a>
# 				</li>
# 				<li class="nav-item" data-bs-toggle="tooltip" data-bs-animation="false" data-bs-placement="bottom" data-bs-original-title="Online Coding System">
# 					<a class="nav-link" href="https://www.tutorialspoint.com/codingground.htm"><i class="fal fa-code me-1"></i> Coding Ground</a>
# 				</li>
# 				<li class="nav-item" data-bs-toggle="tooltip" data-bs-animation="false" data-bs-placement="bottom" data-bs-original-title="Questions & Answers">
# 					<span><a class="nav-link" href="https://www.tutorialspoint.com/questions/index.php"><i class="fal fa-comments-alt me-1"></i> Q/A</a></span>
# 				</li>
# 				<li class="nav-item" data-bs-toggle="tooltip" data-bs-animation="false" data-bs-placement="bottom" data-bs-original-title="Job Openings">
# 					<span><a class="nav-link" href="https://www.tutorialspoint.com/about/about_careers.htm"><i class="fal fa-suitcase me-1"></i> Jobs</a></span>
# 				</li>
# 				<li class="nav-item" data-bs-toggle="tooltip" data-bs-animation="false" data-bs-placement="bottom" data-bs-original-title="Digital Whiteboard">
# 					<span><a class="nav-link" href="https://www.tutorialspoint.com/whiteboard.htm"><i class="fal fa-chalkboard me-1"></i> Whiteboard</a></span>
# 				</li>
# 				<li class="nav-item" data-bs-toggle="tooltip" data-bs-animation="false" data-bs-placement="bottom" data-bs-original-title="Developer's Tools">
# 					<span><a class="nav-link" href="https://www.tutorialspoint.com/online_dev_tools.htm"><i class="fal fa-screwdriver-wrench me-1"></i> Tools</a></span>
# 				</li>
# 				<li class="nav-item" data-bs-toggle="tooltip" data-bs-animation="false" data-bs-placement="bottom" data-bs-original-title="Corporate Trainings">
# 					<span><a class="nav-link" href="https://www.tutorialspoint.com/business/index.asp"><i class="fal fa-analytics me-1"></i> Business</a></span>
# 				</li>
# 			</ul>
# 			<div class="d-flex align-items-center justify-content-center">
# 				<div class="navbar-nav ms-2">
# 					<div class="modeswitch-wrap" id="darkModeSwitch">
# 						<div class="modeswitch-item">
# 							<div class="modeswitch-icon"></div>
# 						</div>
# 					</div>
# 				</div>
# 				<!-- teach with us -->
# 				<div class="me-3c top-nav-social">
# 					<a class="nav-link" href="https://www.tutorialspoint.com/market/teach_with_us.jsp" aria-haspopup="true" aria-expanded="false" target="_blank"><i class="fal fa-screen-users me-2"></i> Teach with us</i></a>
# 				</div>
# 				<!-- Top social -->
# 				<ul class="list-unstyled d-flex mb-0 top-nav-social">
# 					<li><a class="px-2 nav-link" rel="nofollow" href="https://www.facebook.com/tutorialspointindia" target="_blank"><i class="fab fa-facebook"></i></a> </li>
# 					<li><a class="px-2 nav-link" rel="nofollow" href="https://www.instagram.com/tutorialspoint_/" target="_blank"><i class="fab fa-instagram"></i></a> </li>
# 					<li><a class="px-2 nav-link" rel="nofollow" href="https://twitter.com/tutorialspoint" target="_blank"><i class="fab fa-twitter"></i></a> </li>
# 					<li><a class="px-2 nav-link" rel="nofollow" href="https://www.youtube.com/channel/UCVLbzhxVTiTLiVKeGV7WEBg" target="_blank"><i class="fab fa-youtube"></i></a> </li>
# 					<li> <a class="px-2 nav-link" rel="nofollow" href="https://www.linkedin.com/authwall?trk=bf&trkInfo=AQEkqX2eckF__gAAAX-wMwEYvrsjBVbEtWQd4pgEdVSzkL22Nik1KEpY_ECWLKDGc41z8IOZWr2Bb0fvJplT60NPBtSw87J6QCpc7wD4qQ3iU13n6xJtBxME5o05Wmpg5JPm5YY=&originalReferer=&sessionRedirect=https%3A%2F%2Fwww.linkedin.com%2Fcompany%2Ftutorialspoint" target="_blank"><i class="fab fa-linkedin-in"></i></a> </li>
# 				</ul>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <!-- Top header END -->
#
# <!-- Header START -->
# <header class="navbar-light navbar-sticky header-static">
# 	<!-- Logo Nav START -->
# 	<nav class="navbar navbar-expand-xl">
# 		<div class="container-fluid px-3 px-xl-5">
# 			<!-- Logo START -->
# 			<a class="navbar-brand" href="index.htm">
# 				<img class="light-mode-item navbar-brand-item" src="/images/logo.png" alt="logo">
# 				<img class="dark-mode-item navbar-brand-item" src="/images/logo-w.png" alt="logo">
# 			</a>
# 			<button class="navbar-toggler ms-auto" type="button" data-bs-toggle="collapse" data-bs-target="#navbarCollapse" aria-controls="navbarCollapse" aria-expanded="false" aria-label="Toggle navigation">
# 				<span class="navbar-toggler-animation">
# 					<span></span>
# 					<span></span>
# 					<span></span>
# 				</span>
# 			</button>
# 			<div class="navbar-collapse w-100 collapse" id="navbarCollapse">
# 				<ul class="navbar-nav navbar-nav-scroll me-auto">
# 					<li class="nav-item dropdown dropdown-menu-shadow-stacked">
# 						<a class="nav-link" href="#" id="categoryMenu" data-bs-toggle="dropdown" aria-haspopup="true" aria-expanded="false"><i class="fal fa-th me-3 fs-5 me-xl-1 d-xl-none"></i> <i class="fal fa-th me-1 d-none d-xl-inline-block"></i><span class="d-xl-inline-block dropdown-toggle">Category</span></a>
# 						<ul class="dropdown-menu" aria-labelledby="categoryMenu">
# 							<li> <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/development"><i class="fa fa-cogs cat-icons"></i> Development</a></li>
# 							<li> <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/it_and_software"><i class="fa fa-tv cat-icons"></i>  IT and Networking</a></li>
# 							<li> <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/data_science_and_ai_ml"><i class="fa fa-head-side-brain cat-icons"></i> Data Science and AI ML</a></li>
# 							<li> <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/cyber_security"><i class="fa fa-camera-home cat-icons"></i> Cyber Security</a></li>
# 							<li> <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/marketing"><i class="fa fa-bullseye-arrow cat-icons"></i> Marketing</a></li>
# 							<li> <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/office_productivity"><i class="fa fa-camera-home cat-icons"></i> Office Productivity</a></li>
# 							<li> <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/business"><i class="fa fa-chart-bar cat-icons"></i> Business</a></li>
# 							<li> <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/lifestyle"><i class="fa fa-person-dolly-empty cat-icons"></i> Lifestyle</a></li>
# 						</ul>
# 					</li>
# 				</ul>
# 				<!-- Nav category menu END -->
#
# 				<!-- Main navbar START -->
# 				<div class="navbar-collapse collapse" id="navbarCollapse">
# 					<!-- Nav Search START -->
# 					<div class="col-xl-4"></div>
# 					<!-- Nav Search END -->
# 				</div>
# 				<!-- Main navbar END -->
#
# 				<!-- Nav Main menu START -->
# 				<ul class="navbar-nav navbar-nav-scroll me-auto">
# 					<li class="nav-item">
# 						<a class="nav-link" href="https://www.tutorialspoint.com/latest/prime-packs" aria-haspopup="true" aria-expanded="false" target="_self"><i class="fal fa-cubes me-1"></i> Prime Packs</a>
# 					</li>
# 					<li class="nav-item">
# 						<a class="nav-link" href="https://www.tutorialspoint.com/market/index.asp" aria-haspopup="true" aria-expanded="false" target="_self"><i class="fal fa-circle-play me-1"></i> Courses</a>
# 					</li>
# 					<li class="nav-item">
# 						<a class="nav-link" href="https://www.tutorialspoint.com/latest/ebooks" aria-haspopup="true" aria-expanded="false" target="_self"><i class="fal fa-book-reader me-1"></i> eBooks</a>
# 					</li>
# 					<li class="nav-item">
# 						<a class="nav-link" href="https://www.tutorialspoint.com/tutorialslibrary.htm" aria-haspopup="true" aria-expanded="false" target="_self"><i class="fal fa-books me-1"></i> Library</a>
# 					</li>
# 				</ul>
# 				<!-- Nav Main menu END -->
# 			</div>
# 			<!-- Main navbar END -->
# 			<!-- Signin START -->
# 			<div class="navbar-nav d-lg-inline-block">
# 				<a href="https://www.tutorialspoint.com/market/login.asp" target="_self"><button class="btn btn-grey-border mb-0"><i class="fal fa-sign-in-alt me-2"></i> Login</button></a>
# 			</div>
#          <!-- Signin END -->
# 		</div>
# 	</nav>
# 	<!-- Logo Nav END -->
# </header>
# <!-- Header END -->
#
# <!-- **************** MAIN CONTENT START **************** -->
# <main>
#
# <!-- ======================= Main Banner START -->
# <section class="position-relative overflow-hidden pt-5 pt-lg-3">
# 	<!-- SVG START -->
# 	<figure class="position-absolute top-50 start-0 translate-middle-y ms-n7 d-none d-xxl-block">
# 		<svg class="rotate-74 fill-green opacity-1">
# 			<circle cx="180.4" cy="15.5" r="7.7" />
# 			<path d="m159.9 22.4c-3.8 0-6.9-3.1-6.9-6.9s3.1-6.9 6.9-6.9 6.9 3.1 6.9 6.9-3.1 6.9-6.9 6.9z" />
# 			<ellipse transform="matrix(.3862 -.9224 .9224 .3862 71.25 138.08)" cx="139.4" cy="15.5" rx="6.1" ry="6.1" />
# 			<circle cx="118.9" cy="15.5" r="5.4" />
# 			<path d="m98.4 20.1c-2.5 0-4.6-2.1-4.6-4.6s2.1-4.6 4.6-4.6 4.6 2.1 4.6 4.6-2.1 4.6-4.6 4.6z" />
# 			<path d="m77.9 19.3c-2.1 0-3.8-1.7-3.8-3.8s1.7-3.8 3.8-3.8 3.8 1.7 3.8 3.8-1.7 3.8-3.8 3.8z" />
# 			<path d="m57.3 18.6c-1.7 0-3.1-1.4-3.1-3.1s1.4-3.1 3.1-3.1 3.1 1.4 3.1 3.1-1.4 3.1-3.1 3.1z" />
# 			<path d="m36.8 17.8c-1.3 0-2.3-1-2.3-2.3s1-2.3 2.3-2.3 2.3 1 2.3 2.3-1 2.3-2.3 2.3z" />
# 			<circle cx="16.3" cy="15.5" r="1.6" />
# 			<circle cx="180.4" cy="38.5" r="7.7" />
# 			<path d="m159.9 45.3c-3.8 0-6.9-3.1-6.9-6.9s3.1-6.9 6.9-6.9 6.9 3.1 6.9 6.9-3.1 6.9-6.9 6.9z" />
# 			<ellipse transform="matrix(.8486 -.5291 .5291 .8486 .7599 79.566)" cx="139.4" cy="38.5" rx="6.1" ry="6.1" />
# 			<circle cx="118.9" cy="38.5" r="5.4" />
# 			<circle cx="77.9" cy="153.2" r="3.8" />
# 			<path d="m57.3 156.3c-1.7 0-3.1-1.4-3.1-3.1s1.4-3.1 3.1-3.1 3.1 1.4 3.1 3.1-1.4 3.1-3.1 3.1z" />
# 			<path d="m36.8 155.5c-1.3 0-2.3-1-2.3-2.3s1-2.3 2.3-2.3 2.3 1 2.3 2.3-1 2.3-2.3 2.3z" />
# 			<circle cx="16.3" cy="153.2" r="1.6" />
# 			<circle cx="180.4" cy="176.2" r="7.7" />
# 			<path d="m159.9 183.1c-3.8 0-6.9-3.1-6.9-6.9s3.1-6.9 6.9-6.9 6.9 3.1 6.9 6.9-3.1 6.9-6.9 6.9z" />
# 			<ellipse transform="matrix(.3862 -.9224 .9224 .3862 -76.968 236.7)" cx="139.4" cy="176.2" rx="6.1" ry="6.1" />
# 			<circle cx="118.9" cy="176.2" r="5.4" />
# 			<path d="m98.4 180.8c-2.5 0-4.6-2.1-4.6-4.6s2.1-4.6 4.6-4.6 4.6 2.1 4.6 4.6-2.1 4.6-4.6 4.6z" />
# 			<path d="m77.9 180c-2.1 0-3.8-1.7-3.8-3.8s1.7-3.8 3.8-3.8 3.8 1.7 3.8 3.8-1.7 3.8-3.8 3.8z" />
# 			<path d="m57.3 179.3c-1.7 0-3.1-1.4-3.1-3.1s1.4-3.1 3.1-3.1 3.1 1.4 3.1 3.1-1.4 3.1-3.1 3.1z" />
# 			<path d="m36.8 178.5c-1.3 0-2.3-1-2.3-2.3s1-2.3 2.3-2.3 2.3 1 2.3 2.3-1 2.3-2.3 2.3z" />
# 			<circle cx="16.3" cy="176.2" r="1.6" />
# 		</svg>
# 	</figure>
# 	<!-- SVG END -->
#
# 	<!-- SVG START -->
# 	<span class="position-absolute top-50 end-0 translate-middle-y mt-5 me-n5 d-none d-xxl-inline-flex">
# 		<svg class="fill-green rotate-186 opacity-8">
# 			<path d="m35.4 54.2c0 0.6 0 1.1-0.1 1.7-0.9 9.3-9.2 16.1-18.5 15.1-4.5-0.4-8.5-2.6-11.4-6.1-2.8-3.5-4.2-7.9-3.7-12.4 0.9-9.3 9.2-16.1 18.5-15.1 4.5 0.4 8.5 2.6 11.4 6.1 2.4 3 3.8 6.8 3.8 10.7zm-33.4 0c0 3.8 1.3 7.5 3.8 10.4 2.8 3.4 6.8 5.5 11.2 6 9.1 0.9 17.2-5.8 18.1-14.8 0.4-4.4-0.9-8.7-3.7-12.1s-6.8-5.5-11.2-6c-9.2-0.8-17.3 5.8-18.2 14.9v1.6z" />
# 			<path d="m39 54.1c0 1.1-0.1 2.2-0.3 3.3-1.8 9.8-11.2 16.2-21 14.4-4.7-0.8-8.8-3.5-11.5-7.4-2.7-4-3.7-8.7-2.8-13.5 1.8-9.8 11.2-16.2 21-14.4 4.7 0.9 8.8 3.6 11.5 7.5 2.1 3 3.1 6.6 3.1 10.1zm-35.6 0.1c0 3.5 1.1 7 3.1 9.9 2.7 3.9 6.7 6.5 11.3 7.4 9.6 1.8 18.8-4.5 20.6-14.1 0.9-4.6-0.1-9.3-2.8-13.2s-6.7-6.5-11.3-7.4c-9.6-1.8-18.8 4.5-20.6 14.1-0.2 1.1-0.3 2.2-0.3 3.3z" />
# 			<path d="m118.3 54.2c0 13-5.1 25.3-14.3 34.5-19 19-50 19-69 0-9.2-9.2-14.3-21.4-14.3-34.5 0-13 5.1-25.3 14.3-34.5 19-19 50-19 69 0l-0.1 0.1 0.1-0.1c9.2 9.2 14.3 21.5 14.3 34.5zm-97.2 0c0 12.9 5 25.1 14.2 34.2 18.9 18.9 49.6 18.9 68.4 0 9.1-9.1 14.2-21.3 14.2-34.2s-5-25.1-14.2-34.2c-18.8-18.9-49.5-18.9-68.4 0-9.2 9.1-14.2 21.3-14.2 34.2z" />
# 		</svg>
# 	</span>
# 	<!-- SVG END -->
#
# 	<!-- SVG START -->
# 	<figure class="position-absolute top-0 start-50 ms-5">
# 		<svg class="fill-orange opacity-4" width="29px" height="29px">
# 			<path d="M29.004,14.502 C29.004,22.512 22.511,29.004 14.502,29.004 C6.492,29.004 -0.001,22.512 -0.001,14.502 C-0.001,6.492 6.492,-0.001 14.502,-0.001 C22.511,-0.001 29.004,6.492 29.004,14.502 Z"></path>
# 		</svg>
# 	</figure>
# 	<!-- SVG END -->
#
# 	<!-- Content START -->
# 	<div class="container">
# 		<div class="row align-items-center g-5">
# 			<div class="col-lg-5 col-xl-6 position-relative z-index-1 text-center text-lg-start mt-n7">
# 				<figure class="fill-info position-absolute bottom-0 end-0 me-5 d-none d-xl-block">
# 					<svg width="42px" height="42px">
# 						<path d="M21.000,-0.001 L28.424,13.575 L41.999,20.999 L28.424,28.424 L21.000,41.998 L13.575,28.424 L-0.000,20.999 L13.575,13.575 L21.000,-0.001 Z" />
# 					</svg>
# 				</figure>
# 				<figure class="fill-success position-absolute top-0 start-50 translate-middle-x mt-6 ms-5">
# 					<svg width="22px" height="21px">
# 						<path d="M10.717,4.757 L14.440,-0.001 L14.215,6.023 L20.142,4.757 L16.076,9.228 L21.435,12.046 L15.430,12.873 L17.713,18.457 L12.579,15.252 L10.717,20.988 L8.856,15.252 L3.722,18.457 L6.005,12.873 L-0.000,12.046 L5.359,9.228 L1.292,4.757 L7.220,6.023 L6.995,-0.001 L10.717,4.757 Z" />
# 					</svg>
# 				</figure>
# 				<h1 class="mb-0 display-6 mb-4 mt-8">Simply Easy Learning at your
# 					<span class="position-relative">fingertips
# 						<span class="position-absolute top-50 start-50 translate-middle ms-3 z-index-n1">
# 						  <svg width="300px" height="62.1px" enable-background="new 0 0 366 62.1" viewBox="0 0 366 62.1" xmlns="http://www.w3.org/2000/svg">
# 							<path class="fill-green" d="m322.5 25.3c0 1.4 2.9 0.8 3.1 1.6 0.8 1.1-1.1 1.3-0.6 2.4 13.3 0.9 26.9 1.7 40.2 4-2.5 0.7-4.9 1.6-7.3 1.1-4-0.9-8.2-1-12.2-1.2-8.5-0.5-16.9-1.9-25.5-1.7h-3.1c2.6 0.6 4.8 0.4 5.7 2.2-7.3 0.4-14.1-0.8-21.2-1.1-0.2 0.6-0.5 1.2-0.8 1.8 21.3 0.7 42.5 1.6 64.3 4.6-4.2 1.6-7.7 1-10.8 0.8-6.8-0.5-13.5-1.3-20.3-1.9-
# 						  </svg>
# 						</span>
# 						<!-- SVG END -->
# 					</span>
# 				</h1>
# 				<div class="nav-item w-100 mb-4">
# 					<form class="rounded position-relative">
# 						<input class="form-control pe-4 bg-secondary bg-opacity-10 border-0 search-strings lh-7" type="search" placeholder="Search courses, ebooks and prime packs" id="search-strings" name="key" data-result="search-results" aria-label="Search">
# 						<button type="button" id="btnSearch" class="btn bg-transparent px-2 py-0 position-absolute top-50 end-0 translate-middle-y" type="submit"><i class="fal fa-search fs-5 me-3"></i></button>
# 						<div class="search-box" id="search-results"></div>
# 						<div class="clear"></div>
# 					</form>
# 				</div>
# 				<ul class="list-inline position-relative justify-content-center justify-content-lg-start mb-5 mt-2">
# 					<li class="list-inline-item me-3 fs-5"><a class="nav-link" href="https://www.tutorialspoint.com/latest/prime-packs" aria-haspopup="true" aria-expanded="false" target="_self"><i class="fal fa-cubes me-1"></i> Prime Packs</a></li>
# 					<li class="list-inline-item me-3 fs-5"><a class="nav-link" href="https://www.tutorialspoint.com/market/index.asp" aria-haspopup="true" aria-expanded="false" target="_self"><i class="fal fa-circle-play me-1"></i> Courses</a></li>
# 					<li class="list-inline-item me-3 fs-5"><a class="nav-link" href="https://www.tutorialspoint.com/latest/ebooks" aria-haspopup="true" aria-expanded="false" target="_self"><i class="fal fa-book-reader me-1"></i> eBooks</a></li>
# 					<li class="list-inline-item me-3 fs-5"><a class="nav-link" href="https://www.tutorialspoint.com/tutorialslibrary.htm" aria-haspopup="true" aria-expanded="false" target="_self"><i class="fal fa-books me-1"></i> Library</a></li>
# 				</ul>
# 				<div class="">
# 					<a href="https://www.tutorialspoint.com/codingground.htm" class="btn btn-lg btn-green-hard me-2 mb-4 mb-sm-0"><i class="fal fa-code me-1"></i> Coding Ground</a>
# 					<a data-glightbox data-gallery="office-tour" href="https://www.tutorialspoint.com/market/index.asp" class="ms-0 ms-sm-4">
# 						<div class="btn btn-round btn-black-shadow mb-0 me-3 align-middle"> <i class="fal fa-play"></i></div>
# 						<div class="align-middle d-inline-block">
# 							<h6 class="mb-0 fw-normal">Watch Demo Video</h6>
# 						</div>
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class="col-lg-7 col-xl-6 text-center position-relative">
# 				<figure class="position-absolute bottom-0 start-50 translate-middle-x mt-4 mb-0">
# 					<svg width="550px" height="538px" viewBox="0 0 554 544" style="enable-background:new 0 0 554 544;" xml:space="preserve">
# 						<path class="fill-primary" d="M423.3,77.2c49.5,32.5,100.4,67.2,118.4,114.5s3.5,107.1-15.4,165.7c-18.7,58.6-41.8,116.1-84,148.6 c-42.5,32.8-104.2,40.2-163.8,37.3c-59.5-3.2-116.8-17.1-164.7-47.9c-48.3-30.6-87.2-78.2-102-131.6C-3,310.5,6.6,251,25.3,194.7 C43.6,138,70.7,84.3,114.1,49.5C157.2,14.8,216.7-1,270.8,6.4C324.8,14.2,373.4,44.7,423.3,77.2z" />
# 						<path d="m52.1 19.7 0.3-0.3c-0.1 0 0 0 0 0 0.1-0.1 0.3-0.2 0.4-0.3l0.9-0.6c0.6-0.4 1.2-0.8 1.8-1.1 0.3-0.2 0.4-0.6 0.2-0.9s-0.6-0.4-0.9-0.2c-1.3 0.7-2.6 1.5-3.7 2.5-0.3 0.2-0.2 0.7 0 0.9 0.4 0.3 0.7 0.3 1 0z" />
# 						<path d="m20.2 49.3c-0.1 0 0 0 0 0 0.1 0.2 0.1 0.3 0.1 0.4 0.1 0.3 0.2 0.6 0.4 0.9 0.3 0.7 0.5 1.5 0.7 2.3s0.2 1.7 0.3 2.5c0.1 0.7 0.1 1.6 0.5 2.2 0.4 0.7 1.6 0.1 1.1-0.7-0.2-0.3-0.2-0.6-0.2-1 0-0.5-0.1-0.9-0.1-1.4-0.1-0.9-0.2-1.8-0.4-2.7-0.2-0.8-0.5-1.5-0.8-2.3-0.2-0.5-0.3-1.2-0.8-1.4-0.3-0.1-0.7-0.1-0.9 0.2-0.3 0.4-0.3 0.9 0.1 1z" />
# 					</svg>
# 				</figure>
# 				<div class="p-2 bg-white shadow rounded-3 position-absolute top-50 start-0 translate-middle-y mt-n7 d-none d-sm-block">
# 					<img src="static/images/client/science.svg" alt="Icon">
# 				</div>
# 				<div class="p-2 bg-white shadow rounded-3 position-absolute top-0 end-0 me-5">
# 					<img src="static/images/client/angular.svg" alt="Icon">
# 				</div>
# 				<div class="p-2 bg-white shadow rounded-3 position-absolute top-50 end-0 translate-middle-y mt-5 ms-5 d-none d-lg-block z-index-9">
# 					<img src="static/images/client/figma.svg" alt="Icon">
# 				</div>
# 				<div class="p-3 bg-blur border border-light shadow rounded-4 position-absolute bottom-0 start-0 z-index-9 d-none d-xl-block mb-5 ms-5">
# 					<div class="d-flex justify-content-between align-items-center">
# 						<span class="icon-lg bg-warning rounded-circle"><i class="fal fa-envelope text-white"></i></span>
# 					</div>
# 				</div>
# 				<div class="position-relative">
# 					<img src="static/images/banner-img.png" alt="">
# 				</div>
# 			</div>
# 			<!-- Right content END -->
# 		</div>
# 	</div>
# 	<!-- Content END -->
# </section>
# <!-- ======================= Main Banner END -->
#
# <!-- ======================= Counter START -->
# <section class="py-0 pb-5 pt-0 pt-lg-5">
# 	<div class="container">
#               <div class="tiny-slider arrow-round arrow-blur arrow-hover">
# 		     <div class="tiny-slider-inner row g-4" data-autoplay="false" data-gutter="20" data-arrow="true" data-dots="false" data-items="4" data-items-lg="3" data-items-md="2" data-items-xs="1">
# 			<!-- Counter item -->
# 			<div class="col-sm-6 col-xl-3">
# 				<div class="d-flex justify-content-center align-items-center p-4 bg-warning bg-opacity-15 rounded-3">
# 					<span class="display-6 lh-1 text-warning mb-0"><i class="fal fa-laptop"></i></span>
# 					<div class="ms-4 h6 fw-normal">
# 						<div class="d-flex">
# 							<h5 class="purecounter mb-0 fw-bold" data-purecounter-start="0" data-purecounter-end="5000"	data-purecounter-delay="200">0</h5>
# 							<span class="mb-0 h5">+</span>
# 						</div>
# 						<p class="mb-0">Premium Courses</p>
# 					</div>
# 				</div>
# 			</div>
# 			<!-- Counter item -->
# 			<div class="col-sm-6 col-xl-3">
# 				<div class="d-flex justify-content-center align-items-center p-4 bg-blue bg-opacity-10 rounded-3">
# 					<span class="display-6 lh-1 text-blue mb-0"><i class="fal fa-user-tie"></i></span>
# 					<div class="ms-4 h6 fw-normal">
# 						<div class="d-flex">
# 							<h5 class="purecounter mb-0 fw-bold" data-purecounter-start="0" data-purecounter-end="1000" data-purecounter-delay="200">0</h5>
# 							<span class="mb-0 h5">+</span>
# 						</div>
# 						<p class="mb-0">Expert Tutors</p>
# 					</div>
# 				</div>
# 			</div>
# 			<!-- Counter item -->
# 			<div class="col-sm-6 col-xl-3">
# 				<div class="d-flex justify-content-center align-items-center p-4 bg-purple bg-opacity-10 rounded-3">
# 					<span class="display-6 lh-1 text-purple mb-0"><i class="fal fa-user-graduate"></i></span>
# 					<div class="ms-4 h6 fw-normal">
# 						<div class="d-flex">
# 							<h5 class="purecounter mb-0 fw-bold" data-purecounter-start="0" data-purecounter-end="30"	data-purecounter-delay="200">0</h5>
# 							<span class="mb-0 h5">M+</span>
# 						</div>
# 						<p class="mb-0">Online Students</p>
# 					</div>
# 				</div>
# 			</div>
# 			<!-- Counter item -->
# 			<div class="col-sm-6 col-xl-3">
# 				<div class="d-flex justify-content-center align-items-center p-4 bg-info bg-opacity-10 rounded-3">
# 					<span class="display-6 lh-1 text-info mb-0"><i class="fal fa-certificate"></i></span>
# 					<div class="ms-4 h6 fw-normal">
# 						<div class="d-flex">
# 							<h5 class="purecounter mb-0 fw-bold" data-purecounter-start="0" data-purecounter-end="50" data-purecounter-delay="300">0</h5>
# 							<span class="mb-0 h5">K+</span>
# 						</div>
# 						<p class="mb-0">Certificates Delivered</p>
# 					</div>
# 				</div>
# 			</div>
# 			</div>
# 		</div>
# 	</div>
# </section>
# <!-- ======================= Counter END -->
#
# <!-- ======================= Listed course START -->
# <section class="position-relative pb-5 pt-0 pt-lg-5">
# 	<div class="container">
# 		<!-- Title -->
# 		<div class="row mb-4">
# 			<div class="col-lg-8 mx-auto text-center">
# 				<h2 class="fs-1"><i class="fal fa-grid me-3"></i>Top <span class="text-green">Categories</span></h2>
# 			</div>
# 		</div>
#
# 		<div class="tiny-slider arrow-round arrow-blur arrow-hover">
# 		     <div class="tiny-slider-inner row g-4" data-autoplay="false" data-mobile="true" data-gutter="20" data-arrow="true" data-dots="true" data-items="4" data-items-lg="3" data-items-md="2" data-items-xs="1">
# 				<div class="col-sm-6 col-md-4 col-xl-3">
# 					<div class="bg-primary bg-opacity-10 rounded-3 text-center p-3 position-relative btn-transition">
# 						<div class="icon-xl bg-body mx-auto rounded-circle mb-3">
# 							<img src="static/images/development.svg" />
# 						</div>
# 						<h5 class="mb-1"><a href="https://www.tutorialspoint.com/categories/development" class="stretched-link"> Development</a></h5>
# 						<span class="mb-0">15 Course</span>
# 					</div>
# 				</div>
# 				<div class="col-sm-6 col-md-4 col-xl-3">
# 					<div class="bg-primary bg-opacity-10 rounded-3 text-center p-3 position-relative btn-transition">
# 						<div class="icon-xl bg-body mx-auto rounded-circle mb-3">
# 							<img src="static/images/it-and-networking.svg" />
# 						</div>
# 						<h5 class="mb-1"><a href="https://www.tutorialspoint.com/categories/it_and_software" class="stretched-link">IT and Networking</a></h5>
# 						<span class="mb-0">22 Course</span>
# 					</div>
# 				</div>
# 				<div class="col-sm-6 col-md-4 col-xl-3">
# 					<div class="bg-primary bg-opacity-10 rounded-3 text-center p-3 position-relative btn-transition">
# 						<div class="icon-xl bg-body mx-auto rounded-circle mb-3">
# 							<img src="static/images/data-science-and-ai-ml.svg" />
# 						</div>
# 						<h5 class="mb-1"><a href="https://www.tutorialspoint.com/categories/data_science_and_ai_ml" class="stretched-link">Data Science and AI ML</a></h5>
# 						<span class="mb-0">53 Course</span>
# 					</div>
# 				</div>
# 				<div class="col-sm-6 col-md-4 col-xl-3">
# 					<div class="bg-primary bg-opacity-10 rounded-3 text-center p-3 position-relative btn-transition">
# 						<div class="icon-xl bg-body mx-auto rounded-circle mb-3">
# 							<img src="static/images/cyber-security.svg" />
# 						</div>
# ...
# 									<div class="image-title white-title">Microsoft Word</div>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="clear"></div>
# 					<div class="text-end mt-2 pt-2">
# 						<a href="https://www.tutorialspoint.com/microsoft_technologies_tutorials.htm" class="btn btn-white-soft">View more<i class="fal fa-sync ms-2"></i></a>
# 					</div>
# 				</div>
# 			</div>
#
# 			<div class="col-sm-12 col-lg-6 col-xl-6">
# 				<div class="card card-body shadow rounded-3 grey-box">
# 					<div class="row">
# 						<h5 class="card-title pb-2 mb-4 ps-1"><i class="fal fa-chart-pie icon-md text-dark mb-0 bg-grey rounded-3  me-2"></i>Big Data and Analytics</h5>
# 						<div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# 							<div class="big-data-analytics">
# 								<a href="https://www.tutorialspoint.com/big_data_analytics/index.htm" target="_blank" title="Big Data Analytics Tutorial">
# 									<div class="image-title white-title">Big Data Analytics</div>
# 								</a>
# 							</div>
# 						</div>
# 						<div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# 							<div class="hadoop">
# 								<a href="https://www.tutorialspoint.com/hadoop/index.htm" target="_blank" title="Hadoop Tutorial">
# 									<div class="image-title white-title">Hadoop Tutorial</div>
# 								</a>
# 							</div>
# 						</div>
# 						<div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# 							<div class="sas">
# 								<a href="https://www.tutorialspoint.com/sas/index.htm" target="_blank" title="SAS Tutorial">
# 									<div class="image-title white-title">SAS Tutorial</div>
# 								</a>
# 							</div>
# 						</div>
# 						<div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# 							<div class="qlikview">
# 								<a href="https://www.tutorialspoint.com/qlikview/index.htm" target="_blank" title="QlikView Tutorial">
# 									<div class="image-title white-title">QlikView Tutorial</div>
# 								</a>
# 							</div>
# 						</div>
# 						<div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# 							<div class="powerbi">
# 								<a href="https://www.tutorialspoint.com/power_bi/index.htm" target="_blank" title="Power BI Tutorial">
# 									<div class="image-title white-title">Power BI Tutorial</div>
# 								</a>
# 							</div>
# 						</div>
# 						<div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# 							<div class="tableau">
# 								<a href="https://www.tutorialspoint.com/tableau/index.htm" target="_blank" title="Tableau Tutorial">
# 									<div class="image-title white-title">Tableau Tutorial</div>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="clear"></div>
# 					<div class="text-end mt-2 pt-2">
# 						<a href="https://www.tutorialspoint.com/big_data_tutorials.htm" class="btn btn-white-soft">View more<i class="fal fa-sync ms-2"></i></a>
# 					</div>
# 				</div>
# 			</div>
#
# 		</div>
# 	</div>
# </section>
# <!-- =======================
# Tutorials END -->
#
# <!-- =======================
# Become an Instructor START -->
# <section class="py-4">
# 	<div class="container">
# 		<div class="row g-4">
#       <!-- Action box item -->
# 			<div class="col-lg-6 position-relative overflow-hidden">
# 				<div class="bg-primary bg-opacity-10 rounded-3 p-5 h-100">
# 					<!-- Image -->
# 					<div class="position-absolute bottom-0 end-0 me-3">
# 						<img src="static/images/element/08.svg" class="h-100px h-sm-200px" alt="">
# 					</div>
# 					<!-- Content -->
# 					<div class="row">
# 						<div class="col-sm-8 position-relative">
# 							<h3 class="mb-1">Become an Instructor!</h3>
# 							<p class="mb-3 h5 fw-light lead">Join one of the world’s largest online learning marketplaces.</p>
# 							<a href="https://www.tutorialspoint.com/market/teach_with_us.jsp" class="btn btn-primary mb-0" target="_blank">Start Now</a>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
#       <!-- Action box item -->
# 			<div class="col-lg-6 position-relative overflow-hidden">
# 				<div class="bg-secondary rounded-3 bg-opacity-10 p-5 h-100">
# 					<!-- Image -->
# 					<div class="position-absolute bottom-0 end-0 me-3">
# 						<img src="static/images/element/15.svg" class="h-100px h-sm-200px" alt="">
# 					</div>
# 					<!-- Content -->
# 					<div class="row">
# 						<div class="col-sm-8 position-relative">
# 							<h3 class="mb-1">Best Rated Courses</h3>
# 							<p class="mb-3 h5 fw-light lead">Enroll now in the most popular and best rated courses.</p>
# 							<a href="https://www.tutorialspoint.com/bestseller/courses" class="btn btn-warning mb-0" target="_blank">View Courses</a>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# </section>
# <!-- ======================= Become an Instructor END -->
#
# <!-- ======================= Selected reading START -->
# <section class="py-4">
# 	<div class="container">
#       <div class="col-sm-12 col-lg-12 col-xl-12">
#            <div class="card card-body special-reading-box">
#               <div class="row">
#                  <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
#                     <a href="https://www.tutorialspoint.com/developers_best_practices/index.htm" title="Developer's Best Practices" class="nav-link">
# 	             <i class="fal fa-display-code fa-3x w-lg-80px w-sm-50px mb-3"></i>
# 		     <p class="text-secondary">Developers <br/><b>Best Practices</b></p>
#                     </a>
#                  </div>
#                  <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
#                     <a href="https://www.tutorialspoint.com/effective_resume_writing.htm" title="Effective Resume Writing" class="nav-link">
# 	             <i class="fal fa-pen-field fa-3x w-lg-80px w-sm-50px mb-3"></i>
#                         <p class="text-secondary">Effective <br/><b>Resume Writing</b></p>
#                     </a>
#                  </div>
#                  <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
#                     <a href="https://www.tutorialspoint.com/computer_glossary.htm" title="Computer Glossary"  class="nav-link">
# 	                <i class="fal fa-notebook fa-3x w-lg-80px w-sm-50px mb-3"></i>
#                         <p class="text-secondary">Computer <br/><b>Glossary</b></p>
#                     </a>
#                  </div>
#                  <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
#                     <a href="https://www.tutorialspoint.com/computer_whoiswho.htm" title="Who is Who in Computer Science" class="nav-link">
# 	                <i class="fal fa-users fa-3x w-lg-80px w-sm-50px mb-3"></i>
#                         <p class="text-secondary">Who is Who <br/><b>in Computer</b></p>
#                     </a>
#                  </div>
#                  <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
#                     <a href="https://www.tutorialspoint.com/questions_and_answers.htm" title="Technical Questions and Answers"  class="nav-link">
# 	                <i class="fal fa-comments-question-check fa-3x w-lg-80px w-sm-50px mb-3"></i>
#                         <p class="text-secondary">Technical <br/><b>Q &amp; A</b></p>
#                     </a>
#                  </div>
#                  <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
#                     <a href="https://www.tutorialspoint.com/multi_language_tutorials.htm" title="Multi-Lingual Tutorials" class="nav-link">
# 	                <i class="fal fa-globe fa-3x w-lg-80px w-sm-50px mb-3"></i>
#                         <p class="text-secondary">Multi-Lingual <br/><b>Tutorials</b></p>
#                     </a>
#                  </div>
#               </div>
#            </div>
# 		</div>
# 	</div>
# </section>
# <!-- ======================= Selected Reading END -->
# </main>
# <!-- **************** MAIN CONTENT END **************** -->
#
# <!-- ======================= Footer START -->
# <footer class="pt-5 bg-light">
# 	<div class="container">
# 		<!-- Row START -->
# 		<div class="row g-4">
# 			<!-- Widget 1 START -->
# 			<div class="col-lg-3">
# 				<!-- logo -->
# 				<a class="me-0" href="index.htm">
# 					<img class="light-mode-item h-60px" src="/images/logo.png" alt="Tutorials Point">
# 					<img class="dark-mode-item h-60px" src="/images/logo-white.png" alt="Tutorials Point">
# 				</a>
# 				<p class="my-3">Tutorials Point is a leading Ed Tech company striving to provide the best learning material on technical and non-technical subjects.</p>
#
# 				<div class="row g-2 mt-2">
# 					<!-- Google play store button -->
# 					<div class="col-6 col-sm-4 col-md-3 col-lg-6">
# 						<a href="https://play.google.com/store/apps/details?id=com.tutorialspoint.onlineviewer" target="_blank"><img src="static/images/client/google-play.svg" alt=""> </a>
# 					</div>
# 					<!-- App store button -->
# 					<div class="col-6 col-sm-4 col-md-3 col-lg-6">
# 						<a href="https://itunes.apple.com/us/app/tutorials-point/id914891263?ls=1&mt=8" target="_blank"> <img src="static/images/client/app-store.svg" alt="app-store"></a>
# 					</div>
# 				</div> <!-- Row END -->
# 			</div>
# 			<!-- Widget 1 END -->
#
# 			<!-- Widget 2 START -->
# 			<div class="col-lg-6">
# 				<div class="row g-4">
# 					<!-- Link block -->
# 					<div class="col-6 col-md-4">
# 						<h5 class="mb-1 mb-md-3">ABOUT US</h5>
# 						<ul class="nav flex-column">
# 						   <li class="nav-item"><a class="nav-link" href="/about/index.htm"><i class="fal fa-check"></i>  Company</a></li>
#                      <li class="nav-item"><a class="nav-link" href="/about/about_team.htm"><i class="fal fa-check"></i> Our Team</a></li>
#                      <li class="nav-item"><a class="nav-link" href="/about/about_careers.htm"><i class="fal fa-check"></i> Careers</a></li>
#                      <li class="nav-item"><a class="nav-link" href="https://www.tutorialspoint.com/about/about_helping.htm"><i class="fal fa-check"></i> Helping</a></li>
#                      <li class="nav-item"><a class="nav-link" href="#"><i class="fal fa-check"></i> Become a teacher</a></li>
# 						</ul>
# 					</div>
#
# 					<!-- Link block -->
# 					<div class="col-6 col-md-4">
# 						<h5  class="mb-1 mb-md-3">TERMS</h5>
# 						<ul class="nav flex-column">
# 						   <li class="nav-item"><a class="nav-link" href="/about/about_terms_of_use.htm"><i class="fal fa-check"></i> Terms of use</a></li>
#                      <li class="nav-item"><a class="nav-link" href="/about/about_privacy.htm"><i class="fal fa-check"></i> Privacy Policy</a></li>
#                      <li class="nav-item"><a class="nav-link" href="/about/about_cookies.htm"><i class="fal fa-check"></i> Cookies Policy</a></li>
#                      <li class="nav-item"><a class="nav-link" href="/about/return_refund_policy.htm"><i class="fal fa-check"></i> Refund Policy</a></li>
#                      <li class="nav-item"><a class="nav-link" href="/about/faq.htm"><i class="fal fa-check"></i> FAQ</a></li>
# 						</ul>
# 					</div>
#
# 					<!-- Link block -->
# 					<div class="col-6 col-md-4">
# 						<h5  class="mb-1 mb-md-3">EXTRA LINKS</h5>
# 						<ul class="nav flex-column">
#                      <li class="nav-item"><a class="nav-link"  href="https://www.tutorialspoint.com/online_dev_tools.htm"><i class="fal fa-check"></i> Dev Tools</a></li>
#                      <li class="nav-item"><a class="nav-link"  href="https://www.tutorialspoint.com/free_web_graphics.htm"><i class="fal fa-check"></i> Free Graphics</a></li>
#                      <li class="nav-item"><a class="nav-link"  href="https://www.tutorialspoint.com/online_file_conversion.htm"><i class="fal fa-check"></i> File Conversion</a></li>
#                      <li class="nav-item"><a class="nav-link"  href="https://www.tutorialspoint.com/netmeeting.php"><i class="fal fa-check"></i> NetMeeting</a></li>
#                      <li class="nav-item"><a class="nav-link"  href="https://www.tutorialspoint.com/free_online_whiteboard.htm"><i class="fal fa-check"></i> Whiteboard</a></li>
# 						</ul>
# 					</div>
# 				</div>
# 			</div>
# 			<!-- Widget 2 END -->
#
# 			<!-- Widget 3 START -->
# 			<div class="col-lg-3">
# 				<h5  class="mb-1 mb-md-3">CONTACT</h5>
# 				<!-- Time -->
# 				<p class="mb-2">
# 				<i class="fal fa-location-dot"></i> Tutorials Point India Private Limited, 4th Floor Incor9 Building, Kavuri Hills, Madhapur,  Hyderabad, Telangana - 500081, <b>INDIA</b>
# 				</p>
# 				<p class="mb-0"><span class="h6 fw-light"><a href="about/contact_us.htm" title="Contact Form">Contact Form <i class="fal fa-envelope"></i></a></span></p>
# 				<ul class="list-inline mb-0 mt-3">
# 					<li class="list-inline-item"> <a class="btn btn-white btn-sm shadow px-2 text-facebook" rel="nofollow" href="https://www.facebook.com/tutorialspointindia" target="_blank"><i class="fab fa-fw fa-facebook-f fa-xl"></i></a> </li>
# 					<li class="list-inline-item"> <a class="btn btn-white btn-sm shadow px-2 text-instagram" rel="nofollow" href="https://www.instagram.com/tutorialspoint_/" target="_blank"><i class="fab fa-fw fa-instagram fa-xl"></i></a> </li>
# 					<li class="list-inline-item"> <a class="btn btn-white btn-sm shadow px-2 text-youtube" rel="nofollow" href="https://www.youtube.com/channel/UCVLbzhxVTiTLiVKeGV7WEBg" target="_blank"><i class="fab fa-fw fa-youtube fa-xl"></i></a> </li>
# 					<li class="list-inline-item"> <a class="btn btn-white btn-sm shadow px-2 text-twitter" rel="nofollow" href="https://twitter.com/tutorialspoint" target="_blank"><i class="fab fa-fw fa-twitter fa-xl"></i></a> </li>
# 					<li class="list-inline-item"><a class="btn btn-white btn-sm shadow px-2 text-linkedin" rel="nofollow" href="https://www.linkedin.com/authwall?trk=bf&trkInfo=AQEkqX2eckF__gAAAX-wMwEYvrsjBVbEtWQd4pgEdVSzkL22Nik1KEpY_ECWLKDGc41z8IOZWr2Bb0fvJplT60NPBtSw87J6QCpc7wD4qQ3iU13n6xJtBxME5o05Wmpg5JPm5YY=&originalReferer=&sessionRedirect=https%3A%2F%2Fwww.linkedin.com%2Fcompany%2Ftutorialspoint" target="_blank"><i class="fab fa-fw fa-linkedin-in fa-xl"></i></a> </li>
# 				</ul>
# 			</div>
# 			<!-- Widget 3 END -->
# 		</div><!-- Row END -->
#
# 		<!-- Divider -->
# 		<hr class="mt-4 mb-0">
#
# 		<!-- Bottom footer -->
# 		<div class="py-3">
# 			<div class="container px-0">
# 				<div class="d-md-flex justify-content-between align-items-center py-3 text-center text-md-center">
# 					<!-- copyright text -->
# 					<div class="text-primary-hover"> Copyrights <a href="#" class="text-body">&copy; 2022 Tutorials Point</a>. All rights reserved. </div>
# 					<!-- copyright links-->
# 					<div class=" mt-3 mt-md-0">
# 						<ul class="list-inline mb-0">
# 							<li class="list-inline-item"><a class="nav-link" href="/about/return_refund_policy.htm"	><i class="fal fa-map-marker-alt me-1"></i>Refund Policy</a></li>
# 							<li class="list-inline-item"><a class="nav-link" href="/about/about_terms_of_use.htm"><i class="fal fa-file-signature me-1"></i> Terms of use</a></li>
# 							<li class="list-inline-item"><a class="nav-link pe-0" href="/about/about_privacy.htm"><i class="fal fa-shield-check me-1"></i> Privacy policy</a></li>
# 						</ul>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
#
# 	</div>
# </footer>
# <!-- ======================= Footer END -->
#
# <!-- Back to top -->
# <div class="back-top"><i class="fa fa-angle-up position-absolute top-50 start-50 translate-middle"></i></div>
#
# <script src="static/vendor/bootstrap/dist/js/bootstrap.bundle.min.js"></script>
# <script src="https://www.tutorialspoint.com/theme/js/localization.js?v=2.21"></script>
# <script src="static/vendor/tiny-slider/tiny-slider.js"></script>
# <script src="static/vendor/purecounterjs/dist/purecounter_vanilla.js"></script>
# <script src="static/js/functions.js?v=1.11"></script>
# <script async src="https://www.googletagmanager.com/gtag/js?id=UA-232293-6"></script>
# <script>
#    window.dataLayer = window.dataLayer || [];
#    function gtag(){dataLayer.push(arguments);}
#    gtag('js', new Date());
#    gtag('config', 'UA-232293-6');
# </script>
# </body>
# </html>

# %%
req.headers
# Out:
# {'Content-Encoding': 'gzip', 'Accept-Ranges': 'bytes', 'Age': '224892', 'Cache-Control': 'max-age=2592000', 'Content-Type': 'text/html; charset=UTF-8', 'Date': 'Thu, 12 May 2022 06:33:32 GMT', 'Expires': 'Sat, 11 Jun 2022 06:33:32 GMT', 'Last-Modified': 'Mon, 09 May 2022 16:05:20 GMT', 'Server': 'ECAcc (sgd/F09E)', 'Strict-Transport-Security': 'max-age=63072000; includeSubdomains', 'Vary': 'Accept-Encoding', 'X-Cache': 'HIT', 'X-Content-Type-Options': 'nosniff', 'X-Frame-Options': 'SAMEORIGIN', 'X-Version': 'APR-1 V1', 'X-XSS-Protection': '1; mode=block', 'Content-Length': '21707'}

# %%
soup = BeautifulSoup(req.text, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>Online Tutorials Library</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="Online Tutorials Library - The Best Content on latest technologies including C, C++, Java, Python, PHP, Machine Learning, Data Science, AppML, AI with Python, Behave, Java16, Spacy." name="Description">
# <meta content="HTML, Python, CSS, SQL, JavaScript, How to, PHP, Java, C++, jQuery, Bootstrap, C#, XML, MySQL, NodeJS, React, Angular, R, AI, Git, Data Science, Code Game, Tutorials, Programming, Web Development, Training, Learning, Quiz, Courses, Lessons, References, Examples, Source code, Demos, Tips" name="Keywords">
# <link href="https://www.tutorialspoint.com" rel="canonical"/>
# <link href="favicon.ico" rel="shortcut icon"/>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://fonts.googleapis.com/css2?family=Heebo:wght@400;500;700&amp;family=Roboto:wght@400;500;700&amp;display=swap" rel="stylesheet"/>
# <link href="static/vendor/font-awesome/css/fontawesome-custom.min.css" rel="stylesheet" type="text/css"/>
# <link href="static/vendor/tiny-slider/tiny-slider.css" rel="stylesheet" type="text/css"/>
# <link href="static/css/style.css" id="style-switch" rel="stylesheet" type="text/css"/>
# <link href="static/css/custom.css" rel="stylesheet" type="text/css"/>
# <script src="/static/js/jquery-3.3.1.min.js"></script>
# <style>
# .lh-7{background-color:#fff!important; min-height:58px; border:2px solid #59bb4d!important;}
# </style>
# </meta></meta></head>
# <body>
# <!-- Top header START -->
# <div class="navbar-top navbar-dark bg-light d-xl-block py-2 mx-2 mx-md-4 rounded-bottom-4">
# <div class="container-fluid px-3 px-xl-3">
# <div class="d-lg-flex justify-content-lg-between align-items-center top-nav-links">
# <!-- Top info -->
# <ul class="nav align-items-center justify-content-center">
# <li class="nav-item" data-bs-animation="false" data-bs-original-title="Home Page" data-bs-placement="bottom" data-bs-toggle="tooltip">
# <a class="nav-link" href="https://www.tutorialspoint.com/index.htm"><i class="fal fa-home me-1"></i> Home</a>
# </li>
# <li class="nav-item" data-bs-animation="false" data-bs-original-title="Online Coding System" data-bs-placement="bottom" data-bs-toggle="tooltip">
# <a class="nav-link" href="https://www.tutorialspoint.com/codingground.htm"><i class="fal fa-code me-1"></i> Coding Ground</a>
# </li>
# <li class="nav-item" data-bs-animation="false" data-bs-original-title="Questions &amp; Answers" data-bs-placement="bottom" data-bs-toggle="tooltip">
# <span><a class="nav-link" href="https://www.tutorialspoint.com/questions/index.php"><i class="fal fa-comments-alt me-1"></i> Q/A</a></span>
# </li>
# <li class="nav-item" data-bs-animation="false" data-bs-original-title="Job Openings" data-bs-placement="bottom" data-bs-toggle="tooltip">
# <span><a class="nav-link" href="https://www.tutorialspoint.com/about/about_careers.htm"><i class="fal fa-suitcase me-1"></i> Jobs</a></span>
# </li>
# <li class="nav-item" data-bs-animation="false" data-bs-original-title="Digital Whiteboard" data-bs-placement="bottom" data-bs-toggle="tooltip">
# <span><a class="nav-link" href="https://www.tutorialspoint.com/whiteboard.htm"><i class="fal fa-chalkboard me-1"></i> Whiteboard</a></span>
# </li>
# <li class="nav-item" data-bs-animation="false" data-bs-original-title="Developer's Tools" data-bs-placement="bottom" data-bs-toggle="tooltip">
# <span><a class="nav-link" href="https://www.tutorialspoint.com/online_dev_tools.htm"><i class="fal fa-screwdriver-wrench me-1"></i> Tools</a></span>
# </li>
# <li class="nav-item" data-bs-animation="false" data-bs-original-title="Corporate Trainings" data-bs-placement="bottom" data-bs-toggle="tooltip">
# <span><a class="nav-link" href="https://www.tutorialspoint.com/business/index.asp"><i class="fal fa-analytics me-1"></i> Business</a></span>
# </li>
# </ul>
# <div class="d-flex align-items-center justify-content-center">
# <div class="navbar-nav ms-2">
# <div class="modeswitch-wrap" id="darkModeSwitch">
# <div class="modeswitch-item">
# <div class="modeswitch-icon"></div>
# </div>
# </div>
# </div>
# <!-- teach with us -->
# <div class="me-3c top-nav-social">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/market/teach_with_us.jsp" target="_blank"><i class="fal fa-screen-users me-2"></i> Teach with us</a>
# </div>
# <!-- Top social -->
# <ul class="list-unstyled d-flex mb-0 top-nav-social">
# <li><a class="px-2 nav-link" href="https://www.facebook.com/tutorialspointindia" rel="nofollow" target="_blank"><i class="fab fa-facebook"></i></a> </li>
# <li><a class="px-2 nav-link" href="https://www.instagram.com/tutorialspoint_/" rel="nofollow" target="_blank"><i class="fab fa-instagram"></i></a> </li>
# <li><a class="px-2 nav-link" href="https://twitter.com/tutorialspoint" rel="nofollow" target="_blank"><i class="fab fa-twitter"></i></a> </li>
# <li><a class="px-2 nav-link" href="https://www.youtube.com/channel/UCVLbzhxVTiTLiVKeGV7WEBg" rel="nofollow" target="_blank"><i class="fab fa-youtube"></i></a> </li>
# <li> <a class="px-2 nav-link" href="https://www.linkedin.com/authwall?trk=bf&amp;trkInfo=AQEkqX2eckF__gAAAX-wMwEYvrsjBVbEtWQd4pgEdVSzkL22Nik1KEpY_ECWLKDGc41z8IOZWr2Bb0fvJplT60NPBtSw87J6QCpc7wD4qQ3iU13n6xJtBxME5o05Wmpg5JPm5YY=&amp;originalReferer=&amp;sessionRedirect=https%3A%2F%2Fwww.linkedin.com%2Fcompany%2Ftutorialspoint" rel="nofollow" target="_blank"><i class="fab fa-linkedin-in"></i></a> </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <!-- Top header END -->
# <!-- Header START -->
# <header class="navbar-light navbar-sticky header-static">
# <!-- Logo Nav START -->
# <nav class="navbar navbar-expand-xl">
# <div class="container-fluid px-3 px-xl-5">
# <!-- Logo START -->
# <a class="navbar-brand" href="index.htm">
# <img alt="logo" class="light-mode-item navbar-brand-item" src="/images/logo.png"/>
# <img alt="logo" class="dark-mode-item navbar-brand-item" src="/images/logo-w.png"/>
# </a>
# <button aria-controls="navbarCollapse" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler ms-auto" data-bs-target="#navbarCollapse" data-bs-toggle="collapse" type="button">
# <span class="navbar-toggler-animation">
# <span></span>
# <span></span>
# <span></span>
# </span>
# </button>
# <div class="navbar-collapse w-100 collapse" id="navbarCollapse">
# <ul class="navbar-nav navbar-nav-scroll me-auto">
# <li class="nav-item dropdown dropdown-menu-shadow-stacked">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" data-bs-toggle="dropdown" href="#" id="categoryMenu"><i class="fal fa-th me-3 fs-5 me-xl-1 d-xl-none"></i> <i class="fal fa-th me-1 d-none d-xl-inline-block"></i><span class="d-xl-inline-block dropdown-toggle">Category</span></a>
# <ul aria-labelledby="categoryMenu" class="dropdown-menu">
# <li> <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/development"><i class="fa fa-cogs cat-icons"></i> Development</a></li>
# <li> <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/it_and_software"><i class="fa fa-tv cat-icons"></i>  IT and Networking</a></li>
# <li> <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/data_science_and_ai_ml"><i class="fa fa-head-side-brain cat-icons"></i> Data Science and AI ML</a></li>
# <li> <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/cyber_security"><i class="fa fa-camera-home cat-icons"></i> Cyber Security</a></li>
# <li> <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/marketing"><i class="fa fa-bullseye-arrow cat-icons"></i> Marketing</a></li>
# <li> <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/office_productivity"><i class="fa fa-camera-home cat-icons"></i> Office Productivity</a></li>
# <li> <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/business"><i class="fa fa-chart-bar cat-icons"></i> Business</a></li>
# <li> <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/lifestyle"><i class="fa fa-person-dolly-empty cat-icons"></i> Lifestyle</a></li>
# </ul>
# </li>
# </ul>
# <!-- Nav category menu END -->
# <!-- Main navbar START -->
# <div class="navbar-collapse collapse" id="navbarCollapse">
# <!-- Nav Search START -->
# <div class="col-xl-4"></div>
# <!-- Nav Search END -->
# </div>
# <!-- Main navbar END -->
# <!-- Nav Main menu START -->
# <ul class="navbar-nav navbar-nav-scroll me-auto">
# <li class="nav-item">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/latest/prime-packs" target="_self"><i class="fal fa-cubes me-1"></i> Prime Packs</a>
# </li>
# <li class="nav-item">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/market/index.asp" target="_self"><i class="fal fa-circle-play me-1"></i> Courses</a>
# </li>
# <li class="nav-item">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/latest/ebooks" target="_self"><i class="fal fa-book-reader me-1"></i> eBooks</a>
# </li>
# <li class="nav-item">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/tutorialslibrary.htm" target="_self"><i class="fal fa-books me-1"></i> Library</a>
# </li>
# </ul>
# <!-- Nav Main menu END -->
# </div>
# <!-- Main navbar END -->
# <!-- Signin START -->
# <div class="navbar-nav d-lg-inline-block">
# <a href="https://www.tutorialspoint.com/market/login.asp" target="_self"><button class="btn btn-grey-border mb-0"><i class="fal fa-sign-in-alt me-2"></i> Login</button></a>
# </div>
# <!-- Signin END -->
# </div>
# </nav>
# <!-- Logo Nav END -->
# </header>
# <!-- Header END -->
# <!-- **************** MAIN CONTENT START **************** -->
# <main>
# <!-- ======================= Main Banner START -->
# <section class="position-relative overflow-hidden pt-5 pt-lg-3">
# <!-- SVG START -->
# <figure class="position-absolute top-50 start-0 translate-middle-y ms-n7 d-none d-xxl-block">
# <svg class="rotate-74 fill-green opacity-1">
# <circle cx="180.4" cy="15.5" r="7.7"></circle>
# <path d="m159.9 22.4c-3.8 0-6.9-3.1-6.9-6.9s3.1-6.9 6.9-6.9 6.9 3.1 6.9 6.9-3.1 6.9-6.9 6.9z"></path>
# <ellipse cx="139.4" cy="15.5" rx="6.1" ry="6.1" transform="matrix(.3862 -.9224 .9224 .3862 71.25 138.08)"></ellipse>
# <circle cx="118.9" cy="15.5" r="5.4"></circle>
# <path d="m98.4 20.1c-2.5 0-4.6-2.1-4.6-4.6s2.1-4.6 4.6-4.6 4.6 2.1 4.6 4.6-2.1 4.6-4.6 4.6z"></path>
# <path d="m77.9 19.3c-2.1 0-3.8-1.7-3.8-3.8s1.7-3.8 3.8-3.8 3.8 1.7 3.8 3.8-1.7 3.8-3.8 3.8z"></path>
# <path d="m57.3 18.6c-1.7 0-3.1-1.4-3.1-3.1s1.4-3.1 3.1-3.1 3.1 1.4 3.1 3.1-1.4 3.1-3.1 3.1z"></path>
# <path d="m36.8 17.8c-1.3 0-2.3-1-2.3-2.3s1-2.3 2.3-2.3 2.3 1 2.3 2.3-1 2.3-2.3 2.3z"></path>
# <circle cx="180.4" cy="153.2" r="7.7"></circle>
# <path d="m159.9 160.1c-3.8 0-6.9-3.1-6.9-6.9s3.1-6.9 6.9-6.9 6.9 3.1 6.9 6.9-3.1 6.9-6.9 6.9z"></path>
# <ellipse cx="139.4" cy="153.2" rx="6.1" ry="6.1" transform="matrix(.3862 -.9224 .9224 .3862 -55.794 222.61)"></ellipse>
# <circle cx="118.9" cy="153.2" r="5.4"></circle>
# <path d="m98.4 157.8c-2.5 0-4.6-2.1-4.6-4.6s2.1-4.6 4.6-4.6 4.6 2.1 4.6 4.6c0 2.6-2.1 4.6-4.6 4.6z"></path>
# <circle cx="77.9" cy="153.2" r="3.8"></circle>
# <path d="m57.3 156.3c-1.7 0-3.1-1.4-3.1-3.1s1.4-3.1 3.1-3.1 3.1 1.4 3.1 3.1-1.4 3.1-3.1 3.1z"></path>
# <path d="m36.8 155.5c-1.3 0-2.3-1-2.3-2.3s1-2.3 2.3-2.3 2.3 1 2.3 2.3-1 2.3-2.3 2.3z"></path>
# <circle cx="16.3" cy="153.2" r="1.6"></circle>
# <circle cx="180.4" cy="176.2" r="7.7"></circle>
# <path d="m159.9 183.1c-3.8 0-6.9-3.1-6.9-6.9s3.1-6.9 6.9-6.9 6.9 3.1 6.9 6.9-3.1 6.9-6.9 6.9z"></path>
# <ellipse cx="139.4" cy="176.2" rx="6.1" ry="6.1" transform="matrix(.3862 -.9224 .9224 .3862 -76.968 236.7)"></ellipse>
# <circle cx="118.9" cy="176.2" r="5.4"></circle>
# <path d="m98.4 180.8c-2.5 0-4.6-2.1-4.6-4.6s2.1-4.6 4.6-4.6 4.6 2.1 4.6 4.6-2.1 4.6-4.6 4.6z"></path>
# <path d="m77.9 180c-2.1 0-3.8-1.7-3.8-3.8s1.7-3.8 3.8-3.8 3.8 1.7 3.8 3.8-1.7 3.8-3.8 3.8z"></path>
# <path d="m57.3 179.3c-1.7 0-3.1-1.4-3.1-3.1s1.4-3.1 3.1-3.1 3.1 1.4 3.1 3.1-1.4 3.1-3.1 3.1z"></path>
# <path d="m36.8 178.5c-1.3 0-2.3-1-2.3-2.3s1-2.3 2.3-2.3 2.3 1 2.3 2.3-1 2.3-2.3 2.3z"></path>
# <circle cx="16.3" cy="176.2" r="1.6"></circle>
# </svg>
# </figure>
# <!-- SVG END -->
# <!-- SVG START -->
# <span class="position-absolute top-50 end-0 translate-middle-y mt-5 me-n5 d-none d-xxl-inline-flex">
# <svg class="fill-green rotate-186 opacity-8">
# <path d="m35.4 54.2c0 0.6 0 1.1-0.1 1.7-0.9 9.3-9.2 16.1-18.5 15.1-4.5-0.4-8.5-2.6-11.4-6.1-2.8-3.5-4.2-7.9-3.7-12.4 0.9-9.3 9.2-16.1 18.5-15.1 4.5 0.4 8.5 2.6 11.4 6.1 2.4 3 3.8 6.8 3.8 10.7zm-33.4 0c0 3.8 1.3 7.5 3.8 10.4 2.8 3.4 6.8 5.5 11.2 6 9.1 0.9 17.2-5.8 18.1-14.8 0.4-4.4-0.9-8.7-3.7-12.1s-6.8-5.5-11.2-6c-9.2-0.8-17.3 5.8-18.2 14.9v1.6z"></path>
# <path d="m113.9 54.2c0 12.3-4.7 24-13.4 32.8-18.1 18.5-47.9 18.9-66.4 0.8-9-8.8-14-20.5-14.1-33-0.2-12.5 4.6-24.4 13.4-33.4 18.1-18.6 47.9-18.9 66.4-0.8l-0.1 0.1 0.1-0.1c9 8.8 14 20.5 14.1 33v0.6zm-93.6 0v0.5c0.1 12.4 5.1 24.1 14 32.8 18.4 18 48 17.6 65.9-0.7 8.7-8.9 13.4-20.7 13.3-33.1s-5.1-24.1-14-32.8c-18.4-18-48-17.6-65.9 0.7-8.6 8.8-13.3 20.3-13.3 32.6z"></path>
# <path d="m118.3 54.2c0 13-5.1 25.3-14.3 34.5-19 19-50 19-69 0-9.2-9.2-14.3-21.4-14.3-34.5 0-13 5.1-25.3 14.3-34.5 19-19 50-19 69 0l-0.1 0.1 0.1-0.1c9.2 9.2 14.3 21.5 14.3 34.5zm-97.2 0c0 12.9 5 25.1 14.2 34.2 18.9 18.9 49.6 18.9 68.4 0 9.1-9.1 14.2-21.3 14.2-34.2s-5-25.1-14.2-34.2c-18.8-18.9-49.5-18.9-68.4 0-9.2 9.1-14.2 21.3-14.2 34.2z"></path>
# </svg>
# </span>
# <!-- SVG END -->
# <!-- SVG START -->
# <figure class="position-absolute top-0 start-50 ms-5">
# <svg class="fill-orange opacity-4" height="29px" width="29px">
# <path d="M29.004,14.502 C29.004,22.512 22.511,29.004 14.502,29.004 C6.492,29.004 -0.001,22.512 -0.001,14.502 C-0.001,6.492 6.492,-0.001 14.502,-0.001 C22.511,-0.001 29.004,6.492 29.004,14.502 Z"></path>
# </svg>
# </figure>
# <!-- SVG END -->
# <!-- Content START -->
# <div class="container">
# <div class="row align-items-center g-5">
# <div class="col-lg-5 col-xl-6 position-relative z-index-1 text-center text-lg-start mt-n7">
# <figure class="fill-info position-absolute bottom-0 end-0 me-5 d-none d-xl-block">
# <svg height="42px" width="42px">
# <path d="M21.000,-0.001 L28.424,13.575 L41.999,20.999 L28.424,28.424 L21.000,41.998 L13.575,28.424 L-0.000,20.999 L13.575,13.575 L21.000,-0.001 Z"></path>
# </svg>
# </figure>
# <figure class="fill-success position-absolute top-0 start-50 translate-middle-x mt-6 ms-5">
# <svg height="21px" width="22px">
# <path d="M10.717,4.757 L14.440,-0.001 L14.215,6.023 L20.142,4.757 L16.076,9.228 L21.435,12.046 L15.430,12.873 L17.713,18.457 L12.579,15.252 L10.717,20.988 L8.856,15.252 L3.722,18.457 L6.005,12.873 L-0.000,12.046 L5.359,9.228 L1.292,4.757 L7.220,6.023 L6.995,-0.001 L10.717,4.757 Z"></path>
# </svg>
# </figure>
# <h1 class="mb-0 display-6 mb-4 mt-8">Simply Easy Learning at your
# 					<span class="position-relative">fingertips
# 						<span class="position-absolute top-50 start-50 translate-middle ms-3 z-index-n1">
# <svg enable-background="new 0 0 366 62.1" height="62.1px" viewbox="0 0 366 62.1" width="300px" xmlns="http://www.w3.org/2000/svg">
1.6-19.6-1.4-29.4-0.1 2.2 1.4 5.1 1 7.4 1 7.3 0.1 14.1 1.3 21.2 1.9 2.8 0.3 5.9 0 8.5 0.8 1.5 0.5 4.6-1.1 4.9 1.3 4-0.7 7.3 1.5 11.1 1.2 4-0.3 7.7 0.6 11.6 1.1 0.8 0.1 2.2 0.3 2.3 1.1 0.2 1-1.1 1.2-2 1.5-3.4 1-6.7-0.4-10.1-0.4-0.9 0-2-0.2-2.9-0.2-9.4 0.1-18.8-1.3-28.3-1.8-6-0.4-12.1-0.9-18.1-1.3 0 0.2 0 0.4-0.2 0.6 6.1 0.5 12.1 1.4 18.3 0.7z"></path>
# </svg>
# </span>
# <!-- SVG END -->
# </span>
# </h1>
# <div class="nav-item w-100 mb-4">
# <form class="rounded position-relative">
# <input aria-label="Search" class="form-control pe-4 bg-secondary bg-opacity-10 border-0 search-strings lh-7" data-result="search-results" id="search-strings" name="key" placeholder="Search courses, ebooks and prime packs" type="search"/>
# <button class="btn bg-transparent px-2 py-0 position-absolute top-50 end-0 translate-middle-y" id="btnSearch" type="submit"><i class="fal fa-search fs-5 me-3"></i></button>
# <div class="search-box" id="search-results"></div>
# <div class="clear"></div>
# </form>
# </div>
# <ul class="list-inline position-relative justify-content-center justify-content-lg-start mb-5 mt-2">
# <li class="list-inline-item me-3 fs-5"><a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/latest/prime-packs" target="_self"><i class="fal fa-cubes me-1"></i> Prime Packs</a></li>
# <li class="list-inline-item me-3 fs-5"><a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/market/index.asp" target="_self"><i class="fal fa-circle-play me-1"></i> Courses</a></li>
# <li class="list-inline-item me-3 fs-5"><a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/latest/ebooks" target="_self"><i class="fal fa-book-reader me-1"></i> eBooks</a></li>
# <li class="list-inline-item me-3 fs-5"><a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/tutorialslibrary.htm" target="_self"><i class="fal fa-books me-1"></i> Library</a></li>
# </ul>
# <div class="">
# <a class="btn btn-lg btn-green-hard me-2 mb-4 mb-sm-0" href="https://www.tutorialspoint.com/codingground.htm"><i class="fal fa-code me-1"></i> Coding Ground</a>
# <a class="ms-0 ms-sm-4" data-gallery="office-tour" data-glightbox="" href="https://www.tutorialspoint.com/market/index.asp">
# <div class="btn btn-round btn-black-shadow mb-0 me-3 align-middle"> <i class="fal fa-play"></i></div>
# <div class="align-middle d-inline-block">
# <h6 class="mb-0 fw-normal">Watch Demo Video</h6>
# </div>
# </a>
# </div>
# </div>
# <div class="col-lg-7 col-xl-6 text-center position-relative">
# <figure class="position-absolute bottom-0 start-50 translate-middle-x mt-4 mb-0">
# <svg height="538px" style="enable-background:new 0 0 554 544;" viewbox="0 0 554 544" width="550px" xml:space="preserve">
# <path d="m52.1 19.7 0.3-0.3c-0.1 0 0 0 0 0 0.1-0.1 0.3-0.2 0.4-0.3l0.9-0.6c0.6-0.4 1.2-0.8 1.8-1.1 0.3-0.2 0.4-0.6 0.2-0.9s-0.6-0.4-0.9-0.2c-1.3 0.7-2.6 1.5-3.7 2.5-0.3 0.2-0.2 0.7 0 0.9 0.4 0.3 0.7 0.3 1 0z"></path>
# <path d="m20.2 49.3c-0.1 0 0 0 0 0 0.1 0.2 0.1 0.3 0.1 0.4 0.1 0.3 0.2 0.6 0.4 0.9 0.3 0.7 0.5 1.5 0.7 2.3s0.2 1.7 0.3 2.5c0.1 0.7 0.1 1.6 0.5 2.2 0.4 0.7 1.6 0.1 1.1-0.7-0.2-0.3-0.2-0.6-0.2-1 0-0.5-0.1-0.9-0.1-1.4-0.1-0.9-0.2-1.8-0.4-2.7-0.2-0.8-0.5-1.5-0.8-2.3-0.2-0.5-0.3-1.2-0.8-1.4-0.3-0.1-0.7-0.1-0.9 0.2-0.3 0.4-0.3 0.9 0.1 1z"></path>
# </svg>
# </figure>
# <div class="p-2 bg-white shadow rounded-3 position-absolute top-50 start-0 translate-middle-y mt-n7 d-none d-sm-block">
# <img alt="Icon" src="static/images/client/science.svg"/>
# </div>
# <div class="p-2 bg-white shadow rounded-3 position-absolute top-0 end-0 me-5">
# <img alt="Icon" src="static/images/client/angular.svg"/>
# </div>
# <div class="p-2 bg-white shadow rounded-3 position-absolute top-50 end-0 translate-middle-y mt-5 ms-5 d-none d-lg-block z-index-9">
# <img alt="Icon" src="static/images/client/figma.svg"/>
# </div>
# <div class="p-3 bg-blur border border-light shadow rounded-4 position-absolute bottom-0 start-0 z-index-9 d-none d-xl-block mb-5 ms-5">
# <div class="d-flex justify-content-between align-items-center">
# <span class="icon-lg bg-warning rounded-circle"><i class="fal fa-envelope text-white"></i></span>
# </div>
# </div>
# <div class="position-relative">
# <img alt="" src="static/images/banner-img.png"/>
# </div>
# </div>
# <!-- Right content END -->
# </div>
# </div>
# <!-- Content END -->
# </section>
# <!-- ======================= Main Banner END -->
# <!-- ======================= Counter START -->
# <section class="py-0 pb-5 pt-0 pt-lg-5">
# <div class="container">
# <div class="tiny-slider arrow-round arrow-blur arrow-hover">
# <div class="tiny-slider-inner row g-4" data-arrow="true" data-autoplay="false" data-dots="false" data-gutter="20" data-items="4" data-items-lg="3" data-items-md="2" data-items-xs="1">
# <!-- Counter item -->
# <div class="col-sm-6 col-xl-3">
# <div class="d-flex justify-content-center align-items-center p-4 bg-warning bg-opacity-15 rounded-3">
# <span class="display-6 lh-1 text-warning mb-0"><i class="fal fa-laptop"></i></span>
# <div class="ms-4 h6 fw-normal">
# <div class="d-flex">
# <h5 class="purecounter mb-0 fw-bold" data-purecounter-delay="200" data-purecounter-end="5000" data-purecounter-start="0">0</h5>
# <span class="mb-0 h5">+</span>
# </div>
# <p class="mb-0">Premium Courses</p>
# </div>
# </div>
# </div>
# <!-- Counter item -->
# <div class="col-sm-6 col-xl-3">
# <div class="d-flex justify-content-center align-items-center p-4 bg-blue bg-opacity-10 rounded-3">
# <span class="display-6 lh-1 text-blue mb-0"><i class="fal fa-user-tie"></i></span>
# <div class="ms-4 h6 fw-normal">
# <div class="d-flex">
# <h5 class="purecounter mb-0 fw-bold" data-purecounter-delay="200" data-purecounter-end="1000" data-purecounter-start="0">0</h5>
# <span class="mb-0 h5">+</span>
# </div>
# <p class="mb-0">Expert Tutors</p>
# </div>
# </div>
# </div>
# <!-- Counter item -->
# <div class="col-sm-6 col-xl-3">
# <div class="d-flex justify-content-center align-items-center p-4 bg-purple bg-opacity-10 rounded-3">
# <span class="display-6 lh-1 text-purple mb-0"><i class="fal fa-user-graduate"></i></span>
# <div class="ms-4 h6 fw-normal">
# <div class="d-flex">
# <h5 class="purecounter mb-0 fw-bold" data-purecounter-delay="200" data-purecounter-end="30" data-purecounter-start="0">0</h5>
# <span class="mb-0 h5">M+</span>
# </div>
# <p class="mb-0">Online Students</p>
# </div>
# </div>
# </div>
# <!-- Counter item -->
# <div class="col-sm-6 col-xl-3">
# <div class="d-flex justify-content-center align-items-center p-4 bg-info bg-opacity-10 rounded-3">
# <span class="display-6 lh-1 text-info mb-0"><i class="fal fa-certificate"></i></span>
# <div class="ms-4 h6 fw-normal">
# <div class="d-flex">
# <h5 class="purecounter mb-0 fw-bold" data-purecounter-delay="300" data-purecounter-end="50" data-purecounter-start="0">0</h5>
# <span class="mb-0 h5">K+</span>
# </div>
# <p class="mb-0">Certificates Delivered</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!-- ======================= Counter END -->
# <!-- ======================= Listed course START -->
# <section class="position-relative pb-5 pt-0 pt-lg-5">
# <div class="container">
# <!-- Title -->
# <div class="row mb-4">
# <div class="col-lg-8 mx-auto text-center">
# <h2 class="fs-1"><i class="fal fa-grid me-3"></i>Top <span class="text-green">Categories</span></h2>
# </div>
# </div>
# <div class="tiny-slider arrow-round arrow-blur arrow-hover">
# <div class="tiny-slider-inner row g-4" data-arrow="true" data-autoplay="false" data-dots="true" data-gutter="20" data-items="4" data-items-lg="3" data-items-md="2" data-items-xs="1" data-mobile="true">
# <div class="col-sm-6 col-md-4 col-xl-3">
# <div class="bg-primary bg-opacity-10 rounded-3 text-center p-3 position-relative btn-transition">
# <div class="icon-xl bg-body mx-auto rounded-circle mb-3">
# <img src="static/images/development.svg">
# </img></div>
# <h5 class="mb-1"><a class="stretched-link" href="https://www.tutorialspoint.com/categories/development"> Development</a></h5>
# <span class="mb-0">15 Course</span>
# </div>
# </div>
# <div class="col-sm-6 col-md-4 col-xl-3">
# <div class="bg-primary bg-opacity-10 rounded-3 text-center p-3 position-relative btn-transition">
# <div class="icon-xl bg-body mx-auto rounded-circle mb-3">
# <img src="static/images/it-and-networking.svg">
# </img></div>
# <h5 class="mb-1"><a class="stretched-link" href="https://www.tutorialspoint.com/categories/it_and_software">IT and Networking</a></h5>
# <span class="mb-0">22 Course</span>
# </div>
# </div>
# <div class="col-sm-6 col-md-4 col-xl-3">
# <div class="bg-primary bg-opacity-10 rounded-3 text-center p-3 position-relative btn-transition">
# <div class="icon-xl bg-body mx-auto rounded-circle mb-3">
# <img src="static/images/data-science-and-ai-ml.svg">
# </img></div>
# <h5 class="mb-1"><a class="stretched-link" href="https://www.tutorialspoint.com/categories/data_science_and_ai_ml">Data Science and AI ML</a></h5>
# <span class="mb-0">53 Course</span>
# </div>
# </div>
# <div class="col-sm-6 col-md-4 col-xl-3">
# <div class="bg-primary bg-opacity-10 rounded-3 text-center p-3 position-relative btn-transition">
# <div class="icon-xl bg-body mx-auto rounded-circle mb-3">
# <img src="static/images/cyber-security.svg">
# </img></div>
# <h5 class="mb-1"><a class="stretched-link" href="https://www.tutorialspoint.com/categories/cyber_security">Cyber Security</a></h5>
# <span class="mb-0">25 Course</span>
# </div>
# </div>
# <!-- Item -->
# <div class="col-sm-6 col-md-4 col-xl-3">
# <div class="bg-primary bg-opacity-10 rounded-3 text-center p-3 position-relative btn-transition">
# <!-- Image -->
# <div class="icon-xl bg-body mx-auto rounded-circle mb-3">
# <img src="static/images/marketing.svg">
# </img></div>
# <!-- Title -->
# <h5 class="mb-1"><a class="stretched-link" href="https://www.tutorialspoint.com/categories/marketing">Marketing</a></h5>
# <span class="mb-0">30 Course</span>
# </div>
# </div>
# <!-- Item -->
# <div class="col-sm-6 col-md-4 col-xl-3">
# <div class="bg-primary bg-opacity-10 rounded-3 text-center p-3 position-relative btn-transition">
# <!-- Image -->
# <div class="icon-xl bg-body mx-auto rounded-circle mb-3">
# <img src="static/images/office-productivity.svg">
# </img></div>
# <!-- Title -->
# <h5 class="mb-1"><a class="stretched-link" href="https://www.tutorialspoint.com/categories/office_productivity">Office Productivity</a></h5>
# <span class="mb-0">20 Course</span>
# </div>
# </div>
# <!-- Item -->
# <div class="col-sm-6 col-md-4 col-xl-3">
# ...
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/database_tutorials.htm">View more<i class="fal fa-sync ms-2"></i></a>
# </div>
# </div>
# </div>
# <div class="col-sm-12 col-lg-6 col-xl-6">
# <div class="card card-body shadow rounded-3 grey-box">
# <div class="row">
# <h5 class="card-title pb-2 mb-4 ps-1"><i class="fab fa-windows icon-md text-dark mb-0 bg-grey rounded-3 me-2"></i>Microsoft Technologies</h5>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <div class="asp-net">
# <a href="https://www.tutorialspoint.com/asp.net/index.htm" target="_blank" title="ASP.NET Tutorial">
# <div class="image-title white-title">ASP.NET</div>
# </a>
# </div>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <div class="entity-framework">
# <a href="https://www.tutorialspoint.com/entity_framework/index.htm" target="_blank" title="Entity Framework Tutorial">
# <div class="image-title white-title">Entity Framework</div>
# </a>
# </div>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <div class="vb-net">
# <a href="https://www.tutorialspoint.com/vb.net/index.htm" target="_blank" title="VB.NET Tutorial">
# <div class="image-title white-title">VB.NET Tutorial</div>
# </a>
# </div>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <div class="microsoft-project">
# <a href="https://www.tutorialspoint.com/ms_project/index.htm" target="_blank" title="Microsoft Project Tutorial">
# <div class="image-title white-title">Microsoft Project</div>
# </a>
# </div>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <div class="microsoft-excel">
# <a href="https://www.tutorialspoint.com/excel/index.htm" target="_blank" title="Microsoft Excel Tutorial">
# <div class="image-title white-title">Microsoft Excel</div>
# </a>
# </div>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <div class="microsoft-word">
# <a href="https://www.tutorialspoint.com/word/index.htm" target="_blank" title="Microsoft Word Tutorial">
# <div class="image-title white-title">Microsoft Word</div>
# </a>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# <div class="text-end mt-2 pt-2">
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/microsoft_technologies_tutorials.htm">View more<i class="fal fa-sync ms-2"></i></a>
# </div>
# </div>
# </div>
# <div class="col-sm-12 col-lg-6 col-xl-6">
# <div class="card card-body shadow rounded-3 grey-box">
# <div class="row">
# <h5 class="card-title pb-2 mb-4 ps-1"><i class="fal fa-chart-pie icon-md text-dark mb-0 bg-grey rounded-3 me-2"></i>Big Data and Analytics</h5>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <div class="big-data-analytics">
# <a href="https://www.tutorialspoint.com/big_data_analytics/index.htm" target="_blank" title="Big Data Analytics Tutorial">
# <div class="image-title white-title">Big Data Analytics</div>
# </a>
# </div>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <div class="hadoop">
# <a href="https://www.tutorialspoint.com/hadoop/index.htm" target="_blank" title="Hadoop Tutorial">
# <div class="image-title white-title">Hadoop Tutorial</div>
# </a>
# </div>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <div class="sas">
# <a href="https://www.tutorialspoint.com/sas/index.htm" target="_blank" title="SAS Tutorial">
# <div class="image-title white-title">SAS Tutorial</div>
# </a>
# </div>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <div class="qlikview">
# <a href="https://www.tutorialspoint.com/qlikview/index.htm" target="_blank" title="QlikView Tutorial">
# <div class="image-title white-title">QlikView Tutorial</div>
# </a>
# </div>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <div class="powerbi">
# <a href="https://www.tutorialspoint.com/power_bi/index.htm" target="_blank" title="Power BI Tutorial">
# <div class="image-title white-title">Power BI Tutorial</div>
# </a>
# </div>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <div class="tableau">
# <a href="https://www.tutorialspoint.com/tableau/index.htm" target="_blank" title="Tableau Tutorial">
# <div class="image-title white-title">Tableau Tutorial</div>
# </a>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# <div class="text-end mt-2 pt-2">
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/big_data_tutorials.htm">View more<i class="fal fa-sync ms-2"></i></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!-- =======================
# Tutorials END -->
# <!-- =======================
# Become an Instructor START -->
# <section class="py-4">
# <div class="container">
# <div class="row g-4">
# <!-- Action box item -->
# <div class="col-lg-6 position-relative overflow-hidden">
# <div class="bg-primary bg-opacity-10 rounded-3 p-5 h-100">
# <!-- Image -->
# <div class="position-absolute bottom-0 end-0 me-3">
# <img alt="" class="h-100px h-sm-200px" src="static/images/element/08.svg"/>
# </div>
# <!-- Content -->
# <div class="row">
# <div class="col-sm-8 position-relative">
# <h3 class="mb-1">Become an Instructor!</h3>
# <p class="mb-3 h5 fw-light lead">Join one of the world’s largest online learning marketplaces.</p>
# <a class="btn btn-primary mb-0" href="https://www.tutorialspoint.com/market/teach_with_us.jsp" target="_blank">Start Now</a>
# </div>
# </div>
# </div>
# </div>
# <!-- Action box item -->
# <div class="col-lg-6 position-relative overflow-hidden">
# <div class="bg-secondary rounded-3 bg-opacity-10 p-5 h-100">
# <!-- Image -->
# <div class="position-absolute bottom-0 end-0 me-3">
# <img alt="" class="h-100px h-sm-200px" src="static/images/element/15.svg"/>
# </div>
# <!-- Content -->
# <div class="row">
# <div class="col-sm-8 position-relative">
# <h3 class="mb-1">Best Rated Courses</h3>
# <p class="mb-3 h5 fw-light lead">Enroll now in the most popular and best rated courses.</p>
# <a class="btn btn-warning mb-0" href="https://www.tutorialspoint.com/bestseller/courses" target="_blank">View Courses</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!-- ======================= Become an Instructor END -->
# <!-- ======================= Selected reading START -->
# <section class="py-4">
# <div class="container">
# <div class="col-sm-12 col-lg-12 col-xl-12">
# <div class="card card-body special-reading-box">
# <div class="row">
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <a class="nav-link" href="https://www.tutorialspoint.com/developers_best_practices/index.htm" title="Developer's Best Practices">
# <i class="fal fa-display-code fa-3x w-lg-80px w-sm-50px mb-3"></i>
# <p class="text-secondary">Developers <br/><b>Best Practices</b></p>
# </a>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <a class="nav-link" href="https://www.tutorialspoint.com/effective_resume_writing.htm" title="Effective Resume Writing">
# <i class="fal fa-pen-field fa-3x w-lg-80px w-sm-50px mb-3"></i>
# <p class="text-secondary">Effective <br/><b>Resume Writing</b></p>
# </a>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <a class="nav-link" href="https://www.tutorialspoint.com/computer_glossary.htm" title="Computer Glossary">
# <i class="fal fa-notebook fa-3x w-lg-80px w-sm-50px mb-3"></i>
# <p class="text-secondary">Computer <br/><b>Glossary</b></p>
# </a>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <a class="nav-link" href="https://www.tutorialspoint.com/computer_whoiswho.htm" title="Who is Who in Computer Science">
# <i class="fal fa-users fa-3x w-lg-80px w-sm-50px mb-3"></i>
# <p class="text-secondary">Who is Who <br/><b>in Computer</b></p>
# </a>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <a class="nav-link" href="https://www.tutorialspoint.com/questions_and_answers.htm" title="Technical Questions and Answers">
# <i class="fal fa-comments-question-check fa-3x w-lg-80px w-sm-50px mb-3"></i>
# <p class="text-secondary">Technical <br/><b>Q &amp; A</b></p>
# </a>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <a class="nav-link" href="https://www.tutorialspoint.com/multi_language_tutorials.htm" title="Multi-Lingual Tutorials">
# <i class="fal fa-globe fa-3x w-lg-80px w-sm-50px mb-3"></i>
# <p class="text-secondary">Multi-Lingual <br/><b>Tutorials</b></p>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!-- ======================= Selected Reading END -->
# </main>
# <!-- **************** MAIN CONTENT END **************** -->
# <!-- ======================= Footer START -->
# <footer class="pt-5 bg-light">
# <div class="container">
# <!-- Row START -->
# <div class="row g-4">
# <!-- Widget 1 START -->
# <div class="col-lg-3">
# <!-- logo -->
# <a class="me-0" href="index.htm">
# <img alt="Tutorials Point" class="light-mode-item h-60px" src="/images/logo.png"/>
# <img alt="Tutorials Point" class="dark-mode-item h-60px" src="/images/logo-white.png"/>
# </a>
# <p class="my-3">Tutorials Point is a leading Ed Tech company striving to provide the best learning material on technical and non-technical subjects.</p>
# <div class="row g-2 mt-2">
# <!-- Google play store button -->
# <div class="col-6 col-sm-4 col-md-3 col-lg-6">
# <a href="https://play.google.com/store/apps/details?id=com.tutorialspoint.onlineviewer" target="_blank"><img alt="" src="static/images/client/google-play.svg"/> </a>
# </div>
# <!-- App store button -->
# <div class="col-6 col-sm-4 col-md-3 col-lg-6">
# <a href="https://itunes.apple.com/us/app/tutorials-point/id914891263?ls=1&amp;mt=8" target="_blank"> <img alt="app-store" src="static/images/client/app-store.svg"/></a>
# </div>
# </div> <!-- Row END -->
# </div>
# <!-- Widget 1 END -->
# <!-- Widget 2 START -->
# <div class="col-lg-6">
# <div class="row g-4">
# <!-- Link block -->
# <div class="col-6 col-md-4">
# <h5 class="mb-1 mb-md-3">ABOUT US</h5>
# <ul class="nav flex-column">
# <li class="nav-item"><a class="nav-link" href="/about/index.htm"><i class="fal fa-check"></i>  Company</a></li>
# <li class="nav-item"><a class="nav-link" href="/about/about_team.htm"><i class="fal fa-check"></i> Our Team</a></li>
# <li class="nav-item"><a class="nav-link" href="/about/about_careers.htm"><i class="fal fa-check"></i> Careers</a></li>
# <li class="nav-item"><a class="nav-link" href="https://www.tutorialspoint.com/about/about_helping.htm"><i class="fal fa-check"></i> Helping</a></li>
# <li class="nav-item"><a class="nav-link" href="#"><i class="fal fa-check"></i> Become a teacher</a></li>
# </ul>
# </div>
# <!-- Link block -->
# <div class="col-6 col-md-4">
# <h5 class="mb-1 mb-md-3">TERMS</h5>
# <ul class="nav flex-column">
# <li class="nav-item"><a class="nav-link" href="/about/about_terms_of_use.htm"><i class="fal fa-check"></i> Terms of use</a></li>
# <li class="nav-item"><a class="nav-link" href="/about/about_privacy.htm"><i class="fal fa-check"></i> Privacy Policy</a></li>
# <li class="nav-item"><a class="nav-link" href="/about/about_cookies.htm"><i class="fal fa-check"></i> Cookies Policy</a></li>
# <li class="nav-item"><a class="nav-link" href="/about/return_refund_policy.htm"><i class="fal fa-check"></i> Refund Policy</a></li>
# <li class="nav-item"><a class="nav-link" href="/about/faq.htm"><i class="fal fa-check"></i> FAQ</a></li>
# </ul>
# </div>
# <!-- Link block -->
# <div class="col-6 col-md-4">
# <h5 class="mb-1 mb-md-3">EXTRA LINKS</h5>
# <ul class="nav flex-column">
# <li class="nav-item"><a class="nav-link" href="https://www.tutorialspoint.com/online_dev_tools.htm"><i class="fal fa-check"></i> Dev Tools</a></li>
# <li class="nav-item"><a class="nav-link" href="https://www.tutorialspoint.com/free_web_graphics.htm"><i class="fal fa-check"></i> Free Graphics</a></li>
# <li class="nav-item"><a class="nav-link" href="https://www.tutorialspoint.com/online_file_conversion.htm"><i class="fal fa-check"></i> File Conversion</a></li>
# <li class="nav-item"><a class="nav-link" href="https://www.tutorialspoint.com/netmeeting.php"><i class="fal fa-check"></i> NetMeeting</a></li>
# <li class="nav-item"><a class="nav-link" href="https://www.tutorialspoint.com/free_online_whiteboard.htm"><i class="fal fa-check"></i> Whiteboard</a></li>
# </ul>
# </div>
# </div>
# </div>
# <!-- Widget 2 END -->
# <!-- Widget 3 START -->
# <div class="col-lg-3">
# <h5 class="mb-1 mb-md-3">CONTACT</h5>
# <!-- Time -->
# <p class="mb-2">
# <i class="fal fa-location-dot"></i> Tutorials Point India Private Limited, 4th Floor Incor9 Building, Kavuri Hills, Madhapur,  Hyderabad, Telangana - 500081, <b>INDIA</b>
# </p>
# <p class="mb-0"><span class="h6 fw-light"><a href="about/contact_us.htm" title="Contact Form">Contact Form <i class="fal fa-envelope"></i></a></span></p>
# <ul class="list-inline mb-0 mt-3">
# <li class="list-inline-item"> <a class="btn btn-white btn-sm shadow px-2 text-facebook" href="https://www.facebook.com/tutorialspointindia" rel="nofollow" target="_blank"><i class="fab fa-fw fa-facebook-f fa-xl"></i></a> </li>
# <li class="list-inline-item"> <a class="btn btn-white btn-sm shadow px-2 text-instagram" href="https://www.instagram.com/tutorialspoint_/" rel="nofollow" target="_blank"><i class="fab fa-fw fa-instagram fa-xl"></i></a> </li>
# <li class="list-inline-item"> <a class="btn btn-white btn-sm shadow px-2 text-youtube" href="https://www.youtube.com/channel/UCVLbzhxVTiTLiVKeGV7WEBg" rel="nofollow" target="_blank"><i class="fab fa-fw fa-youtube fa-xl"></i></a> </li>
# <li class="list-inline-item"> <a class="btn btn-white btn-sm shadow px-2 text-twitter" href="https://twitter.com/tutorialspoint" rel="nofollow" target="_blank"><i class="fab fa-fw fa-twitter fa-xl"></i></a> </li>
# <li class="list-inline-item"><a class="btn btn-white btn-sm shadow px-2 text-linkedin" href="https://www.linkedin.com/authwall?trk=bf&amp;trkInfo=AQEkqX2eckF__gAAAX-wMwEYvrsjBVbEtWQd4pgEdVSzkL22Nik1KEpY_ECWLKDGc41z8IOZWr2Bb0fvJplT60NPBtSw87J6QCpc7wD4qQ3iU13n6xJtBxME5o05Wmpg5JPm5YY=&amp;originalReferer=&amp;sessionRedirect=https%3A%2F%2Fwww.linkedin.com%2Fcompany%2Ftutorialspoint" rel="nofollow" target="_blank"><i class="fab fa-fw fa-linkedin-in fa-xl"></i></a> </li>
# </ul>
# </div>
# <!-- Widget 3 END -->
# </div><!-- Row END -->
# <!-- Divider -->
# <hr class="mt-4 mb-0"/>
# <!-- Bottom footer -->
# <div class="py-3">
# <div class="container px-0">
# <div class="d-md-flex justify-content-between align-items-center py-3 text-center text-md-center">
# <!-- copyright text -->
# <div class="text-primary-hover"> Copyrights <a class="text-body" href="#">© 2022 Tutorials Point</a>. All rights reserved. </div>
# <!-- copyright links-->
# <div class="mt-3 mt-md-0">
# <ul class="list-inline mb-0">
# <li class="list-inline-item"><a class="nav-link" href="/about/return_refund_policy.htm"><i class="fal fa-map-marker-alt me-1"></i>Refund Policy</a></li>
# <li class="list-inline-item"><a class="nav-link" href="/about/about_terms_of_use.htm"><i class="fal fa-file-signature me-1"></i> Terms of use</a></li>
# <li class="list-inline-item"><a class="nav-link pe-0" href="/about/about_privacy.htm"><i class="fal fa-shield-check me-1"></i> Privacy policy</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <!-- ======================= Footer END -->
# <!-- Back to top -->
# <div class="back-top"><i class="fa fa-angle-up position-absolute top-50 start-50 translate-middle"></i></div>
# <script src="static/vendor/bootstrap/dist/js/bootstrap.bundle.min.js"></script>
# <script src="https://www.tutorialspoint.com/theme/js/localization.js?v=2.21"></script>
# <script src="static/vendor/tiny-slider/tiny-slider.js"></script>
# <script src="static/vendor/purecounterjs/dist/purecounter_vanilla.js"></script>
# <script src="static/js/functions.js?v=1.11"></script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-232293-6"></script>
# <script>
#    window.dataLayer = window.dataLayer || [];
#    function gtag(){dataLayer.push(arguments);}
#    gtag('js', new Date());
#    gtag('config', 'UA-232293-6');
# </script>
# </body>
# </html>

# %%
soup.title # getting title with tag
# Out:
# <title>Online Tutorials Library</title>

# %%
soup.title.text # getting only title text
# Out:
# 'Online Tutorials Library'

# %%
soup.find('title') # return single tag
# Out:
# <title>Online Tutorials Library</title>

# %%
soup.find_all('title') # return multipul tag
# Out:
# [<title>Online Tutorials Library</title>]

# %%
soup.find('title').string # text / string
# Out:
# 'Online Tutorials Library'

# %%
soup.head  # getting head of the HTML
# Out:
# <head>
# <title>Online Tutorials Library</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="Online Tutorials Library - The Best Content on latest technologies including C, C++, Java, Python, PHP, Machine Learning, Data Science, AppML, AI with Python, Behave, Java16, Spacy." name="Description">
# <meta content="HTML, Python, CSS, SQL, JavaScript, How to, PHP, Java, C++, jQuery, Bootstrap, C#, XML, MySQL, NodeJS, React, Angular, R, AI, Git, Data Science, Code Game, Tutorials, Programming, Web Development, Training, Learning, Quiz, Courses, Lessons, References, Examples, Source code, Demos, Tips" name="Keywords">
# <link href="https://www.tutorialspoint.com" rel="canonical"/>
# <link href="favicon.ico" rel="shortcut icon"/>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://fonts.googleapis.com/css2?family=Heebo:wght@400;500;700&amp;family=Roboto:wght@400;500;700&amp;display=swap" rel="stylesheet"/>
# <link href="static/vendor/font-awesome/css/fontawesome-custom.min.css" rel="stylesheet" type="text/css"/>
# <link href="static/vendor/tiny-slider/tiny-slider.css" rel="stylesheet" type="text/css"/>
# <link href="static/css/style.css" id="style-switch" rel="stylesheet" type="text/css"/>
# <link href="static/css/custom.css" rel="stylesheet" type="text/css"/>
# <script src="/static/js/jquery-3.3.1.min.js"></script>
# <style>
# .lh-7{background-color:#fff!important; min-height:58px; border:2px solid #59bb4d!important;}
# </style>
# </meta></meta></head>

# %%
soup.find_all('head') # return multiple tag
# Out:
# [<head>
#  <title>Online Tutorials Library</title>
#  <meta charset="utf-8"/>
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#  <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#  <meta content="Online Tutorials Library - The Best Content on latest technologies including C, C++, Java, Python, PHP, Machine Learning, Data Science, AppML, AI with Python, Behave, Java16, Spacy." name="Description">
#  <meta content="HTML, Python, CSS, SQL, JavaScript, How to, PHP, Java, C++, jQuery, Bootstrap, C#, XML, MySQL, NodeJS, React, Angular, R, AI, Git, Data Science, Code Game, Tutorials, Programming, Web Development, Training, Learning, Quiz, Courses, Lessons, References, Examples, Source code, Demos, Tips" name="Keywords">
#  <link href="https://www.tutorialspoint.com" rel="canonical"/>
#  <link href="favicon.ico" rel="shortcut icon"/>
#  <link href="https://fonts.googleapis.com" rel="preconnect"/>
#  <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
#  <link href="https://fonts.googleapis.com/css2?family=Heebo:wght@400;500;700&amp;family=Roboto:wght@400;500;700&amp;display=swap" rel="stylesheet"/>
#  <link href="static/vendor/font-awesome/css/fontawesome-custom.min.css" rel="stylesheet" type="text/css"/>
#  <link href="static/vendor/tiny-slider/tiny-slider.css" rel="stylesheet" type="text/css"/>
#  <link href="static/css/style.css" id="style-switch" rel="stylesheet" type="text/css"/>
#  <link href="static/css/custom.css" rel="stylesheet" type="text/css"/>
#  <script src="/static/js/jquery-3.3.1.min.js"></script>
#  <style>
#  .lh-7{background-color:#fff!important; min-height:58px; border:2px solid #59bb4d!important;}
#  </style>
#  </meta></meta></head>]

# %%
soup.body   # getting body of the HTML
# Out:
# <body>
# <!-- Top header START -->
# <div class="navbar-top navbar-dark bg-light d-xl-block py-2 mx-2 mx-md-4 rounded-bottom-4">
# <div class="container-fluid px-3 px-xl-3">
# <div class="d-lg-flex justify-content-lg-between align-items-center top-nav-links">
# <!-- Top info -->
# <ul class="nav align-items-center justify-content-center">
# <li class="nav-item" data-bs-animation="false" data-bs-original-title="Home Page" data-bs-placement="bottom" data-bs-toggle="tooltip">
# <a class="nav-link" href="https://www.tutorialspoint.com/index.htm"><i class="fal fa-home me-1"></i> Home</a>
# </li>
# <li class="nav-item" data-bs-animation="false" data-bs-original-title="Online Coding System" data-bs-placement="bottom" data-bs-toggle="tooltip">
# <a class="nav-link" href="https://www.tutorialspoint.com/codingground.htm"><i class="fal fa-code me-1"></i> Coding Ground</a>
# </li>
# <li class="nav-item" data-bs-animation="false" data-bs-original-title="Questions &amp; Answers" data-bs-placement="bottom" data-bs-toggle="tooltip">
# <span><a class="nav-link" href="https://www.tutorialspoint.com/questions/index.php"><i class="fal fa-comments-alt me-1"></i> Q/A</a></span>
# </li>
# <li class="nav-item" data-bs-animation="false" data-bs-original-title="Job Openings" data-bs-placement="bottom" data-bs-toggle="tooltip">
# <span><a class="nav-link" href="https://www.tutorialspoint.com/about/about_careers.htm"><i class="fal fa-suitcase me-1"></i> Jobs</a></span>
# </li>
# <li class="nav-item" data-bs-animation="false" data-bs-original-title="Digital Whiteboard" data-bs-placement="bottom" data-bs-toggle="tooltip">
# <span><a class="nav-link" href="https://www.tutorialspoint.com/whiteboard.htm"><i class="fal fa-chalkboard me-1"></i> Whiteboard</a></span>
# </li>
# <li class="nav-item" data-bs-animation="false" data-bs-original-title="Developer's Tools" data-bs-placement="bottom" data-bs-toggle="tooltip">
# <span><a class="nav-link" href="https://www.tutorialspoint.com/online_dev_tools.htm"><i class="fal fa-screwdriver-wrench me-1"></i> Tools</a></span>
# </li>
# <li class="nav-item" data-bs-animation="false" data-bs-original-title="Corporate Trainings" data-bs-placement="bottom" data-bs-toggle="tooltip">
# <span><a class="nav-link" href="https://www.tutorialspoint.com/business/index.asp"><i class="fal fa-analytics me-1"></i> Business</a></span>
# </li>
# </ul>
# <div class="d-flex align-items-center justify-content-center">
# <div class="navbar-nav ms-2">
# <div class="modeswitch-wrap" id="darkModeSwitch">
# <div class="modeswitch-item">
# <div class="modeswitch-icon"></div>
# </div>
# </div>
# </div>
# <!-- teach with us -->
# <div class="me-3c top-nav-social">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/market/teach_with_us.jsp" target="_blank"><i class="fal fa-screen-users me-2"></i> Teach with us</a>
# </div>
# <!-- Top social -->
# <ul class="list-unstyled d-flex mb-0 top-nav-social">
# <li><a class="px-2 nav-link" href="https://www.facebook.com/tutorialspointindia" rel="nofollow" target="_blank"><i class="fab fa-facebook"></i></a> </li>
# <li><a class="px-2 nav-link" href="https://www.instagram.com/tutorialspoint_/" rel="nofollow" target="_blank"><i class="fab fa-instagram"></i></a> </li>
# <li><a class="px-2 nav-link" href="https://twitter.com/tutorialspoint" rel="nofollow" target="_blank"><i class="fab fa-twitter"></i></a> </li>
# <li><a class="px-2 nav-link" href="https://www.youtube.com/channel/UCVLbzhxVTiTLiVKeGV7WEBg" rel="nofollow" target="_blank"><i class="fab fa-youtube"></i></a> </li>
# <li> <a class="px-2 nav-link" href="https://www.linkedin.com/authwall?trk=bf&amp;trkInfo=AQEkqX2eckF__gAAAX-wMwEYvrsjBVbEtWQd4pgEdVSzkL22Nik1KEpY_ECWLKDGc41z8IOZWr2Bb0fvJplT60NPBtSw87J6QCpc7wD4qQ3iU13n6xJtBxME5o05Wmpg5JPm5YY=&amp;originalReferer=&amp;sessionRedirect=https%3A%2F%2Fwww.linkedin.com%2Fcompany%2Ftutorialspoint" rel="nofollow" target="_blank"><i class="fab fa-linkedin-in"></i></a> </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <!-- Top header END -->
# <!-- Header START -->
# <header class="navbar-light navbar-sticky header-static">
# <!-- Logo Nav START -->
# <nav class="navbar navbar-expand-xl">
# <div class="container-fluid px-3 px-xl-5">
# <!-- Logo START -->
# <a class="navbar-brand" href="index.htm">
# <img alt="logo" class="light-mode-item navbar-brand-item" src="/images/logo.png"/>
# <img alt="logo" class="dark-mode-item navbar-brand-item" src="/images/logo-w.png"/>
# </a>
# <button aria-controls="navbarCollapse" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler ms-auto" data-bs-target="#navbarCollapse" data-bs-toggle="collapse" type="button">
# <span class="navbar-toggler-animation">
# <span></span>
# <span></span>
# <span></span>
# </span>
# </button>
# <div class="navbar-collapse w-100 collapse" id="navbarCollapse">
# <ul class="navbar-nav navbar-nav-scroll me-auto">
# <li class="nav-item dropdown dropdown-menu-shadow-stacked">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" data-bs-toggle="dropdown" href="#" id="categoryMenu"><i class="fal fa-th me-3 fs-5 me-xl-1 d-xl-none"></i> <i class="fal fa-th me-1 d-none d-xl-inline-block"></i><span class="d-xl-inline-block dropdown-toggle">Category</span></a>
# <ul aria-labelledby="categoryMenu" class="dropdown-menu">
# <li> <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/development"><i class="fa fa-cogs cat-icons"></i> Development</a></li>
# <li> <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/it_and_software"><i class="fa fa-tv cat-icons"></i>  IT and Networking</a></li>
# <li> <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/data_science_and_ai_ml"><i class="fa fa-head-side-brain cat-icons"></i> Data Science and AI ML</a></li>
# <li> <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/cyber_security"><i class="fa fa-camera-home cat-icons"></i> Cyber Security</a></li>
# <li> <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/marketing"><i class="fa fa-bullseye-arrow cat-icons"></i> Marketing</a></li>
# <li> <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/office_productivity"><i class="fa fa-camera-home cat-icons"></i> Office Productivity</a></li>
# <li> <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/business"><i class="fa fa-chart-bar cat-icons"></i> Business</a></li>
# <li> <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/lifestyle"><i class="fa fa-person-dolly-empty cat-icons"></i> Lifestyle</a></li>
# </ul>
# </li>
# </ul>
# <!-- Nav category menu END -->
# <!-- Main navbar START -->
# <div class="navbar-collapse collapse" id="navbarCollapse">
# <!-- Nav Search START -->
# <div class="col-xl-4"></div>
# <!-- Nav Search END -->
# </div>
# <!-- Main navbar END -->
# <!-- Nav Main menu START -->
# <ul class="navbar-nav navbar-nav-scroll me-auto">
# <li class="nav-item">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/latest/prime-packs" target="_self"><i class="fal fa-cubes me-1"></i> Prime Packs</a>
# </li>
# <li class="nav-item">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/market/index.asp" target="_self"><i class="fal fa-circle-play me-1"></i> Courses</a>
# </li>
# <li class="nav-item">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/latest/ebooks" target="_self"><i class="fal fa-book-reader me-1"></i> eBooks</a>
# </li>
# <li class="nav-item">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/tutorialslibrary.htm" target="_self"><i class="fal fa-books me-1"></i> Library</a>
# </li>
# </ul>
# <!-- Nav Main menu END -->
# </div>
# <!-- Main navbar END -->
# <!-- Signin START -->
# <div class="navbar-nav d-lg-inline-block">
# <a href="https://www.tutorialspoint.com/market/login.asp" target="_self"><button class="btn btn-grey-border mb-0"><i class="fal fa-sign-in-alt me-2"></i> Login</button></a>
# </div>
# <!-- Signin END -->
# </div>
# </nav>
# <!-- Logo Nav END -->
# </header>
# <!-- Header END -->
# <!-- **************** MAIN CONTENT START **************** -->
# <main>
# <!-- ======================= Main Banner START -->
# <section class="position-relative overflow-hidden pt-5 pt-lg-3">
# <!-- SVG START -->
# <figure class="position-absolute top-50 start-0 translate-middle-y ms-n7 d-none d-xxl-block">
# <svg class="rotate-74 fill-green opacity-1">
# <circle cx="180.4" cy="15.5" r="7.7"></circle>
# <path d="m159.9 22.4c-3.8 0-6.9-3.1-6.9-6.9s3.1-6.9 6.9-6.9 6.9 3.1 6.9 6.9-3.1 6.9-6.9 6.9z"></path>
# <ellipse cx="139.4" cy="15.5" rx="6.1" ry="6.1" transform="matrix(.3862 -.9224 .9224 .3862 71.25 138.08)"></ellipse>
# <circle cx="118.9" cy="15.5" r="5.4"></circle>
# <path d="m98.4 20.1c-2.5 0-4.6-2.1-4.6-4.6s2.1-4.6 4.6-4.6 4.6 2.1 4.6 4.6-2.1 4.6-4.6 4.6z"></path>
# <path d="m77.9 19.3c-2.1 0-3.8-1.7-3.8-3.8s1.7-3.8 3.8-3.8 3.8 1.7 3.8 3.8-1.7 3.8-3.8 3.8z"></path>
# <path d="m57.3 18.6c-1.7 0-3.1-1.4-3.1-3.1s1.4-3.1 3.1-3.1 3.1 1.4 3.1 3.1-1.4 3.1-3.1 3.1z"></path>
# <path d="m36.8 17.8c-1.3 0-2.3-1-2.3-2.3s1-2.3 2.3-2.3 2.3 1 2.3 2.3-1 2.3-2.3 2.3z"></path>
# <circle cx="16.3" cy="15.5" r="1.6"></circle>
# <circle cx="180.4" cy="38.5" r="7.7"></circle>
# <ellipse cx="139.4" cy="153.2" rx="6.1" ry="6.1" transform="matrix(.3862 -.9224 .9224 .3862 -55.794 222.61)"></ellipse>
# <circle cx="118.9" cy="153.2" r="5.4"></circle>
# <path d="m98.4 157.8c-2.5 0-4.6-2.1-4.6-4.6s2.1-4.6 4.6-4.6 4.6 2.1 4.6 4.6c0 2.6-2.1 4.6-4.6 4.6z"></path>
# <circle cx="77.9" cy="153.2" r="3.8"></circle>
# <path d="m57.3 156.3c-1.7 0-3.1-1.4-3.1-3.1s1.4-3.1 3.1-3.1 3.1 1.4 3.1 3.1-1.4 3.1-3.1 3.1z"></path>
# <path d="m36.8 155.5c-1.3 0-2.3-1-2.3-2.3s1-2.3 2.3-2.3 2.3 1 2.3 2.3-1 2.3-2.3 2.3z"></path>
# <circle cx="16.3" cy="153.2" r="1.6"></circle>
# <circle cx="180.4" cy="176.2" r="7.7"></circle>
# <path d="m159.9 183.1c-3.8 0-6.9-3.1-6.9-6.9s3.1-6.9 6.9-6.9 6.9 3.1 6.9 6.9-3.1 6.9-6.9 6.9z"></path>
# <ellipse cx="139.4" cy="176.2" rx="6.1" ry="6.1" transform="matrix(.3862 -.9224 .9224 .3862 -76.968 236.7)"></ellipse>
# <circle cx="118.9" cy="176.2" r="5.4"></circle>
# <path d="m98.4 180.8c-2.5 0-4.6-2.1-4.6-4.6s2.1-4.6 4.6-4.6 4.6 2.1 4.6 4.6-2.1 4.6-4.6 4.6z"></path>
# <path d="m77.9 180c-2.1 0-3.8-1.7-3.8-3.8s1.7-3.8 3.8-3.8 3.8 1.7 3.8 3.8-1.7 3.8-3.8 3.8z"></path>
# <path d="m57.3 179.3c-1.7 0-3.1-1.4-3.1-3.1s1.4-3.1 3.1-3.1 3.1 1.4 3.1 3.1-1.4 3.1-3.1 3.1z"></path>
# <path d="m36.8 178.5c-1.3 0-2.3-1-2.3-2.3s1-2.3 2.3-2.3 2.3 1 2.3 2.3-1 2.3-2.3 2.3z"></path>
# <circle cx="16.3" cy="176.2" r="1.6"></circle>
# </svg>
# </figure>
# <!-- SVG END -->
# <!-- SVG START -->
# <span class="position-absolute top-50 end-0 translate-middle-y mt-5 me-n5 d-none d-xxl-inline-flex">
# <svg class="fill-green rotate-186 opacity-8">
# <path d="m35.4 54.2c0 0.6 0 1.1-0.1 1.7-0.9 9.3-9.2 16.1-18.5 15.1-4.5-0.4-8.5-2.6-11.4-6.1-2.8-3.5-4.2-7.9-3.7-12.4 0.9-9.3 9.2-16.1 18.5-15.1 4.5 0.4 8.5 2.6 11.4 6.1 2.4 3 3.8 6.8 3.8 10.7zm-33.4 0c0 3.8 1.3 7.5 3.8 10.4 2.8 3.4 6.8 5.5 11.2 6 9.1 0.9 17.2-5.8 18.1-14.8 0.4-4.4-0.9-8.7-3.7-12.1s-6.8-5.5-11.2-6c-9.2-0.8-17.3 5.8-18.2 14.9v1.6z"></path>
# <path d="m113.9 54.2c0 12.3-4.7 24-13.4 32.8-18.1 18.5-47.9 18.9-66.4 0.8-9-8.8-14-20.5-14.1-33-0.2-12.5 4.6-24.4 13.4-33.4 18.1-18.6 47.9-18.9 66.4-0.8l-0.1 0.1 0.1-0.1c9 8.8 14 20.5 14.1 33v0.6zm-93.6 0v0.5c0.1 12.4 5.1 24.1 14 32.8 18.4 18 48 17.6 65.9-0.7 8.7-8.9 13.4-20.7 13.3-33.1s-5.1-24.1-14-32.8c-18.4-18-48-17.6-65.9 0.7-8.6 8.8-13.3 20.3-13.3 32.6z"></path>
# <path d="m118.3 54.2c0 13-5.1 25.3-14.3 34.5-19 19-50 19-69 0-9.2-9.2-14.3-21.4-14.3-34.5 0-13 5.1-25.3 14.3-34.5 19-19 50-19 69 0l-0.1 0.1 0.1-0.1c9.2 9.2 14.3 21.5 14.3 34.5zm-97.2 0c0 12.9 5 25.1 14.2 34.2 18.9 18.9 49.6 18.9 68.4 0 9.1-9.1 14.2-21.3 14.2-34.2s-5-25.1-14.2-34.2c-18.8-18.9-49.5-18.9-68.4 0-9.2 9.1-14.2 21.3-14.2 34.2z"></path>
# </svg>
# </span>
# <!-- SVG END -->
# <!-- SVG START -->
# <figure class="position-absolute top-0 start-50 ms-5">
# <svg class="fill-orange opacity-4" height="29px" width="29px">
# <path d="M29.004,14.502 C29.004,22.512 22.511,29.004 14.502,29.004 C6.492,29.004 -0.001,22.512 -0.001,14.502 C-0.001,6.492 6.492,-0.001 14.502,-0.001 C22.511,-0.001 29.004,6.492 29.004,14.502 Z"></path>
# </svg>
# </figure>
# <!-- SVG END -->
# <!-- Content START -->
# <div class="container">
# <div class="row align-items-center g-5">
# <div class="col-lg-5 col-xl-6 position-relative z-index-1 text-center text-lg-start mt-n7">
# <figure class="fill-info position-absolute bottom-0 end-0 me-5 d-none d-xl-block">
# <svg height="42px" width="42px">
# <path d="M21.000,-0.001 L28.424,13.575 L41.999,20.999 L28.424,28.424 L21.000,41.998 L13.575,28.424 L-0.000,20.999 L13.575,13.575 L21.000,-0.001 Z"></path>
# </svg>
# </figure>
# <figure class="fill-success position-absolute top-0 start-50 translate-middle-x mt-6 ms-5">
# <svg height="21px" width="22px">
# <path d="M10.717,4.757 L14.440,-0.001 L14.215,6.023 L20.142,4.757 L16.076,9.228 L21.435,12.046 L15.430,12.873 L17.713,18.457 L12.579,15.252 L10.717,20.988 L8.856,15.252 L3.722,18.457 L6.005,12.873 L-0.000,12.046 L5.359,9.228 L1.292,4.757 L7.220,6.023 L6.995,-0.001 L10.717,4.757 Z"></path>
# </svg>
# </figure>
# <h1 class="mb-0 display-6 mb-4 mt-8">Simply Easy Learning at your
# 					<span class="position-relative">fingertips
# 						<span class="position-absolute top-50 start-50 translate-middle ms-3 z-index-n1">
# <svg enable-background="new 0 0 366 62.1" height="62.1px" viewbox="0 0 366 62.1" width="300px" xmlns="http://www.w3.org/2000/svg">
 1.5 11.1 1.2 4-0.3 7.7 0.6 11.6 1.1 0.8 0.1 2.2 0.3 2.3 1.1 0.2 1-1.1 1.2-2 1.5-3.4 1-6.7-0.4-10.1-0.4-0.9 0-2-0.2-2.9-0.2-9.4 0.1-18.8-1.3-28.3-1.8-6-0.4-12.1-0.9-18.1-1.3 0 0.2 0 0.4-0.2 0.6 6.1 0.5 12.1 1.4 18.3 0.7z"></path>
# </svg>
# </span>
# <!-- SVG END -->
# </span>
# </h1>
# <div class="nav-item w-100 mb-4">
# <form class="rounded position-relative">
# <input aria-label="Search" class="form-control pe-4 bg-secondary bg-opacity-10 border-0 search-strings lh-7" data-result="search-results" id="search-strings" name="key" placeholder="Search courses, ebooks and prime packs" type="search"/>
# <button class="btn bg-transparent px-2 py-0 position-absolute top-50 end-0 translate-middle-y" id="btnSearch" type="submit"><i class="fal fa-search fs-5 me-3"></i></button>
# <div class="search-box" id="search-results"></div>
# <div class="clear"></div>
# </form>
# </div>
# <ul class="list-inline position-relative justify-content-center justify-content-lg-start mb-5 mt-2">
# <li class="list-inline-item me-3 fs-5"><a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/latest/prime-packs" target="_self"><i class="fal fa-cubes me-1"></i> Prime Packs</a></li>
# <li class="list-inline-item me-3 fs-5"><a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/market/index.asp" target="_self"><i class="fal fa-circle-play me-1"></i> Courses</a></li>
# <li class="list-inline-item me-3 fs-5"><a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/latest/ebooks" target="_self"><i class="fal fa-book-reader me-1"></i> eBooks</a></li>
# <li class="list-inline-item me-3 fs-5"><a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/tutorialslibrary.htm" target="_self"><i class="fal fa-books me-1"></i> Library</a></li>
# </ul>
# <div class="">
# <a class="btn btn-lg btn-green-hard me-2 mb-4 mb-sm-0" href="https://www.tutorialspoint.com/codingground.htm"><i class="fal fa-code me-1"></i> Coding Ground</a>
# <a class="ms-0 ms-sm-4" data-gallery="office-tour" data-glightbox="" href="https://www.tutorialspoint.com/market/index.asp">
# <div class="btn btn-round btn-black-shadow mb-0 me-3 align-middle"> <i class="fal fa-play"></i></div>
# <div class="align-middle d-inline-block">
# <h6 class="mb-0 fw-normal">Watch Demo Video</h6>
# </div>
# </a>
# </div>
# </div>
# <div class="col-lg-7 col-xl-6 text-center position-relative">
# <figure class="position-absolute bottom-0 start-50 translate-middle-x mt-4 mb-0">
# <svg height="538px" style="enable-background:new 0 0 554 544;" viewbox="0 0 554 544" width="550px" xml:space="preserve">
# <path class="fill-primary" d="M423.3,77.2c49.5,32.5,100.4,67.2,118.4,114.5s3.5,107.1-15.4,165.7c-18.7,58.6-41.8,116.1-84,148.6 c-42.5,32.8-104.2,40.2-163.8,37.3c-59.5-3.2-116.8-17.1-164.7-47.9c-48.3-30.6-87.2-78.2-102-131.6C-3,310.5,6.6,251,25.3,194.7 C43.6,138,70.7,84.3,114.1,49.5C157.2,14.8,216.7-1,270.8,6.4C324.8,14.2,373.4,44.7,423.3,77.2z"></path>
# <path d="m52.1 19.7 0.3-0.3c-0.1 0 0 0 0 0 0.1-0.1 0.3-0.2 0.4-0.3l0.9-0.6c0.6-0.4 1.2-0.8 1.8-1.1 0.3-0.2 0.4-0.6 0.2-0.9s-0.6-0.4-0.9-0.2c-1.3 0.7-2.6 1.5-3.7 2.5-0.3 0.2-0.2 0.7 0 0.9 0.4 0.3 0.7 0.3 1 0z"></path>
# <path d="m20.2 49.3c-0.1 0 0 0 0 0 0.1 0.2 0.1 0.3 0.1 0.4 0.1 0.3 0.2 0.6 0.4 0.9 0.3 0.7 0.5 1.5 0.7 2.3s0.2 1.7 0.3 2.5c0.1 0.7 0.1 1.6 0.5 2.2 0.4 0.7 1.6 0.1 1.1-0.7-0.2-0.3-0.2-0.6-0.2-1 0-0.5-0.1-0.9-0.1-1.4-0.1-0.9-0.2-1.8-0.4-2.7-0.2-0.8-0.5-1.5-0.8-2.3-0.2-0.5-0.3-1.2-0.8-1.4-0.3-0.1-0.7-0.1-0.9 0.2-0.3 0.4-0.3 0.9 0.1 1z"></path>
# </svg>
# </figure>
# <div class="p-2 bg-white shadow rounded-3 position-absolute top-50 start-0 translate-middle-y mt-n7 d-none d-sm-block">
# <img alt="Icon" src="static/images/client/science.svg"/>
# </div>
# <div class="p-2 bg-white shadow rounded-3 position-absolute top-0 end-0 me-5">
# <img alt="Icon" src="static/images/client/angular.svg"/>
# </div>
# <div class="p-2 bg-white shadow rounded-3 position-absolute top-50 end-0 translate-middle-y mt-5 ms-5 d-none d-lg-block z-index-9">
# <img alt="Icon" src="static/images/client/figma.svg"/>
# </div>
# <div class="p-3 bg-blur border border-light shadow rounded-4 position-absolute bottom-0 start-0 z-index-9 d-none d-xl-block mb-5 ms-5">
# <div class="d-flex justify-content-between align-items-center">
# <span class="icon-lg bg-warning rounded-circle"><i class="fal fa-envelope text-white"></i></span>
# </div>
# </div>
# <div class="position-relative">
# <img alt="" src="static/images/banner-img.png"/>
# </div>
# </div>
# <!-- Right content END -->
# </div>
# </div>
# <!-- Content END -->
# </section>
# <!-- ======================= Main Banner END -->
# <!-- ======================= Counter START -->
# <section class="py-0 pb-5 pt-0 pt-lg-5">
# <div class="container">
# <div class="tiny-slider arrow-round arrow-blur arrow-hover">
# <div class="tiny-slider-inner row g-4" data-arrow="true" data-autoplay="false" data-dots="false" data-gutter="20" data-items="4" data-items-lg="3" data-items-md="2" data-items-xs="1">
# <!-- Counter item -->
# <div class="col-sm-6 col-xl-3">
# <div class="d-flex justify-content-center align-items-center p-4 bg-warning bg-opacity-15 rounded-3">
# <span class="display-6 lh-1 text-warning mb-0"><i class="fal fa-laptop"></i></span>
# <div class="ms-4 h6 fw-normal">
# <div class="d-flex">
# <h5 class="purecounter mb-0 fw-bold" data-purecounter-delay="200" data-purecounter-end="5000" data-purecounter-start="0">0</h5>
# <span class="mb-0 h5">+</span>
# </div>
# <p class="mb-0">Premium Courses</p>
# </div>
# </div>
# </div>
# <!-- Counter item -->
# <div class="col-sm-6 col-xl-3">
# <div class="d-flex justify-content-center align-items-center p-4 bg-blue bg-opacity-10 rounded-3">
# <span class="display-6 lh-1 text-blue mb-0"><i class="fal fa-user-tie"></i></span>
# <div class="ms-4 h6 fw-normal">
# <div class="d-flex">
# <h5 class="purecounter mb-0 fw-bold" data-purecounter-delay="200" data-purecounter-end="1000" data-purecounter-start="0">0</h5>
# <span class="mb-0 h5">+</span>
# </div>
# <p class="mb-0">Expert Tutors</p>
# </div>
# </div>
# </div>
# <!-- Counter item -->
# <div class="col-sm-6 col-xl-3">
# <div class="d-flex justify-content-center align-items-center p-4 bg-purple bg-opacity-10 rounded-3">
# <span class="display-6 lh-1 text-purple mb-0"><i class="fal fa-user-graduate"></i></span>
# <div class="ms-4 h6 fw-normal">
# <div class="d-flex">
# <h5 class="purecounter mb-0 fw-bold" data-purecounter-delay="200" data-purecounter-end="30" data-purecounter-start="0">0</h5>
# <span class="mb-0 h5">M+</span>
# </div>
# <p class="mb-0">Online Students</p>
# </div>
# </div>
# </div>
# <!-- Counter item -->
# <div class="col-sm-6 col-xl-3">
# <div class="d-flex justify-content-center align-items-center p-4 bg-info bg-opacity-10 rounded-3">
# <span class="display-6 lh-1 text-info mb-0"><i class="fal fa-certificate"></i></span>
# <div class="ms-4 h6 fw-normal">
# <div class="d-flex">
# <h5 class="purecounter mb-0 fw-bold" data-purecounter-delay="300" data-purecounter-end="50" data-purecounter-start="0">0</h5>
# <span class="mb-0 h5">K+</span>
# </div>
# <p class="mb-0">Certificates Delivered</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!-- ======================= Counter END -->
# <!-- ======================= Listed course START -->
# <section class="position-relative pb-5 pt-0 pt-lg-5">
# <div class="container">
# <!-- Title -->
# <div class="row mb-4">
# <div class="col-lg-8 mx-auto text-center">
# <h2 class="fs-1"><i class="fal fa-grid me-3"></i>Top <span class="text-green">Categories</span></h2>
# </div>
# </div>
# <div class="tiny-slider arrow-round arrow-blur arrow-hover">
# <div class="tiny-slider-inner row g-4" data-arrow="true" data-autoplay="false" data-dots="true" data-gutter="20" data-items="4" data-items-lg="3" data-items-md="2" data-items-xs="1" data-mobile="true">
# <div class="col-sm-6 col-md-4 col-xl-3">
# <div class="bg-primary bg-opacity-10 rounded-3 text-center p-3 position-relative btn-transition">
# <div class="icon-xl bg-body mx-auto rounded-circle mb-3">
# <img src="static/images/development.svg">
# </img></div>
# <h5 class="mb-1"><a class="stretched-link" href="https://www.tutorialspoint.com/categories/development"> Development</a></h5>
# <span class="mb-0">15 Course</span>
# </div>
# </div>
# <div class="col-sm-6 col-md-4 col-xl-3">
# <div class="bg-primary bg-opacity-10 rounded-3 text-center p-3 position-relative btn-transition">
# <div class="icon-xl bg-body mx-auto rounded-circle mb-3">
# <img src="static/images/it-and-networking.svg">
# </img></div>
# <h5 class="mb-1"><a class="stretched-link" href="https://www.tutorialspoint.com/categories/it_and_software">IT and Networking</a></h5>
# <span class="mb-0">22 Course</span>
# </div>
# </div>
# <div class="col-sm-6 col-md-4 col-xl-3">
# <div class="bg-primary bg-opacity-10 rounded-3 text-center p-3 position-relative btn-transition">
# <div class="icon-xl bg-body mx-auto rounded-circle mb-3">
# <img src="static/images/data-science-and-ai-ml.svg">
# </img></div>
# <h5 class="mb-1"><a class="stretched-link" href="https://www.tutorialspoint.com/categories/data_science_and_ai_ml">Data Science and AI ML</a></h5>
# <span class="mb-0">53 Course</span>
# </div>
# </div>
# <div class="col-sm-6 col-md-4 col-xl-3">
# <div class="bg-primary bg-opacity-10 rounded-3 text-center p-3 position-relative btn-transition">
# <div class="icon-xl bg-body mx-auto rounded-circle mb-3">
# <img src="static/images/cyber-security.svg">
# </img></div>
# <h5 class="mb-1"><a class="stretched-link" href="https://www.tutorialspoint.com/categories/cyber_security">Cyber Security</a></h5>
# <span class="mb-0">25 Course</span>
# </div>
# </div>
# <!-- Item -->
# <div class="col-sm-6 col-md-4 col-xl-3">
# <div class="bg-primary bg-opacity-10 rounded-3 text-center p-3 position-relative btn-transition">
# <!-- Image -->
# <div class="icon-xl bg-body mx-auto rounded-circle mb-3">
# <img src="static/images/marketing.svg">
# </img></div>
# <!-- Title -->
# <h5 class="mb-1"><a class="stretched-link" href="https://www.tutorialspoint.com/categories/marketing">Marketing</a></h5>
# <span class="mb-0">30 Course</span>
# </div>
# </div>
# <!-- Item -->
# <div class="col-sm-6 col-md-4 col-xl-3">
# <div class="bg-primary bg-opacity-10 rounded-3 text-center p-3 position-relative btn-transition">
# <!-- Image -->
# <div class="icon-xl bg-body mx-auto rounded-circle mb-3">
# <img src="static/images/office-productivity.svg">
# </img></div>
# <!-- Title -->
# <h5 class="mb-1"><a class="stretched-link" href="https://www.tutorialspoint.com/categories/office_productivity">Office Productivity</a></h5>
# <span class="mb-0">20 Course</span>
# </div>
# </div>
# <!-- Item -->
# <div class="col-sm-6 col-md-4 col-xl-3">
# <div class="bg-primary bg-opacity-10 rounded-3 text-center p-3 position-relative btn-transition">
# <!-- Image -->
# <div class="icon-xl bg-body mx-auto rounded-circle mb-3">
# <img src="static/images/business.svg"/>
# </div>
# <!-- Title -->
# <h5 class="mb-1"><a class="stretched-link" href="https://www.tutorialspoint.com/categories/business">Business</a></h5>
# <span class="mb-0">10 Course</span>
# </div>
# </div>
# <!-- Item -->
# <div class="col-sm-6 col-md-4 col-xl-3">
# <div class="bg-primary bg-opacity-10 rounded-3 text-center p-3 position-relative btn-transition">
# <!-- Image -->
# <div class="icon-xl bg-body mx-auto rounded-circle mb-3">
# <img src="static/images/lifestyle.svg"/>
# </div>
# <!-- Title -->
# <h5 class="mb-1"><a class="stretched-link" href="https://www.tutorialspoint.com/categories/lifestyle">Lifestyle</a></h5>
# <span class="mb-0">30 Course</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!-- ======================= Listed course END -->
# <!-- ======================= Prime Packs START -->
# <section class="pb-5 pt-0 pt-lg-5">
# <div class="container">
# <!-- Title -->
# <div class="row mb-4">
# <div class="col-lg-8 mx-auto text-center">
# <h2 class="fs-1"><i class="fal fa-cubes me-3"></i>Premium <span class="text-green">Packs</span></h2>
# <p class="mb-0">Curated courses packed together from expert tutors</p>
# </div>
# </div>
# <div class="row">
# <!-- Slider START -->
# <div class="tiny-slider arrow-round arrow-blur arrow-hover">
# <div class="tiny-slider-inner pb-1" data-arrow="true" data-autoplay="false" data-dots="false" data-edge="2" data-items="4" data-items-lg="2" data-items-sm="1">
# <div class="col-sm-6 col-lg-4 col-xl-3">
# <div class="card shadow-hover h-100 border">
# ...
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/database_tutorials.htm">View more<i class="fal fa-sync ms-2"></i></a>
# </div>
# </div>
# </div>
# <div class="col-sm-12 col-lg-6 col-xl-6">
# <div class="card card-body shadow rounded-3 grey-box">
# <div class="row">
# <h5 class="card-title pb-2 mb-4 ps-1"><i class="fab fa-windows icon-md text-dark mb-0 bg-grey rounded-3 me-2"></i>Microsoft Technologies</h5>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <div class="asp-net">
# <a href="https://www.tutorialspoint.com/asp.net/index.htm" target="_blank" title="ASP.NET Tutorial">
# <div class="image-title white-title">ASP.NET</div>
# </a>
# </div>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <div class="entity-framework">
# <a href="https://www.tutorialspoint.com/entity_framework/index.htm" target="_blank" title="Entity Framework Tutorial">
# <div class="image-title white-title">Entity Framework</div>
# </a>
# </div>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <div class="vb-net">
# <a href="https://www.tutorialspoint.com/vb.net/index.htm" target="_blank" title="VB.NET Tutorial">
# <div class="image-title white-title">VB.NET Tutorial</div>
# </a>
# </div>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <div class="microsoft-project">
# <a href="https://www.tutorialspoint.com/ms_project/index.htm" target="_blank" title="Microsoft Project Tutorial">
# <div class="image-title white-title">Microsoft Project</div>
# </a>
# </div>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <div class="microsoft-excel">
# <a href="https://www.tutorialspoint.com/excel/index.htm" target="_blank" title="Microsoft Excel Tutorial">
# <div class="image-title white-title">Microsoft Excel</div>
# </a>
# </div>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <div class="microsoft-word">
# <a href="https://www.tutorialspoint.com/word/index.htm" target="_blank" title="Microsoft Word Tutorial">
# <div class="image-title white-title">Microsoft Word</div>
# </a>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# <div class="text-end mt-2 pt-2">
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/microsoft_technologies_tutorials.htm">View more<i class="fal fa-sync ms-2"></i></a>
# </div>
# </div>
# </div>
# <div class="col-sm-12 col-lg-6 col-xl-6">
# <div class="card card-body shadow rounded-3 grey-box">
# <div class="row">
# <h5 class="card-title pb-2 mb-4 ps-1"><i class="fal fa-chart-pie icon-md text-dark mb-0 bg-grey rounded-3 me-2"></i>Big Data and Analytics</h5>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <div class="big-data-analytics">
# <a href="https://www.tutorialspoint.com/big_data_analytics/index.htm" target="_blank" title="Big Data Analytics Tutorial">
# <div class="image-title white-title">Big Data Analytics</div>
# </a>
# </div>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <div class="hadoop">
# <a href="https://www.tutorialspoint.com/hadoop/index.htm" target="_blank" title="Hadoop Tutorial">
# <div class="image-title white-title">Hadoop Tutorial</div>
# </a>
# </div>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <div class="sas">
# <a href="https://www.tutorialspoint.com/sas/index.htm" target="_blank" title="SAS Tutorial">
# <div class="image-title white-title">SAS Tutorial</div>
# </a>
# </div>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <div class="qlikview">
# <a href="https://www.tutorialspoint.com/qlikview/index.htm" target="_blank" title="QlikView Tutorial">
# <div class="image-title white-title">QlikView Tutorial</div>
# </a>
# </div>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <div class="powerbi">
# <a href="https://www.tutorialspoint.com/power_bi/index.htm" target="_blank" title="Power BI Tutorial">
# <div class="image-title white-title">Power BI Tutorial</div>
# </a>
# </div>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <div class="tableau">
# <a href="https://www.tutorialspoint.com/tableau/index.htm" target="_blank" title="Tableau Tutorial">
# <div class="image-title white-title">Tableau Tutorial</div>
# </a>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# <div class="text-end mt-2 pt-2">
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/big_data_tutorials.htm">View more<i class="fal fa-sync ms-2"></i></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!-- =======================
# Tutorials END -->
# <!-- =======================
# Become an Instructor START -->
# <section class="py-4">
# <div class="container">
# <div class="row g-4">
# <!-- Action box item -->
# <div class="col-lg-6 position-relative overflow-hidden">
# <div class="bg-primary bg-opacity-10 rounded-3 p-5 h-100">
# <!-- Image -->
# <div class="position-absolute bottom-0 end-0 me-3">
# <img alt="" class="h-100px h-sm-200px" src="static/images/element/08.svg"/>
# </div>
# <!-- Content -->
# <div class="row">
# <div class="col-sm-8 position-relative">
# <h3 class="mb-1">Become an Instructor!</h3>
# <p class="mb-3 h5 fw-light lead">Join one of the world’s largest online learning marketplaces.</p>
# <a class="btn btn-primary mb-0" href="https://www.tutorialspoint.com/market/teach_with_us.jsp" target="_blank">Start Now</a>
# </div>
# </div>
# </div>
# </div>
# <!-- Action box item -->
# <div class="col-lg-6 position-relative overflow-hidden">
# <div class="bg-secondary rounded-3 bg-opacity-10 p-5 h-100">
# <!-- Image -->
# <div class="position-absolute bottom-0 end-0 me-3">
# <img alt="" class="h-100px h-sm-200px" src="static/images/element/15.svg"/>
# </div>
# <!-- Content -->
# <div class="row">
# <div class="col-sm-8 position-relative">
# <h3 class="mb-1">Best Rated Courses</h3>
# <p class="mb-3 h5 fw-light lead">Enroll now in the most popular and best rated courses.</p>
# <a class="btn btn-warning mb-0" href="https://www.tutorialspoint.com/bestseller/courses" target="_blank">View Courses</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!-- ======================= Become an Instructor END -->
# <!-- ======================= Selected reading START -->
# <section class="py-4">
# <div class="container">
# <div class="col-sm-12 col-lg-12 col-xl-12">
# <div class="card card-body special-reading-box">
# <div class="row">
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <a class="nav-link" href="https://www.tutorialspoint.com/developers_best_practices/index.htm" title="Developer's Best Practices">
# <i class="fal fa-display-code fa-3x w-lg-80px w-sm-50px mb-3"></i>
# <p class="text-secondary">Developers <br/><b>Best Practices</b></p>
# </a>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <a class="nav-link" href="https://www.tutorialspoint.com/effective_resume_writing.htm" title="Effective Resume Writing">
# <i class="fal fa-pen-field fa-3x w-lg-80px w-sm-50px mb-3"></i>
# <p class="text-secondary">Effective <br/><b>Resume Writing</b></p>
# </a>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <a class="nav-link" href="https://www.tutorialspoint.com/computer_glossary.htm" title="Computer Glossary">
# <i class="fal fa-notebook fa-3x w-lg-80px w-sm-50px mb-3"></i>
# <p class="text-secondary">Computer <br/><b>Glossary</b></p>
# </a>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <a class="nav-link" href="https://www.tutorialspoint.com/computer_whoiswho.htm" title="Who is Who in Computer Science">
# <i class="fal fa-users fa-3x w-lg-80px w-sm-50px mb-3"></i>
# <p class="text-secondary">Who is Who <br/><b>in Computer</b></p>
# </a>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <a class="nav-link" href="https://www.tutorialspoint.com/questions_and_answers.htm" title="Technical Questions and Answers">
# <i class="fal fa-comments-question-check fa-3x w-lg-80px w-sm-50px mb-3"></i>
# <p class="text-secondary">Technical <br/><b>Q &amp; A</b></p>
# </a>
# </div>
# <div class="col-6 col-sm-2 col-md-2 col-lg-2 col-xxl-2 col-xl-2 px-1 text-center">
# <a class="nav-link" href="https://www.tutorialspoint.com/multi_language_tutorials.htm" title="Multi-Lingual Tutorials">
# <i class="fal fa-globe fa-3x w-lg-80px w-sm-50px mb-3"></i>
# <p class="text-secondary">Multi-Lingual <br/><b>Tutorials</b></p>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!-- ======================= Selected Reading END -->
# </main>
# <!-- **************** MAIN CONTENT END **************** -->
# <!-- ======================= Footer START -->
# <footer class="pt-5 bg-light">
# <div class="container">
# <!-- Row START -->
# <div class="row g-4">
# <!-- Widget 1 START -->
# <div class="col-lg-3">
# <!-- logo -->
# <a class="me-0" href="index.htm">
# <img alt="Tutorials Point" class="light-mode-item h-60px" src="/images/logo.png"/>
# <img alt="Tutorials Point" class="dark-mode-item h-60px" src="/images/logo-white.png"/>
# </a>
# <p class="my-3">Tutorials Point is a leading Ed Tech company striving to provide the best learning material on technical and non-technical subjects.</p>
# <div class="row g-2 mt-2">
# <!-- Google play store button -->
# <div class="col-6 col-sm-4 col-md-3 col-lg-6">
# <a href="https://play.google.com/store/apps/details?id=com.tutorialspoint.onlineviewer" target="_blank"><img alt="" src="static/images/client/google-play.svg"/> </a>
# </div>
# <!-- App store button -->
# <div class="col-6 col-sm-4 col-md-3 col-lg-6">
# <a href="https://itunes.apple.com/us/app/tutorials-point/id914891263?ls=1&amp;mt=8" target="_blank"> <img alt="app-store" src="static/images/client/app-store.svg"/></a>
# </div>
# </div> <!-- Row END -->
# </div>
# <!-- Widget 1 END -->
# <!-- Widget 2 START -->
# <div class="col-lg-6">
# <div class="row g-4">
# <!-- Link block -->
# <div class="col-6 col-md-4">
# <h5 class="mb-1 mb-md-3">ABOUT US</h5>
# <ul class="nav flex-column">
# <li class="nav-item"><a class="nav-link" href="/about/index.htm"><i class="fal fa-check"></i>  Company</a></li>
# <li class="nav-item"><a class="nav-link" href="/about/about_team.htm"><i class="fal fa-check"></i> Our Team</a></li>
# <li class="nav-item"><a class="nav-link" href="/about/about_careers.htm"><i class="fal fa-check"></i> Careers</a></li>
# <li class="nav-item"><a class="nav-link" href="https://www.tutorialspoint.com/about/about_helping.htm"><i class="fal fa-check"></i> Helping</a></li>
# <li class="nav-item"><a class="nav-link" href="#"><i class="fal fa-check"></i> Become a teacher</a></li>
# </ul>
# </div>
# <!-- Link block -->
# <div class="col-6 col-md-4">
# <h5 class="mb-1 mb-md-3">TERMS</h5>
# <ul class="nav flex-column">
# <li class="nav-item"><a class="nav-link" href="/about/about_terms_of_use.htm"><i class="fal fa-check"></i> Terms of use</a></li>
# <li class="nav-item"><a class="nav-link" href="/about/about_privacy.htm"><i class="fal fa-check"></i> Privacy Policy</a></li>
# <li class="nav-item"><a class="nav-link" href="/about/about_cookies.htm"><i class="fal fa-check"></i> Cookies Policy</a></li>
# <li class="nav-item"><a class="nav-link" href="/about/return_refund_policy.htm"><i class="fal fa-check"></i> Refund Policy</a></li>
# <li class="nav-item"><a class="nav-link" href="/about/faq.htm"><i class="fal fa-check"></i> FAQ</a></li>
# </ul>
# </div>
# <!-- Link block -->
# <div class="col-6 col-md-4">
# <h5 class="mb-1 mb-md-3">EXTRA LINKS</h5>
# <ul class="nav flex-column">
# <li class="nav-item"><a class="nav-link" href="https://www.tutorialspoint.com/online_dev_tools.htm"><i class="fal fa-check"></i> Dev Tools</a></li>
# <li class="nav-item"><a class="nav-link" href="https://www.tutorialspoint.com/free_web_graphics.htm"><i class="fal fa-check"></i> Free Graphics</a></li>
# <li class="nav-item"><a class="nav-link" href="https://www.tutorialspoint.com/online_file_conversion.htm"><i class="fal fa-check"></i> File Conversion</a></li>
# <li class="nav-item"><a class="nav-link" href="https://www.tutorialspoint.com/netmeeting.php"><i class="fal fa-check"></i> NetMeeting</a></li>
# <li class="nav-item"><a class="nav-link" href="https://www.tutorialspoint.com/free_online_whiteboard.htm"><i class="fal fa-check"></i> Whiteboard</a></li>
# </ul>
# </div>
# </div>
# </div>
# <!-- Widget 2 END -->
# <!-- Widget 3 START -->
# <div class="col-lg-3">
# <h5 class="mb-1 mb-md-3">CONTACT</h5>
# <!-- Time -->
# <p class="mb-2">
# <i class="fal fa-location-dot"></i> Tutorials Point India Private Limited, 4th Floor Incor9 Building, Kavuri Hills, Madhapur,  Hyderabad, Telangana - 500081, <b>INDIA</b>
# </p>
# <p class="mb-0"><span class="h6 fw-light"><a href="about/contact_us.htm" title="Contact Form">Contact Form <i class="fal fa-envelope"></i></a></span></p>
# <ul class="list-inline mb-0 mt-3">
# <li class="list-inline-item"> <a class="btn btn-white btn-sm shadow px-2 text-facebook" href="https://www.facebook.com/tutorialspointindia" rel="nofollow" target="_blank"><i class="fab fa-fw fa-facebook-f fa-xl"></i></a> </li>
# <li class="list-inline-item"> <a class="btn btn-white btn-sm shadow px-2 text-instagram" href="https://www.instagram.com/tutorialspoint_/" rel="nofollow" target="_blank"><i class="fab fa-fw fa-instagram fa-xl"></i></a> </li>
# <li class="list-inline-item"> <a class="btn btn-white btn-sm shadow px-2 text-youtube" href="https://www.youtube.com/channel/UCVLbzhxVTiTLiVKeGV7WEBg" rel="nofollow" target="_blank"><i class="fab fa-fw fa-youtube fa-xl"></i></a> </li>
# <li class="list-inline-item"> <a class="btn btn-white btn-sm shadow px-2 text-twitter" href="https://twitter.com/tutorialspoint" rel="nofollow" target="_blank"><i class="fab fa-fw fa-twitter fa-xl"></i></a> </li>
# <li class="list-inline-item"><a class="btn btn-white btn-sm shadow px-2 text-linkedin" href="https://www.linkedin.com/authwall?trk=bf&amp;trkInfo=AQEkqX2eckF__gAAAX-wMwEYvrsjBVbEtWQd4pgEdVSzkL22Nik1KEpY_ECWLKDGc41z8IOZWr2Bb0fvJplT60NPBtSw87J6QCpc7wD4qQ3iU13n6xJtBxME5o05Wmpg5JPm5YY=&amp;originalReferer=&amp;sessionRedirect=https%3A%2F%2Fwww.linkedin.com%2Fcompany%2Ftutorialspoint" rel="nofollow" target="_blank"><i class="fab fa-fw fa-linkedin-in fa-xl"></i></a> </li>
# </ul>
# </div>
# <!-- Widget 3 END -->
# </div><!-- Row END -->
# <!-- Divider -->
# <hr class="mt-4 mb-0"/>
# <!-- Bottom footer -->
# <div class="py-3">
# <div class="container px-0">
# <div class="d-md-flex justify-content-between align-items-center py-3 text-center text-md-center">
# <!-- copyright text -->
# <div class="text-primary-hover"> Copyrights <a class="text-body" href="#">© 2022 Tutorials Point</a>. All rights reserved. </div>
# <!-- copyright links-->
# <div class="mt-3 mt-md-0">
# <ul class="list-inline mb-0">
# <li class="list-inline-item"><a class="nav-link" href="/about/return_refund_policy.htm"><i class="fal fa-map-marker-alt me-1"></i>Refund Policy</a></li>
# <li class="list-inline-item"><a class="nav-link" href="/about/about_terms_of_use.htm"><i class="fal fa-file-signature me-1"></i> Terms of use</a></li>
# <li class="list-inline-item"><a class="nav-link pe-0" href="/about/about_privacy.htm"><i class="fal fa-shield-check me-1"></i> Privacy policy</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <!-- ======================= Footer END -->
# <!-- Back to top -->
# <div class="back-top"><i class="fa fa-angle-up position-absolute top-50 start-50 translate-middle"></i></div>
# <script src="static/vendor/bootstrap/dist/js/bootstrap.bundle.min.js"></script>
# <script src="https://www.tutorialspoint.com/theme/js/localization.js?v=2.21"></script>
# <script src="static/vendor/tiny-slider/tiny-slider.js"></script>
# <script src="static/vendor/purecounterjs/dist/purecounter_vanilla.js"></script>
# <script src="static/js/functions.js?v=1.11"></script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-232293-6"></script>
# <script>
#    window.dataLayer = window.dataLayer || [];
#    function gtag(){dataLayer.push(arguments);}
#    gtag('js', new Date());
#    gtag('config', 'UA-232293-6');
# </script>
# </body>

# %%
soup.link # return single link
# Out:
# <link href="https://www.tutorialspoint.com" rel="canonical"/>

# %%
soup.find_all('link') # return multiple link
# Out:
# [<link href="https://www.tutorialspoint.com" rel="canonical"/>,
#  <link href="favicon.ico" rel="shortcut icon"/>,
#  <link href="https://fonts.googleapis.com" rel="preconnect"/>,
#  <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>,
#  <link href="https://fonts.googleapis.com/css2?family=Heebo:wght@400;500;700&amp;family=Roboto:wght@400;500;700&amp;display=swap" rel="stylesheet"/>,
#  <link href="static/vendor/font-awesome/css/fontawesome-custom.min.css" rel="stylesheet" type="text/css"/>,
#  <link href="static/vendor/tiny-slider/tiny-slider.css" rel="stylesheet" type="text/css"/>,
#  <link href="static/css/style.css" id="style-switch" rel="stylesheet" type="text/css"/>,
#  <link href="static/css/custom.css" rel="stylesheet" type="text/css"/>]

# %%
soup.link.attrs # return link as list
# Out:
# {'rel': ['canonical'], 'href': 'https://www.tutorialspoint.com'}

# %%
soup.link.attrs['href'] # return only link text
# Out:
# 'https://www.tutorialspoint.com'

# %%
for link in soup.find_all('a'): # extract all the URLs within a webpage
    print(link.get('href'))
# Out:
# https://www.tutorialspoint.com/index.htm
# https://www.tutorialspoint.com/codingground.htm
# https://www.tutorialspoint.com/questions/index.php
# https://www.tutorialspoint.com/about/about_careers.htm
# https://www.tutorialspoint.com/whiteboard.htm
# https://www.tutorialspoint.com/online_dev_tools.htm
# https://www.tutorialspoint.com/business/index.asp
# https://www.tutorialspoint.com/market/teach_with_us.jsp
# https://www.facebook.com/tutorialspointindia
# https://www.instagram.com/tutorialspoint_/
# https://twitter.com/tutorialspoint
# https://www.youtube.com/channel/UCVLbzhxVTiTLiVKeGV7WEBg
# https://www.linkedin.com/authwall?trk=bf&trkInfo=AQEkqX2eckF__gAAAX-wMwEYvrsjBVbEtWQd4pgEdVSzkL22Nik1KEpY_ECWLKDGc41z8IOZWr2Bb0fvJplT60NPBtSw87J6QCpc7wD4qQ3iU13n6xJtBxME5o05Wmpg5JPm5YY=&originalReferer=&sessionRedirect=https%3A%2F%2Fwww.linkedin.com%2Fcompany%2Ftutorialspoint
# index.htm
# #
# https://www.tutorialspoint.com/categories/development
# https://www.tutorialspoint.com/categories/it_and_software
# https://www.tutorialspoint.com/categories/data_science_and_ai_ml
# https://www.tutorialspoint.com/categories/cyber_security
# https://www.tutorialspoint.com/prime-pack/data-science-prime-pack/index.asp
# https://www.tutorialspoint.com/profile/tutorialspoint_com
# https://www.tutorialspoint.com/prime-pack/data-science-prime-pack/index.asp
# https://www.tutorialspoint.com/prime-pack/data-science-prime-pack/index.asp
# https://www.tutorialspoint.com/html5-and-css3-fundamentals/index.asp
# https://www.tutorialspoint.com/html5-and-css3-fundamentals/index.asp
# https://www.tutorialspoint.com/profile/stone-river-elearning-16509579258
# https://www.tutorialspoint.com/html5-and-css3-fundamentals/index.asp
# https://www.tutorialspoint.com/html5-and-css3-fundamentals/index.asp
# https://www.tutorialspoint.com/tableau_online_training/index.asp
# https://www.tutorialspoint.com/tableau_online_training/index.asp
# https://www.tutorialspoint.com/profile/Pavan-Lalwani
# https://www.tutorialspoint.com/tableau_online_training/index.asp
# https://www.tutorialspoint.com/tableau_online_training/index.asp
# https://www.tutorialspoint.com/learn_python_programming_from_a_z_beginner_to_expert_course/index.asp
# https://www.tutorialspoint.com/learn_python_programming_from_a_z_beginner_to_expert_course/index.asp
# https://www.tutorialspoint.com/profile/juan_galvan
# https://www.tutorialspoint.com/learn_python_programming_from_a_z_beginner_to_expert_course/index.asp
# https://www.tutorialspoint.com/learn_python_programming_from_a_z_beginner_to_expert_course/index.asp
# https://www.tutorialspoint.com/cyber_security_go_from_zero_to_hero/index.asp
# https://www.tutorialspoint.com/cyber_security_go_from_zero_to_hero/index.asp
# https://www.tutorialspoint.com/profile/chinmay_kulkarni
# https://www.tutorialspoint.com/cyber_security_go_from_zero_to_hero/index.asp
# https://www.tutorialspoint.com/cyber_security_go_from_zero_to_hero/index.asp
# https://www.tutorialspoint.com/sql_masterclass_sql_for_data_analytics/index.asp
# https://www.tutorialspoint.com/prime-pack/data-science-prime-pack/index.asp
# https://www.tutorialspoint.com/profile/abhishek_and_pukhraj-14426528
# https://www.tutorialspoint.com/sql_masterclass_sql_for_data_analytics/index.asp
# https://www.tutorialspoint.com/sql_masterclass_sql_for_data_analytics/index.asp
# https://www.tutorialspoint.com/full_stack_java_developer_java_plus_jsp_plus_restful_ws_plus_spring/index.asp
# https://www.tutorialspoint.com/full_stack_java_developer_java_plus_jsp_plus_restful_ws_plus_spring/index.asp
# https://www.tutorialspoint.com/profile/chaand_sheikh
# https://www.tutorialspoint.com/full_stack_java_developer_java_plus_jsp_plus_restful_ws_plus_spring/index.asp
# https://www.tutorialspoint.com/full_stack_java_developer_java_plus_jsp_plus_restful_ws_plus_spring/index.asp
# https://www.tutorialspoint.com/market/index.asp
# https://www.tutorialspoint.com/bitcoin/index.htm
# https://www.tutorialspoint.com/blockchain/index.htm
# https://www.tutorialspoint.com/blue_prism/index.htm
# https://www.tutorialspoint.com/ethereum/index.htm
# https://www.tutorialspoint.com/python_blockchain/index.htm
# https://www.tutorialspoint.com/openshift/index.htm
# https://www.tutorialspoint.com/latest_technologies.htm
# https://www.tutorialspoint.com/machine_learning/index.htm
# https://www.tutorialspoint.com/tensorflow/index.htm
# https://www.tutorialspoint.com/machine_learning_with_python/index.htm
# https://www.tutorialspoint.com/developers_best_practices/index.htm
# https://www.tutorialspoint.com/effective_resume_writing.htm
# https://www.tutorialspoint.com/computer_glossary.htm
# https://www.tutorialspoint.com/computer_whoiswho.htm
# https://www.tutorialspoint.com/questions_and_answers.htm
# https://www.tutorialspoint.com/multi_language_tutorials.htm
# index.htm
# https://play.google.com/store/apps/details?id=com.tutorialspoint.onlineviewer
# https://itunes.apple.com/us/app/tutorials-point/id914891263?ls=1&mt=8
# /about/index.htm
# /about/about_team.htm
# /about/about_careers.htm
# https://www.tutorialspoint.com/about/about_helping.htm
# #
# /about/about_terms_of_use.htm
# /about/about_privacy.htm
# /about/about_cookies.htm
# /about/return_refund_policy.htm
# /about/faq.htm
# https://www.tutorialspoint.com/online_dev_tools.htm
# https://www.tutorialspoint.com/free_web_graphics.htm
# https://www.tutorialspoint.com/online_file_conversion.htm
# https://www.tutorialspoint.com/netmeeting.php
# https://www.tutorialspoint.com/free_online_whiteboard.htm
# about/contact_us.htm
# https://www.facebook.com/tutorialspointindia
# https://www.instagram.com/tutorialspoint_/
# https://www.youtube.com/channel/UCVLbzhxVTiTLiVKeGV7WEBg
# https://twitter.com/tutorialspoint
# https://www.linkedin.com/authwall?trk=bf&trkInfo=AQEkqX2eckF__gAAAX-wMwEYvrsjBVbEtWQd4pgEdVSzkL22Nik1KEpY_ECWLKDGc41z8IOZWr2Bb0fvJplT60NPBtSw87J6QCpc7wD4qQ3iU13n6xJtBxME5o05Wmpg5JPm5YY=&originalReferer=&sessionRedirect=https%3A%2F%2Fwww.linkedin.com%2Fcompany%2Ftutorialspoint
# #
# /about/return_refund_policy.htm
# /about/about_terms_of_use.htm
# /about/about_privacy.htm

# %%
for link in soup.find_all('a'): # extract all the a tag within a webpage
    print(link)
# Out:
# <a class="nav-link" href="https://www.tutorialspoint.com/index.htm"><i class="fal fa-home me-1"></i> Home</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/codingground.htm"><i class="fal fa-code me-1"></i> Coding Ground</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/questions/index.php"><i class="fal fa-comments-alt me-1"></i> Q/A</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/about/about_careers.htm"><i class="fal fa-suitcase me-1"></i> Jobs</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/whiteboard.htm"><i class="fal fa-chalkboard me-1"></i> Whiteboard</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/online_dev_tools.htm"><i class="fal fa-screwdriver-wrench me-1"></i> Tools</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/business/index.asp"><i class="fal fa-analytics me-1"></i> Business</a>
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/market/teach_with_us.jsp" target="_blank"><i class="fal fa-screen-users me-2"></i> Teach with us</a>
# <a class="px-2 nav-link" href="https://www.facebook.com/tutorialspointindia" rel="nofollow" target="_blank"><i class="fab fa-facebook"></i></a>
# <a class="px-2 nav-link" href="https://www.instagram.com/tutorialspoint_/" rel="nofollow" target="_blank"><i class="fab fa-instagram"></i></a>
# <a class="px-2 nav-link" href="https://twitter.com/tutorialspoint" rel="nofollow" target="_blank"><i class="fab fa-twitter"></i></a>
# <a class="px-2 nav-link" href="https://www.youtube.com/channel/UCVLbzhxVTiTLiVKeGV7WEBg" rel="nofollow" target="_blank"><i class="fab fa-youtube"></i></a>
# <a class="px-2 nav-link" href="https://www.linkedin.com/authwall?trk=bf&amp;trkInfo=AQEkqX2eckF__gAAAX-wMwEYvrsjBVbEtWQd4pgEdVSzkL22Nik1KEpY_ECWLKDGc41z8IOZWr2Bb0fvJplT60NPBtSw87J6QCpc7wD4qQ3iU13n6xJtBxME5o05Wmpg5JPm5YY=&amp;originalReferer=&amp;sessionRedirect=https%3A%2F%2Fwww.linkedin.com%2Fcompany%2Ftutorialspoint" rel="nofollow" target="_blank"><i class="fab fa-linkedin-in"></i></a>
# <a class="navbar-brand" href="index.htm">
# <img alt="logo" class="light-mode-item navbar-brand-item" src="/images/logo.png"/>
# <img alt="logo" class="dark-mode-item navbar-brand-item" src="/images/logo-w.png"/>
# </a>
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" data-bs-toggle="dropdown" href="#" id="categoryMenu"><i class="fal fa-th me-3 fs-5 me-xl-1 d-xl-none"></i> <i class="fal fa-th me-1 d-none d-xl-inline-block"></i><span class="d-xl-inline-block dropdown-toggle">Category</span></a>
# <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/development"><i class="fa fa-cogs cat-icons"></i> Development</a>
# <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/it_and_software"><i class="fa fa-tv cat-icons"></i>  IT and Networking</a>
# <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/data_science_and_ai_ml"><i class="fa fa-head-side-brain cat-icons"></i> Data Science and AI ML</a>
# <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/cyber_security"><i class="fa fa-camera-home cat-icons"></i> Cyber Security</a>
# <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/marketing"><i class="fa fa-bullseye-arrow cat-icons"></i> Marketing</a>
# <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/office_productivity"><i class="fa fa-camera-home cat-icons"></i> Office Productivity</a>
# <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/business"><i class="fa fa-chart-bar cat-icons"></i> Business</a>
# <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/lifestyle"><i class="fa fa-person-dolly-empty cat-icons"></i> Lifestyle</a>
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/latest/prime-packs" target="_self"><i class="fal fa-cubes me-1"></i> Prime Packs</a>
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/market/index.asp" target="_self"><i class="fal fa-circle-play me-1"></i> Courses</a>
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/latest/ebooks" target="_self"><i class="fal fa-book-reader me-1"></i> eBooks</a>
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/tutorialslibrary.htm" target="_self"><i class="fal fa-books me-1"></i> Library</a>
# <a href="https://www.tutorialspoint.com/market/login.asp" target="_self"><button class="btn btn-grey-border mb-0"><i class="fal fa-sign-in-alt me-2"></i> Login</button></a>
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/latest/prime-packs" target="_self"><i class="fal fa-cubes me-1"></i> Prime Packs</a>
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/market/index.asp" target="_self"><i class="fal fa-circle-play me-1"></i> Courses</a>
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/latest/ebooks" target="_self"><i class="fal fa-book-reader me-1"></i> eBooks</a>
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/tutorialslibrary.htm" target="_self"><i class="fal fa-books me-1"></i> Library</a>
# <a class="btn btn-lg btn-green-hard me-2 mb-4 mb-sm-0" href="https://www.tutorialspoint.com/codingground.htm"><i class="fal fa-code me-1"></i> Coding Ground</a>
# <a class="ms-0 ms-sm-4" data-gallery="office-tour" data-glightbox="" href="https://www.tutorialspoint.com/market/index.asp">
# <div class="btn btn-round btn-black-shadow mb-0 me-3 align-middle"> <i class="fal fa-play"></i></div>
# <div class="align-middle d-inline-block">
# <h6 class="mb-0 fw-normal">Watch Demo Video</h6>
# </div>
# </a>
# <a class="stretched-link" href="https://www.tutorialspoint.com/categories/development"> Development</a>
# <a class="stretched-link" href="https://www.tutorialspoint.com/categories/it_and_software">IT and Networking</a>
# <a class="stretched-link" href="https://www.tutorialspoint.com/categories/data_science_and_ai_ml">Data Science and AI ML</a>
# <a class="stretched-link" href="https://www.tutorialspoint.com/categories/cyber_security">Cyber Security</a>
# <a class="stretched-link" href="https://www.tutorialspoint.com/categories/marketing">Marketing</a>
# <a class="stretched-link" href="https://www.tutorialspoint.com/categories/office_productivity">Office Productivity</a>
# <a class="stretched-link" href="https://www.tutorialspoint.com/categories/business">Business</a>
# <a class="stretched-link" href="https://www.tutorialspoint.com/categories/lifestyle">Lifestyle</a>
# <a href="https://www.tutorialspoint.com/prime-pack/complete-python-prime-pack/index.asp" title="Complete Python Prime Pack"><img alt="course image" class="card-img-top" src="https://d3mxt5v3yxgcsr.cloudfront.net/courses/4870/course_4870_image.jpg"/></a>
# <a href="https://www.tutorialspoint.com/prime-pack/complete-python-prime-pack/index.asp" title="Complete Python Prime Pack">Complete Python Prime Pack</a>
# <a class="h6 fw-light mb-0" href="https://www.tutorialspoint.com/profile/tutorialspoint_com"><i class="fal fa-user me-2"></i> Tutorialspoint</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/prime-pack/complete-python-prime-pack/index.asp"><i class="fal fa-shopping-cart me-2"></i>Add to cart</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/prime-pack/complete-python-prime-pack/index.asp"><i class="fal fa-money-check-alt me-2"></i>Buy Now</a>
# <a href="https://www.tutorialspoint.com/prime-pack/cyber-security-prime-pack/index.asp" title="Complete Python Prime Pack"><img alt="course image" class="card-img-top" src="https://d3mxt5v3yxgcsr.cloudfront.net/courses/4876/course_4876_image.jpg"/></a>
# <a href="https://www.tutorialspoint.com/prime-pack/cyber-security-prime-pack/index.asp" title="Cyber Security Prime Pack">Cyber Security Prime Pack</a>
# <a class="h6 fw-light mb-0" href="https://www.tutorialspoint.com/profile/tutorialspoint_com"><i class="fal fa-user me-2"></i> Tutorialspoint</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/prime-pack/cyber-security-prime-pack/index.asp"><i class="fal fa-shopping-cart me-2"></i>Add to cart</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/prime-pack/cyber-security-prime-pack/index.asp"><i class="fal fa-money-check-alt me-2"></i>Buy Now</a>
# <a href="https://www.tutorialspoint.com/prime-pack/fullstack-web-development-prime-pack/index.asp" title="FullStack Web Development Prime Pack"><img alt="course image" class="card-img-top" src="https://d3mxt5v3yxgcsr.cloudfront.net/courses/4982/course_4982_image.jpg"/></a>
# <a href="https://www.tutorialspoint.com/prime-pack/fullstack-web-development-prime-pack/index.asp">FullStack Web Development Prime Pack</a>
# <a class="h6 fw-light mb-0" href="https://www.tutorialspoint.com/profile/tutorialspoint_com"><i class="fal fa-user me-2"></i> Tutorialspoint</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/prime-pack/fullstack-web-development-prime-pack/index.asp"><i class="fal fa-shopping-cart me-2"></i>Add to cart</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/prime-pack/fullstack-web-development-prime-pack/index.asp"><i class="fal fa-money-check-alt me-2"></i>Buy Now</a>
# <a href="https://www.tutorialspoint.com/prime-pack/artificial-intelligence-and-machine-learning-prime-pack/index.asp" title="Artificial Intelligence &amp; Machine Learning Prime Pack"><img alt="course image" class="card-img-top" src="https://d3mxt5v3yxgcsr.cloudfront.net/courses/4874/course_4874_image.jpg"/></a>
# <a href="https://www.tutorialspoint.com/prime-pack/artificial-intelligence-and-machine-learning-prime-pack/index.asp" title="Artificial Intelligence &amp; Machine Learning Prime Pack">Artificial Intelligence &amp; Machine Learning Prime Pack</a>
# <a class="h6 fw-light mb-0" href="https://www.tutorialspoint.com/profile/tutorialspoint_com"><i class="fal fa-user me-2"></i> Tutorialspoint</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/prime-pack/artificial-intelligence-and-machine-learning-prime-pack/index.asp"><i class="fal fa-shopping-cart me-2"></i>Add to cart</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/prime-pack/artificial-intelligence-and-machine-learning-prime-pack/index.asp"><i class="fal fa-money-check-alt me-2"></i>Buy Now</a>
# <a href="https://www.tutorialspoint.com/prime-pack/javascript-prime-pack/index.asp" title="JavaScript Prime Pack"><img alt="course image" class="card-img-top" src="https://d3mxt5v3yxgcsr.cloudfront.net/courses/4986/course_4986_image.jpg"/></a>
# <a href="https://www.tutorialspoint.com/prime-pack/javascript-prime-pack/index.asp" title="JavaScript Prime Pack">JavaScript Prime Pack</a>
# <a class="h6 fw-light mb-0" href="https://www.tutorialspoint.com/profile/tutorialspoint_com"><i class="fal fa-user me-2"></i> Tutorialspoint</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/prime-pack/javascript-prime-pack/index.asp"><i class="fal fa-shopping-cart me-2"></i>Add to cart</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/prime-pack/javascript-prime-pack/index.asp"><i class="fal fa-money-check-alt me-2"></i>Buy Now</a>
# <a href="https://www.tutorialspoint.com/prime-pack/data-science-prime-pack/index.asp" title="Data Science Prime Pack"><img alt="course image" class="card-img-top" src="https://d3mxt5v3yxgcsr.cloudfront.net/courses/4873/course_4873_image.jpg"/></a>
# <a href="https://www.tutorialspoint.com/prime-pack/data-science-prime-pack/index.asp" title="Data Science Prime Pack">Data Science Prime Pack</a>
# <a class="h6 fw-light mb-0" href="https://www.tutorialspoint.com/profile/tutorialspoint_com"><i class="fal fa-user me-2"></i> Tutorialspoint</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/prime-pack/data-science-prime-pack/index.asp"><i class="fal fa-shopping-cart me-2"></i>Add to cart</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/prime-pack/data-science-prime-pack/index.asp"><i class="fal fa-money-check-alt me-2"></i>Buy Now</a>
# <a href="https://www.tutorialspoint.com/html5-and-css3-fundamentals/index.asp" title="HTML5 And CSS3 Fundamentals"><img alt="course image" class="card-img-top" src="https://d3mxt5v3yxgcsr.cloudfront.net/courses/6584/course_6584_image.jpg"/></a>
# <a href="https://www.tutorialspoint.com/html5-and-css3-fundamentals/index.asp" title="HTML5 And CSS3 Fundamentals">HTML5 And CSS3 Fundamentals</a>
# <a class="h6 fw-light mb-0" href="https://www.tutorialspoint.com/profile/stone-river-elearning-16509579258"><i class="fal fa-user me-2"></i> Stone River ELearning</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/html5-and-css3-fundamentals/index.asp"><i class="fal fa-shopping-cart me-2"></i>Add to cart</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/html5-and-css3-fundamentals/index.asp"><i class="fal fa-money-check-alt me-2"></i>Buy Now</a>
# <a href="https://www.tutorialspoint.com/tableau_online_training/index.asp" title="Tableau Online Training"><img alt="course image" class="card-img-top" src="https://d3mxt5v3yxgcsr.cloudfront.net/courses/1895/course_1895_image.png"/></a>
# <a href="https://www.tutorialspoint.com/tableau_online_training/index.asp" title="Tableau Online Training">Tableau Online Training</a>
# <a class="h6 fw-light mb-0" href="https://www.tutorialspoint.com/profile/Pavan-Lalwani"><i class="fal fa-user me-2"></i> Pavan Lalwani</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/tableau_online_training/index.asp"><i class="fal fa-shopping-cart me-2"></i>Add to cart</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/tableau_online_training/index.asp"><i class="fal fa-money-check-alt me-2"></i>Buy Now</a>
# <a href="https://www.tutorialspoint.com/learn_python_programming_from_a_z_beginner_to_expert_course/index.asp" title="Learn Python Programming From A-Z: Beginner To Expert Course"><img alt="course image" class="card-img-top" src="https://d3mxt5v3yxgcsr.cloudfront.net/courses/3903/course_3903_image.png"/></a>
# <a href="https://www.tutorialspoint.com/learn_python_programming_from_a_z_beginner_to_expert_course/index.asp" title="Learn Python Programming From A-Z: Beginner To Expert Course">Learn Python Programming From A-Z: Beginner To Expert Course</a>
# <a class="h6 fw-light mb-0" href="https://www.tutorialspoint.com/profile/juan_galvan"><i class="fal fa-user me-2"></i> Juan Galvan</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/learn_python_programming_from_a_z_beginner_to_expert_course/index.asp"><i class="fal fa-shopping-cart me-2"></i>Add to cart</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/learn_python_programming_from_a_z_beginner_to_expert_course/index.asp"><i class="fal fa-money-check-alt me-2"></i>Buy Now</a>
# <a href="https://www.tutorialspoint.com/cyber_security_go_from_zero_to_hero/index.asp" title="Cyber Security : Go From Zero To Hero"><img alt="course image" class="card-img-top" src="https://d3mxt5v3yxgcsr.cloudfront.net/courses/3187/course_3187_image.jpg"/></a>
# <a href="https://www.tutorialspoint.com/cyber_security_go_from_zero_to_hero/index.asp" title="Cyber Security : Go From Zero To Hero">Cyber Security : Go From Zero To Hero</a>
# <a class="h6 fw-light mb-0" href="https://www.tutorialspoint.com/profile/chinmay_kulkarni"><i class="fal fa-user me-2"></i> Chinmay Kulkarni</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/cyber_security_go_from_zero_to_hero/index.asp"><i class="fal fa-shopping-cart me-2"></i>Add to cart</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/cyber_security_go_from_zero_to_hero/index.asp"><i class="fal fa-money-check-alt me-2"></i>Buy Now</a>
# <a href="https://www.tutorialspoint.com/sql_masterclass_sql_for_data_analytics/index.asp" title="SQL Masterclass: SQL For Data Analytics"><img alt="course image" class="card-img-top" src="https://d3mxt5v3yxgcsr.cloudfront.net/courses/2346/course_2346_image.png"/></a>
# <a href="https://www.tutorialspoint.com/prime-pack/data-science-prime-pack/index.asp" title="SQL Masterclass: SQL For Data Analytics">SQL Masterclass: SQL For Data Analytics</a>
# <a class="h6 fw-light mb-0" href="https://www.tutorialspoint.com/profile/abhishek_and_pukhraj-14426528"><i class="fal fa-user me-2"></i> Abhishek And Pukhraj</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/sql_masterclass_sql_for_data_analytics/index.asp"><i class="fal fa-shopping-cart me-2"></i>Add to cart</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/sql_masterclass_sql_for_data_analytics/index.asp"><i class="fal fa-money-check-alt me-2"></i>Buy Now</a>
# <a href="https://www.tutorialspoint.com/full_stack_java_developer_java_plus_jsp_plus_restful_ws_plus_spring/index.asp" title="Full Stack Java Developer - Java + JSP + Restful WS + Spring"><img alt="course image" class="card-img-top" src="https://d3mxt5v3yxgcsr.cloudfront.net/courses/2705/course_2705_image.jpg"/></a>
# <a href="https://www.tutorialspoint.com/full_stack_java_developer_java_plus_jsp_plus_restful_ws_plus_spring/index.asp" title="Full Stack Java Developer - Java + JSP + Restful WS + Spring">Full Stack Java Developer - Java + JSP + Restful WS + Spring</a>
# <a class="h6 fw-light mb-0" href="https://www.tutorialspoint.com/profile/chaand_sheikh"><i class="fal fa-user me-2"></i> Chaand Sheikh</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/full_stack_java_developer_java_plus_jsp_plus_restful_ws_plus_spring/index.asp"><i class="fal fa-shopping-cart me-2"></i>Add to cart</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/full_stack_java_developer_java_plus_jsp_plus_restful_ws_plus_spring/index.asp"><i class="fal fa-money-check-alt me-2"></i>Buy Now</a>
# <a class="btn btn-grey-border mb-0" href="https://www.tutorialspoint.com/market/index.asp" target="_blank">View more<i class="fal fa-sync ms-2"></i></a>
# <a href="https://www.tutorialspoint.com/bitcoin/index.htm" target="_blank" title="Bitcoin Tutorial">
# <div class="image-title white-title">Bitcoin Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/blockchain/index.htm" target="_blank" title="Blockchain Tutorial">
# <div class="image-title white-title">Blockchain Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/blue_prism/index.htm" target="_blank" title="Blue Prism Tutorial">
# <div class="image-title white-title">Blue Prism Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/ethereum/index.htm" target="_blank" title="Ethereum Tutorial">
# <div class="image-title white-title">Ethereum Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/python_blockchain/index.htm" target="_blank" title="Python Blockchain Tutorial">
# <div class="image-title white-title">Python Blockchain</div>
# </a>
# <a href="https://www.tutorialspoint.com/openshift/index.htm" target="_blank" title="OpenShift Tutorial">
# <div class="image-title white-title">OpenShift Tutorial</div>
# </a>
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/latest_technologies.htm">View more<i class="fal fa-sync ms-2"></i></a>
# <a href="https://www.tutorialspoint.com/machine_learning/index.htm" target="_blank" title="Machine Learning Tutorial">
# <div class="image-title white-title">Machine Learning</div>
# </a>
# <a href="https://www.tutorialspoint.com/tensorflow/index.htm" target="_blank" title="TensorFlow Tutorial">
# <div class="image-title white-title">TensorFlow Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/machine_learning_with_python/index.htm" target="_blank" title="Machine Learning with Python Tutorial">
# <div class="image-title white-title">ML with Python</div>
# </a>
# <a href="https://www.tutorialspoint.com/artificial_intelligence_with_python/index.htm" target="_blank" title="AI with Python Tutorial">
# <div class="image-title white-title">AI with Python</div>
# </a>
# <a href="https://www.tutorialspoint.com/time_series/index.htm" target="_blank" title="Python Blockchain Tutorial">
# <div class="image-title white-title">Time Series Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/pytorch/index.htm" target="_blank" title="PyTorch Tutorial">
# <div class="image-title white-title">PyTorch Tutorial</div>
# </a>
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/machine_learning_tutorials.htm">View more<i class="fal fa-sync ms-2"></i></a>
# <a href="https://www.tutorialspoint.com/computer_fundamentals/index.htm" target="_blank" title="Computer-Fundamentals Tutorial">
# <div class="image-title white-title">Computer <span>Fundamentals</span></div>
# </a>
# <a href="https://www.tutorialspoint.com/compiler_design/index.htm" target="_blank" title="Compiler-Design Tutorial">
# <div class="image-title white-title">Compiler Design</div>
# </a>
# <a href="https://www.tutorialspoint.com/operating_system/index.htm" target="_blank" title="Operating-System Tutorial">
# <div class="image-title white-title">Operating System</div>
# </a>
# <a href="https://www.tutorialspoint.com/data_structures_algorithms/index.htm" target="_blank" title="Data Structure Tutorial">
# <div class="image-title white-title">Data Structure</div>
# </a>
# <a href="https://www.tutorialspoint.com/dbms/index.htm" target="_blank" title="DBMS Tutorial">
# <div class="image-title white-title">DBMS Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/data_communication_computer_network/index.htm" target="_blank" title="Networking Tutorial">
# <div class="image-title white-title">Networking Tutorial</div>
# </a>
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/computer_science_tutorials.htm">View more<i class="fal fa-sync ms-2"></i></a>
# <a href="https://www.tutorialspoint.com/html/index.htm" target="_blank" title="html Tutorial">
# <div class="image-title white-title">HTML Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/css/index.htm" target="_blank" title="css Tutorial">
# <div class="image-title white-title">css Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/javascript/index.htm" target="_blank" title="Javascript Tutorial">
# <div class="image-title white-title">Javascript Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/php/index.htm" target="_blank" title="PHP Tutorial">
# <div class="image-title white-title">PHP Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/angular4/index.htm" target="_blank" title="Angular JS 4 Tutorial">
# <div class="image-title white-title">Angular JS 4 Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/mysql/index.htm" target="_blank" title="MySQL Tutorial">
# <div class="image-title white-title">MySQL Tutorial</div>
# </a>
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/web_development_tutorials.htm">View more<i class="fal fa-sync ms-2"></i></a>
# <a href="https://www.tutorialspoint.com/html/index.htm" target="_blank" title="html Tutorial">
# <div class="image-title white-title">HTML Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/cplusplus/index.htm" target="_blank" title="C++  Tutorial">
# <div class="image-title white-title">C++ Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/java8/index.htm" target="_blank" title="Java 8 Tutorial">
# <div class="image-title white-title">Java 8 Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/python/index.htm" target="_blank" title="Python Tutorial">
# <div class="image-title white-title">Python Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/scala/index.htm" target="_blank" title="Scala Tutorial">
# <div class="image-title white-title">Scala Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/csharp/index.htm" target="_blank" title="C# Tutorial">
# <div class="image-title white-title">C# Tutorial</div>
# </a>
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/computer_programming_tutorials.htm">View more<i class="fal fa-sync ms-2"></i></a>
# <a href="https://www.tutorialspoint.com/java8/index.htm" target="_blank" title="Java 8 Tutorial">
# <div class="image-title white-title">Java 8 Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/jdbc/index.htm" target="_blank" title="JDBC  Tutorial">
# <div class="image-title white-title">JDBC Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/swing/index.htm" target="_blank" title="Swing Tutorial">
# <div class="image-title white-title">Swing Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/servlets/index.htm" target="_blank" title="Servlets Tutorial">
# <div class="image-title white-title">Servlets Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/spring/index.htm" target="_blank" title="Spring Tutorial">
# <div class="image-title white-title">Spring Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/hibernate/index.htm" target="_blank" title="Hibernate Tutorial">
# <div class="image-title white-title">Hibernate Tutorial</div>
# </a>
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/java_technology_tutorials.htm">View more<i class="fal fa-sync ms-2"></i></a>
# <a href="https://www.tutorialspoint.com/android/index.htm" target="_blank" title="Android Tutorial">
# <div class="image-title white-title">Android Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/swift/index.htm" target="_blank" title="Swift Tutorial">
# <div class="image-title white-title">Swift Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/ios/index.htm" target="_blank" title="IOS Tutorial">
# <div class="image-title white-title">IOS Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/kotlin/index.htm" target="_blank" title="Kotlin Tutorial">
# <div class="image-title white-title">Kotlin Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/xamarin/index.htm" target="_blank" title="Xamarian Tutorial">
# <div class="image-title white-title">Xamarian Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/react_native/index.htm" target="_blank" title="React Native Tutorial">
# <div class="image-title white-title">React Native Tutorial</div>
# </a>
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/mobile_development_tutorials.htm">View more<i class="fal fa-sync ms-2"></i></a>
# <a href="https://www.tutorialspoint.com/mongodb/index.htm" target="_blank" title="Mongo DB Tutorial">
# <div class="image-title white-title">Mongo DB Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/plsql/index.htm" target="_blank" title="PL / SQL Tutorial">
# <div class="image-title white-title">PL / SQL Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/sql/index.htm" target="_blank" title="SQL Tutorial">
# <div class="image-title white-title">SQL Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/db2/index.htm" target="_blank" title="DB2 Tutorial">
# <div class="image-title white-title">DB2 Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/mysql/index.htm" target="_blank" title="MySQL Tutorial">
# <div class="image-title white-title">MySQL Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/memcached/index.htm" target="_blank" title="Memcached Tutorial">
# <div class="image-title white-title">Memcached Tutorial</div>
# </a>
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/database_tutorials.htm">View more<i class="fal fa-sync ms-2"></i></a>
# <a href="https://www.tutorialspoint.com/asp.net/index.htm" target="_blank" title="ASP.NET Tutorial">
# <div class="image-title white-title">ASP.NET</div>
# </a>
# <a href="https://www.tutorialspoint.com/entity_framework/index.htm" target="_blank" title="Entity Framework Tutorial">
# <div class="image-title white-title">Entity Framework</div>
# </a>
# <a href="https://www.tutorialspoint.com/vb.net/index.htm" target="_blank" title="VB.NET Tutorial">
# <div class="image-title white-title">VB.NET Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/ms_project/index.htm" target="_blank" title="Microsoft Project Tutorial">
# <div class="image-title white-title">Microsoft Project</div>
# </a>
# <a href="https://www.tutorialspoint.com/excel/index.htm" target="_blank" title="Microsoft Excel Tutorial">
# <div class="image-title white-title">Microsoft Excel</div>
# </a>
# <a href="https://www.tutorialspoint.com/word/index.htm" target="_blank" title="Microsoft Word Tutorial">
# <div class="image-title white-title">Microsoft Word</div>
# </a>
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/microsoft_technologies_tutorials.htm">View more<i class="fal fa-sync ms-2"></i></a>
# <a href="https://www.tutorialspoint.com/big_data_analytics/index.htm" target="_blank" title="Big Data Analytics Tutorial">
# <div class="image-title white-title">Big Data Analytics</div>
# </a>
# <a href="https://www.tutorialspoint.com/hadoop/index.htm" target="_blank" title="Hadoop Tutorial">
# <div class="image-title white-title">Hadoop Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/sas/index.htm" target="_blank" title="SAS Tutorial">
# <div class="image-title white-title">SAS Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/qlikview/index.htm" target="_blank" title="QlikView Tutorial">
# <div class="image-title white-title">QlikView Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/power_bi/index.htm" target="_blank" title="Power BI Tutorial">
# <div class="image-title white-title">Power BI Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/tableau/index.htm" target="_blank" title="Tableau Tutorial">
# <div class="image-title white-title">Tableau Tutorial</div>
# </a>
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/big_data_tutorials.htm">View more<i class="fal fa-sync ms-2"></i></a>
# <a class="btn btn-primary mb-0" href="https://www.tutorialspoint.com/market/teach_with_us.jsp" target="_blank">Start Now</a>
# <a class="btn btn-warning mb-0" href="https://www.tutorialspoint.com/bestseller/courses" target="_blank">View Courses</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/developers_best_practices/index.htm" title="Developer's Best Practices">
# <i class="fal fa-display-code fa-3x w-lg-80px w-sm-50px mb-3"></i>
# <p class="text-secondary">Developers <br/><b>Best Practices</b></p>
# </a>
# <a class="nav-link" href="https://www.tutorialspoint.com/effective_resume_writing.htm" title="Effective Resume Writing">
# <i class="fal fa-pen-field fa-3x w-lg-80px w-sm-50px mb-3"></i>
# <p class="text-secondary">Effective <br/><b>Resume Writing</b></p>
# </a>
# <a class="nav-link" href="https://www.tutorialspoint.com/computer_glossary.htm" title="Computer Glossary">
# <i class="fal fa-notebook fa-3x w-lg-80px w-sm-50px mb-3"></i>
# <p class="text-secondary">Computer <br/><b>Glossary</b></p>
# </a>
# <a class="nav-link" href="https://www.tutorialspoint.com/computer_whoiswho.htm" title="Who is Who in Computer Science">
# <i class="fal fa-users fa-3x w-lg-80px w-sm-50px mb-3"></i>
# <p class="text-secondary">Who is Who <br/><b>in Computer</b></p>
# </a>
# <a class="nav-link" href="https://www.tutorialspoint.com/questions_and_answers.htm" title="Technical Questions and Answers">
# <i class="fal fa-comments-question-check fa-3x w-lg-80px w-sm-50px mb-3"></i>
# <p class="text-secondary">Technical <br/><b>Q &amp; A</b></p>
# </a>
# <a class="nav-link" href="https://www.tutorialspoint.com/multi_language_tutorials.htm" title="Multi-Lingual Tutorials">
# <i class="fal fa-globe fa-3x w-lg-80px w-sm-50px mb-3"></i>
# <p class="text-secondary">Multi-Lingual <br/><b>Tutorials</b></p>
# </a>
# <a class="me-0" href="index.htm">
# <img alt="Tutorials Point" class="light-mode-item h-60px" src="/images/logo.png"/>
# <img alt="Tutorials Point" class="dark-mode-item h-60px" src="/images/logo-white.png"/>
# </a>
# <a href="https://play.google.com/store/apps/details?id=com.tutorialspoint.onlineviewer" target="_blank"><img alt="" src="static/images/client/google-play.svg"/> </a>
# <a href="https://itunes.apple.com/us/app/tutorials-point/id914891263?ls=1&amp;mt=8" target="_blank"> <img alt="app-store" src="static/images/client/app-store.svg"/></a>
# <a class="nav-link" href="/about/index.htm"><i class="fal fa-check"></i>  Company</a>
# <a class="nav-link" href="/about/about_team.htm"><i class="fal fa-check"></i> Our Team</a>
# <a class="nav-link" href="/about/about_careers.htm"><i class="fal fa-check"></i> Careers</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/about/about_helping.htm"><i class="fal fa-check"></i> Helping</a>
# <a class="nav-link" href="#"><i class="fal fa-check"></i> Become a teacher</a>
# <a class="nav-link" href="/about/about_terms_of_use.htm"><i class="fal fa-check"></i> Terms of use</a>
# <a class="nav-link" href="/about/about_privacy.htm"><i class="fal fa-check"></i> Privacy Policy</a>
# <a class="nav-link" href="/about/about_cookies.htm"><i class="fal fa-check"></i> Cookies Policy</a>
# <a class="nav-link" href="/about/return_refund_policy.htm"><i class="fal fa-check"></i> Refund Policy</a>
# <a class="nav-link" href="/about/faq.htm"><i class="fal fa-check"></i> FAQ</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/online_dev_tools.htm"><i class="fal fa-check"></i> Dev Tools</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/free_web_graphics.htm"><i class="fal fa-check"></i> Free Graphics</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/online_file_conversion.htm"><i class="fal fa-check"></i> File Conversion</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/netmeeting.php"><i class="fal fa-check"></i> NetMeeting</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/free_online_whiteboard.htm"><i class="fal fa-check"></i> Whiteboard</a>
# <a href="about/contact_us.htm" title="Contact Form">Contact Form <i class="fal fa-envelope"></i></a>
# <a class="btn btn-white btn-sm shadow px-2 text-facebook" href="https://www.facebook.com/tutorialspointindia" rel="nofollow" target="_blank"><i class="fab fa-fw fa-facebook-f fa-xl"></i></a>
# <a class="btn btn-white btn-sm shadow px-2 text-instagram" href="https://www.instagram.com/tutorialspoint_/" rel="nofollow" target="_blank"><i class="fab fa-fw fa-instagram fa-xl"></i></a>
# <a class="btn btn-white btn-sm shadow px-2 text-youtube" href="https://www.youtube.com/channel/UCVLbzhxVTiTLiVKeGV7WEBg" rel="nofollow" target="_blank"><i class="fab fa-fw fa-youtube fa-xl"></i></a>
# <a class="btn btn-white btn-sm shadow px-2 text-twitter" href="https://twitter.com/tutorialspoint" rel="nofollow" target="_blank"><i class="fab fa-fw fa-twitter fa-xl"></i></a>
# <a class="btn btn-white btn-sm shadow px-2 text-linkedin" href="https://www.linkedin.com/authwall?trk=bf&amp;trkInfo=AQEkqX2eckF__gAAAX-wMwEYvrsjBVbEtWQd4pgEdVSzkL22Nik1KEpY_ECWLKDGc41z8IOZWr2Bb0fvJplT60NPBtSw87J6QCpc7wD4qQ3iU13n6xJtBxME5o05Wmpg5JPm5YY=&amp;originalReferer=&amp;sessionRedirect=https%3A%2F%2Fwww.linkedin.com%2Fcompany%2Ftutorialspoint" rel="nofollow" target="_blank"><i class="fab fa-fw fa-linkedin-in fa-xl"></i></a>
# <a class="text-body" href="#">© 2022 Tutorials Point</a>
# <a class="nav-link" href="/about/return_refund_policy.htm"><i class="fal fa-map-marker-alt me-1"></i>Refund Policy</a>
# <a class="nav-link" href="/about/about_terms_of_use.htm"><i class="fal fa-file-signature me-1"></i> Terms of use</a>
# <a class="nav-link pe-0" href="/about/about_privacy.htm"><i class="fal fa-shield-check me-1"></i> Privacy policy</a>

# %% [markdown]
# # Step-1
# Another way is to pass the document through open filehandle.

# %%
with open("BCB.html") as fp:
   B_soup = BeautifulSoup(fp)
   print(B_soup)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Bangladesh Cricket Board</title>
# <!-- bootstrap link -->
# <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" rel="stylesheet"/>
# <!-- CSS link -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <script src="https://kit.fontawesome.com/a076d05399.js"></script>
# <!--Get y
# 	<!-- CSS link -->
# <link href="BCB.css" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div>
# <header>
# <nav class="navbar navbar-expand-lg navbar-light bg-info fixed-top">
# <!-- Image and text -->
# <a class="navbar-brand" href="#">
# <img alt="" class="d-inline-block align-top" height="70" src="img/BCB.png" width="70"/>
# </a>
# <!-- toggle -->
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <!-- toggle div-->
# <div class="collapse navbar-collapse" id="navbarSupportedContent">
# <ul class="navbar-nav ml-auto">
# <li class="nav-item"> <a class="nav-link" href="#"> About BCB</a></li>
# <li class="nav-item"> <a class="nav-link" href="#"> News</a></li>
# <li class="nav-item"> <a class="nav-link" href="#">Fixtures</a></li>
# <li class="nav-item"> <a class="nav-link" href="#">Domestic</a>
# </li>
# <li class="nav-item"> <a class="nav-link" href="#">International</a></li>
# <li class="nav-item"> <a class="nav-link" href="#"> Gallary</a></li>
# </ul>
# <!-- Search bar-->
# <form class="form-inline my-2 my-lg-0">
# <input aria-label="Searc" class="form-control mr-sm-2" placeholder="Search" type="search"/>
# <button class="btn btn-outline-light my-2 my-sm-0" type="submit">Search</button>
# </form>
# </div>
# </nav>
# </header>
# </div>
# <!------carasol---->
# <div>
# <div class="carousel slide" data-ride="carousel" id="carouselExampleIndicators">
# <ol class="carousel-indicators">
# <li class="active" data-slide-to="0" data-target="#carouselExampleIndicators"></li>
# <li data-slide-to="1" data-target="#carouselExampleIndicators"></li>
# <li data-slide-to="2" data-target="#carouselExampleIndicators"></li>
# </ol>
# <div class="carousel-inner">
# <div class="carousel-item active">
# <img alt="photo" class="d-block w-100" src="img/1.jpg"/>
# </div>
# <div class="carousel-item">
# <img alt="photo" class="d-block w-100" src="img/2.jpg"/>
# </div>
# <div class="carousel-item">
# <img alt="photo" class="d-block w-100" src="img/3.jpg"/>
# </div>
# </div>
# <a class="carousel-control-prev" data-slide="prev" href="#carouselExampleIndicators" role="button">
# <span aria-hidden="true" class="carousel-control-prev-icon"></span>
# <span class="sr-only">Previous</span>
# </a>
# <a class="carousel-control-next" data-slide="next" href="#carouselExampleIndicators" role="button">
# <span aria-hidden="true" class="carousel-control-next-icon"></span>
# <span class="sr-only">Next</span>
# </a>
# </div>
# </div>
# <div class="container">
# <div class="row">
# <div>
# <div class="container">
# <h2>Update Notice   <div class="spinner-border text-danger"></div>
# </h2>
# <!-- Button to Open the Modal -->
# <button class="btn btn-outline-danger" data-target="#myModal" data-toggle="modal" type="button">
#     Open Notice
#   </button>
# <!-- The Modal -->
# <div class="modal" id="myModal">
# <div class="modal-dialog">
# <div class="modal-content">
# <!-- Modal Header -->
# <div class="modal-header">
# <h2 class="modal-title">Bangladesh vs Zimbabwe</h2>
# <button class="close" data-dismiss="modal" type="button">Ã—</button>
# </div>
# <!-- Modal body -->
# <div class="modal-body">
# <h4>Clinical Tigers clean sweep series 3-0</h4>
# <p>Bangladesh have wrapped up the ODI series against Zimbabwe with a stunning victory in Sylhet thanks to Liton Das and Tamim Iqbalâ€™s heroics. Reduced to a 43 overs match due to rain, Tigers defeated the visitors by 123 runs. With this match, Mashrafe Bin Mortaza ended his stint as the ODI skipper as the most successful captain in this format. It was Mashrafeâ€™s 50th win as the ODI captain.</p>
# <p>
#           Earlier, Zimbabwe put Bangladesh into bat first after winning the toss. Four changes were made in the playing eleven from the last match. Debutans Naim Sheikh, Afif Hossain came to the side alongside Mohammad Saifuddin and Mustafizur Rahman to replace Najmul Hossain, Mushfiqur Rahim, Shafiul Islam and Al-Amin Hossain.</p>
# <p>
#       Tamim and Liton both of them were their absolute best from the beginning as the pair scored runs for fun at the both end. Rain stopped the play for a while and reduced the match to 43 overs. Tamim and Liton then resumed the innings and both went onto pick up their second century in the innings.
#     </p>
# <p>
#     Liton was more destructive as he punished the Zimbabwe bowlers to score the highest ODI knock among the Bangladeshi batsmen. Liton was finally dismissed after scoring 176 off 143 balls. Tamim on the other end remained unbeaten on 128 and powered Bangladesh to post 322 for 3 in 43 overs.
#     </p>
# <p>
#     Chasing a revised target of 342, Zimbabwe faced the first setback when they lost Tinashe in the first over by Mashrafe. Madhevere, Chkavba and Williams all got the start but failed to play the big innings which their side needed in the chase. Bowlers kept taking regular wickets as Zimbabwe never looked threatening in any stage of the innings. Sikandar put some fightback with but his knock only reduced the defeat margin.
#     </p> <p>
#     Zimbabwe were eventually all out for 218. Saifuddin garbbed 4 wickets for 41.
#     </p>
# </div>
# <!-- Modal footer -->
# <div class="modal-footer">
# <button class="btn btn-danger" data-dismiss="modal" type="button">Close</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="login">
# <button class="btn btn-outline-primary" type="button">
# <a color="green" href="Login page.html">Players panel  </a> </button>
# </div>
# </div>
# </div>
# <!----info section 1----->
# <section class="py-5" id="homeinfo">
# <div class="container">
# <div class="row">
# <div class="col-md-6 align-self-center">
# <h3>Mujib Borsho Celebration</h3>
# <p class="lead">The March 17 grand rally -- the flagship event of Mujib Borsho -- at the National Parade Ground was postponed hours after the  we are going to rearrange the programmes," he told reporters after a meeting with Prime Minister Sheikh Hasina at the Gono Bhaban.Kamal Abdul Naser
#         </p>
# <a class="btn btn-outline-dark" href="#">read more</a>
# </div>
# <div class="col-md-6 mt-sm-3">
# <img alt="pc" class="img-fluid rounded" src="icc.jpg"/>
# </div>
# </div>
# </div>
# </section>
# <!----info section 2----->
# <section class="py-5" id="homeinfo">
# <div class="container">
# <div class="row">
# <div class="col-md-6 mt-sm-3">
# <img alt="pc" class="img-fluid rounded" src="m1.jpg"/>
# </div>
# <div class="col-md-6 align-self-center">
# <h3>Mujib Borsho Celebration</h3>
# <p class="lead">The March 17 grand rally -- the flagship event of Mujib Borsho -- at the National Parade Ground was postponed hours after the  we are going to rearrange the programmes," he told reporters after a meeting with Prime Minister Sheikh Hasina at the Gono Bhaban.Kamal Abdul Naser
#         </p>
# <a class="btn btn-outline-dark" href="#">read more</a>
# </div>
# </div>
# </div>
# </section>
# <!--getbstarted-->
# <section class="py-5 text-center" id="getstarted">
# <div class="dark-overlay">
# <div class="container">
# <div class="row">
# <div class="col">
# <h3>Mujib Borsho Celebration</h3>
# <p class="lead">The March 17 grand rally -- the flagship event of Mujib Borsho -- at the National Parade Ground was postponed hours after the  we are going to rearrange the programmes," he told reporters after a meeting with Prime Minister Sheikh Hasina at the Gono Bhaban.Kamal Abdul Naser
#         </p>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!-- sponcor link -->
# <h1 align="center">Sponsor Partners</h1>
# <div class="card-deck">
# <div class="card">
# <a href="https://www.gtvlivebd.com/">
# <img alt="" class="card-img-top" src="img/GTV.png"/>
# <div class="card-body">
# <h5 class="card-title">GTV</h5>
# <p class="card-text">Broadcast Patner </p>
# </div>
# <div class="card-footer">
# </div>
# </a></div>
# <div class="card">
# <a href="https://www.bracbank.com/en/">
# <img alt="..." class="card-img-top" src="img/BRAC-BANK.jpg"/>
# <div class="card-body">
# <h5 class="card-title">BRAC-BANK</h5>
# <p class="card-text">Teamkits Sponsor</p>
# </div>
# <div class="card-footer">
# </div>
# </a></div>
# <div class="card">
# <a href="http://freshgroupbd.com/"> <img alt="..." class="card-img-top" src="img/fgresh.jpg"/>
# <div class="card-body">
# <h5 class="card-title">Fresh</h5>
# <p class="card-text">Drinking Sponsor</p>
# </div>
# <div class="card-footer">
# </div>
# </a></div>
# </div>
# <div class="foot">
# <!-- Footer -->
# <footer class="page-footer font-small mdb-color lighten-3 pt-4">
# <!-- Footer Links -->
# <div class="container text-center text-md-left">
# <!-- Grid row -->
# <div class="row">
# <!-- Grid column -->
# <div class="col-md-4 col-lg-3 mr-auto my-md-4 my-0 mt-4 mb-1">
# <!-- Content -->
# <a class="navbar-brand" href="#">
# <img alt="" class="d-inline-block align-top" height="150" src="img/BCB-LOGO.png" width="250"/><br/>
# </a>
# </div>
# <!-- Grid column -->
# <div class="col-md-4 col-lg-3 mx-auto my-md-4 my-0 mt-4 mb-1">
# <!-- Contact details -->
# <h5 class="font-weight-bold text-uppercase mb-4">Address</h5>
# <ul class="list-unstyled">
# <li><p><i class="fas fa-home mr-3"></i> Mirpur Dhaka. </p></li>
# <li> <p> <i class="fas fa-envelope mr-3"></i>info@tigercricket.com.bd</p></li>
# <li><p><i class="fas fa-phone mr-3"></i> + 01 234 567 88</p></li>
# </ul>
# </div>
# <!-- Grid column -->
# <hr class="clearfix w-100 d-md-none"/>
# <!-- Grid column -->
# <div class="col-md-2 col-lg-2 text-center mx-auto my-4">
# <!-- Social buttons -->
# <h5 class="font-weight-bold text-uppercase mb-4">Follow Us</h5><br/>
# <!-- Facebook -->
# <a class="btn-floating btn-fb" type="button">
# </a><a href="https://www.facebook.com/bcbtigercricket"> <i class="fab fa-facebook-f"></i></a>
# <br/><br/>
# <!-- Twitter -->
# <a class="btn-floating btn-tw" type="button">
# </a><a href="https://twitter.com/bcbtigers?lang=bn"><i class="fab fa-twitter"></i></a>
# <br/><br/>
# <!-- Google +-->
# <a class="btn-floating btn-gplus" type="button">
# </a><a href="http://www.tigercricket.com.bd/contact/"> <i class="fab fa-google-plus-g"></i></a>
# </div>
# <!-- Grid column -->
# </div>
# <!-- Grid row -->
# </div>
# <!-- Footer Links -->
# <!-- Copyright -->
# <div class="footer-copyright text-center py-3">Â© 2020 Copyright:
#     <i>Bangladesh Cricket Board</i>
# </div>
# <!-- Copyright -->
# </footer>
# <!-- Footer -->
# </div>
# <!-- java script link -->
# <script crossorigin="anonymous" integrity="sha384-J6qa4849blE2+poT4WnyKhv5vZF5SrPo0iEjwBvKU7imGFAV0wwj1yYfoRSJoZ+n" src="https://code.jquery.com/jquery-3.4.1.slim.min.js"></script>
# <script crossorigin="anonymous" integrity="sha384-Q6E9RHvbIyZFJoft+2mJbHaEWldlvI9IOYy5n3zV9zzTtmI3UksdQRVvoxMfooAo" src="https://cdn.jsdelivr.net/npm/popper.js@1.16.0/dist/umd/popper.min.js"></script>
# <script crossorigin="anonymous" integrity="sha384-wfSDF2E50Y2D1uUdj0O3uMBJnjuUD4Ih7YwaYd1iqfktj0Uod8GCExl3Og8ifwB6" src="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/js/bootstrap.min.js"></script>
# </body>
# </html>

# %%
B_soup.nav # access a specific tag
# Out:
# <nav class="navbar navbar-expand-lg navbar-light bg-info fixed-top">
# <!-- Image and text -->
# <a class="navbar-brand" href="#">
# <img alt="" class="d-inline-block align-top" height="70" src="img/BCB.png" width="70"/>
# </a>
# <!-- toggle -->
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <!-- toggle div-->
# <div class="collapse navbar-collapse" id="navbarSupportedContent">
# <ul class="navbar-nav ml-auto">
# <li class="nav-item"> <a class="nav-link" href="#"> About BCB</a></li>
# <li class="nav-item"> <a class="nav-link" href="#"> News</a></li>
# <li class="nav-item"> <a class="nav-link" href="#">Fixtures</a></li>
# <li class="nav-item"> <a class="nav-link" href="#">Domestic</a>
# </li>
# <li class="nav-item"> <a class="nav-link" href="#">International</a></li>
# <li class="nav-item"> <a class="nav-link" href="#"> Gallary</a></li>
# </ul>
# <!-- Search bar-->
# <form class="form-inline my-2 my-lg-0">
# <input aria-label="Searc" class="form-control mr-sm-2" placeholder="Search" type="search"/>
# <button class="btn btn-outline-light my-2 my-sm-0" type="submit">Search</button>
# </form>
# </div>
# </nav>

# %%
a=B_soup.nav  # access class of a specific tag
a['class']
# Out:
# ['navbar', 'navbar-expand-lg', 'navbar-light', 'bg-info', 'fixed-top']

# %%
t=B_soup.html # tag type
type(t)
# Out:
# bs4.element.Tag

# %%
t.name # Return tah name
# Out:
# 'html'

# %%
t.name = "Rasel" # Change the tag name
t
# Out:
# <Rasel>
# <head>
# <title>Bangladesh Cricket Board</title>
# <!-- bootstrap link -->
# <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" rel="stylesheet"/>
# <!-- CSS link -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <script src="https://kit.fontawesome.com/a076d05399.js"></script>
# <!--Get y
# 	<!-- CSS link -->
# <link href="BCB.css" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div>
# <header>
# <nav class="navbar navbar-expand-lg navbar-light bg-info fixed-top">
# <!-- Image and text -->
# <a class="navbar-brand" href="#">
# <img alt="" class="d-inline-block align-top" height="70" src="img/BCB.png" width="70"/>
# </a>
# <!-- toggle -->
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <!-- toggle div-->
# <div class="collapse navbar-collapse" id="navbarSupportedContent">
# <ul class="navbar-nav ml-auto">
# <li class="nav-item"> <a class="nav-link" href="#"> About BCB</a></li>
# <li class="nav-item"> <a class="nav-link" href="#"> News</a></li>
# <li class="nav-item"> <a class="nav-link" href="#">Fixtures</a></li>
# <li class="nav-item"> <a class="nav-link" href="#">Domestic</a>
# </li>
# <li class="nav-item"> <a class="nav-link" href="#">International</a></li>
# <li class="nav-item"> <a class="nav-link" href="#"> Gallary</a></li>
# </ul>
# <!-- Search bar-->
# <form class="form-inline my-2 my-lg-0">
# <input aria-label="Searc" class="form-control mr-sm-2" placeholder="Search" type="search"/>
# <button class="btn btn-outline-light my-2 my-sm-0" type="submit">Search</button>
# </form>
# </div>
# </nav>
# </header>
# </div>
# <!------carasol---->
# <div>
# <div class="carousel slide" data-ride="carousel" id="carouselExampleIndicators">
# <ol class="carousel-indicators">
# <li class="active" data-slide-to="0" data-target="#carouselExampleIndicators"></li>
# <li data-slide-to="1" data-target="#carouselExampleIndicators"></li>
# <li data-slide-to="2" data-target="#carouselExampleIndicators"></li>
# </ol>
# <div class="carousel-inner">
# <div class="carousel-item active">
# <img alt="photo" class="d-block w-100" src="img/1.jpg"/>
# </div>
# <div class="carousel-item">
# <img alt="photo" class="d-block w-100" src="img/2.jpg"/>
# </div>
# <div class="carousel-item">
# <img alt="photo" class="d-block w-100" src="img/3.jpg"/>
# </div>
# </div>
# <a class="carousel-control-prev" data-slide="prev" href="#carouselExampleIndicators" role="button">
# <span aria-hidden="true" class="carousel-control-prev-icon"></span>
# <span class="sr-only">Previous</span>
# </a>
# <a class="carousel-control-next" data-slide="next" href="#carouselExampleIndicators" role="button">
# <span aria-hidden="true" class="carousel-control-next-icon"></span>
# <span class="sr-only">Next</span>
# </a>
# </div>
# </div>
# <div class="container">
# <div class="row">
# <div>
# <div class="container">
# <h2>Update Notice   <div class="spinner-border text-danger"></div>
# </h2>
# <!-- Button to Open the Modal -->
# <button class="btn btn-outline-danger" data-target="#myModal" data-toggle="modal" type="button">
#     Open Notice
#   </button>
# <!-- The Modal -->
# <div class="modal" id="myModal">
# <div class="modal-dialog">
# <div class="modal-content">
# <!-- Modal Header -->
# <div class="modal-header">
# <h2 class="modal-title">Bangladesh vs Zimbabwe</h2>
# <button class="close" data-dismiss="modal" type="button">Ã—</button>
# </div>
# <!-- Modal body -->
# <div class="modal-body">
# <h4>Clinical Tigers clean sweep series 3-0</h4>
# <p>Bangladesh have wrapped up the ODI series against Zimbabwe with a stunning victory in Sylhet thanks to Liton Das and Tamim Iqbalâ€™s heroics. Reduced to a 43 overs match due to rain, Tigers defeated the visitors by 123 runs. With this match, Mashrafe Bin Mortaza ended his stint as the ODI skipper as the most successful captain in this format. It was Mashrafeâ€™s 50th win as the ODI captain.</p>
# <p>
#           Earlier, Zimbabwe put Bangladesh into bat first after winning the toss. Four changes were made in the playing eleven from the last match. Debutans Naim Sheikh, Afif Hossain came to the side alongside Mohammad Saifuddin and Mustafizur Rahman to replace Najmul Hossain, Mushfiqur Rahim, Shafiul Islam and Al-Amin Hossain.</p>
# <p>
#       Tamim and Liton both of them were their absolute best from the beginning as the pair scored runs for fun at the both end. Rain stopped the play for a while and reduced the match to 43 overs. Tamim and Liton then resumed the innings and both went onto pick up their second century in the innings.
#     </p>
# <p>
#     Liton was more destructive as he punished the Zimbabwe bowlers to score the highest ODI knock among the Bangladeshi batsmen. Liton was finally dismissed after scoring 176 off 143 balls. Tamim on the other end remained unbeaten on 128 and powered Bangladesh to post 322 for 3 in 43 overs.
#     </p>
# <p>
#     Chasing a revised target of 342, Zimbabwe faced the first setback when they lost Tinashe in the first over by Mashrafe. Madhevere, Chkavba and Williams all got the start but failed to play the big innings which their side needed in the chase. Bowlers kept taking regular wickets as Zimbabwe never looked threatening in any stage of the innings. Sikandar put some fightback with but his knock only reduced the defeat margin.
#     </p> <p>
#     Zimbabwe were eventually all out for 218. Saifuddin garbbed 4 wickets for 41.
#     </p>
# </div>
# <!-- Modal footer -->
# <div class="modal-footer">
# <button class="btn btn-danger" data-dismiss="modal" type="button">Close</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="login">
# <button class="btn btn-outline-primary" type="button">
# <a color="green" href="Login page.html">Players panel  </a> </button>
# </div>
# </div>
# </div>
# <!----info section 1----->
# <section class="py-5" id="homeinfo">
# <div class="container">
# <div class="row">
# <div class="col-md-6 align-self-center">
# <h3>Mujib Borsho Celebration</h3>
# <p class="lead">The March 17 grand rally -- the flagship event of Mujib Borsho -- at the National Parade Ground was postponed hours after the  we are going to rearrange the programmes," he told reporters after a meeting with Prime Minister Sheikh Hasina at the Gono Bhaban.Kamal Abdul Naser
#         </p>
# <a class="btn btn-outline-dark" href="#">read more</a>
# </div>
# <div class="col-md-6 mt-sm-3">
# <img alt="pc" class="img-fluid rounded" src="icc.jpg"/>
# </div>
# </div>
# </div>
# </section>
# <!----info section 2----->
# <section class="py-5" id="homeinfo">
# <div class="container">
# <div class="row">
# <div class="col-md-6 mt-sm-3">
# <img alt="pc" class="img-fluid rounded" src="m1.jpg"/>
# </div>
# <div class="col-md-6 align-self-center">
# <h3>Mujib Borsho Celebration</h3>
# <p class="lead">The March 17 grand rally -- the flagship event of Mujib Borsho -- at the National Parade Ground was postponed hours after the  we are going to rearrange the programmes," he told reporters after a meeting with Prime Minister Sheikh Hasina at the Gono Bhaban.Kamal Abdul Naser
#         </p>
# <a class="btn btn-outline-dark" href="#">read more</a>
# </div>
# </div>
# </div>
# </section>
# <!--getbstarted-->
# <section class="py-5 text-center" id="getstarted">
# <div class="dark-overlay">
# <div class="container">
# <div class="row">
# <div class="col">
# <h3>Mujib Borsho Celebration</h3>
# <p class="lead">The March 17 grand rally -- the flagship event of Mujib Borsho -- at the National Parade Ground was postponed hours after the  we are going to rearrange the programmes," he told reporters after a meeting with Prime Minister Sheikh Hasina at the Gono Bhaban.Kamal Abdul Naser
#         </p>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!-- sponcor link -->
# <h1 align="center">Sponsor Partners</h1>
# <div class="card-deck">
# <div class="card">
# <a href="https://www.gtvlivebd.com/">
# <img alt="" class="card-img-top" src="img/GTV.png"/>
# <div class="card-body">
# <h5 class="card-title">GTV</h5>
# <p class="card-text">Broadcast Patner </p>
# </div>
# <div class="card-footer">
# </div>
# </a></div>
# <div class="card">
# <a href="https://www.bracbank.com/en/">
# <img alt="..." class="card-img-top" src="img/BRAC-BANK.jpg"/>
# <div class="card-body">
# <h5 class="card-title">BRAC-BANK</h5>
# <p class="card-text">Teamkits Sponsor</p>
# </div>
# <div class="card-footer">
# </div>
# </a></div>
# <div class="card">
# <a href="http://freshgroupbd.com/"> <img alt="..." class="card-img-top" src="img/fgresh.jpg"/>
# <div class="card-body">
# <h5 class="card-title">Fresh</h5>
# <p class="card-text">Drinking Sponsor</p>
# </div>
# <div class="card-footer">
# </div>
# </a></div>
# </div>
# <div class="foot">
# <!-- Footer -->
# <footer class="page-footer font-small mdb-color lighten-3 pt-4">
# <!-- Footer Links -->
# <div class="container text-center text-md-left">
# <!-- Grid row -->
# <div class="row">
# <!-- Grid column -->
# <div class="col-md-4 col-lg-3 mr-auto my-md-4 my-0 mt-4 mb-1">
# <!-- Content -->
# <a class="navbar-brand" href="#">
# <img alt="" class="d-inline-block align-top" height="150" src="img/BCB-LOGO.png" width="250"/><br/>
# </a>
# </div>
# <!-- Grid column -->
# <div class="col-md-4 col-lg-3 mx-auto my-md-4 my-0 mt-4 mb-1">
# <!-- Contact details -->
# <h5 class="font-weight-bold text-uppercase mb-4">Address</h5>
# <ul class="list-unstyled">
# <li><p><i class="fas fa-home mr-3"></i> Mirpur Dhaka. </p></li>
# <li> <p> <i class="fas fa-envelope mr-3"></i>info@tigercricket.com.bd</p></li>
# <li><p><i class="fas fa-phone mr-3"></i> + 01 234 567 88</p></li>
# </ul>
# </div>
# <!-- Grid column -->
# <hr class="clearfix w-100 d-md-none"/>
# <!-- Grid column -->
# <div class="col-md-2 col-lg-2 text-center mx-auto my-4">
# <!-- Social buttons -->
# <h5 class="font-weight-bold text-uppercase mb-4">Follow Us</h5><br/>
# <!-- Facebook -->
# <a class="btn-floating btn-fb" type="button">
# </a><a href="https://www.facebook.com/bcbtigercricket"> <i class="fab fa-facebook-f"></i></a>
# <br/><br/>
# <!-- Twitter -->
# <a class="btn-floating btn-tw" type="button">
# </a><a href="https://twitter.com/bcbtigers?lang=bn"><i class="fab fa-twitter"></i></a>
# <br/><br/>
# <!-- Google +-->
# <a class="btn-floating btn-gplus" type="button">
# </a><a href="http://www.tigercricket.com.bd/contact/"> <i class="fab fa-google-plus-g"></i></a>
# </div>
# <!-- Grid column -->
# </div>
# <!-- Grid row -->
# </div>
# <!-- Footer Links -->
# <!-- Copyright -->
# <div class="footer-copyright text-center py-3">Â© 2020 Copyright:
#     <i>Bangladesh Cricket Board</i>
# </div>
# <!-- Copyright -->
# </footer>
# <!-- Footer -->
# </div>
# <!-- java script link -->
# <script crossorigin="anonymous" integrity="sha384-J6qa4849blE2+poT4WnyKhv5vZF5SrPo0iEjwBvKU7imGFAV0wwj1yYfoRSJoZ+n" src="https://code.jquery.com/jquery-3.4.1.slim.min.js"></script>
# <script crossorigin="anonymous" integrity="sha384-Q6E9RHvbIyZFJoft+2mJbHaEWldlvI9IOYy5n3zV9zzTtmI3UksdQRVvoxMfooAo" src="https://cdn.jsdelivr.net/npm/popper.js@1.16.0/dist/umd/popper.min.js"></script>
# <script crossorigin="anonymous" integrity="sha384-wfSDF2E50Y2D1uUdj0O3uMBJnjuUD4Ih7YwaYd1iqfktj0Uod8GCExl3Og8ifwB6" src="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/js/bootstrap.min.js"></script>
# </body>
# </Rasel>

# %%
B_soup.title
# Out:
# <title>Bangladesh Cricket Board</title>

# %%
B_soup.head
# Out:
# <head>
# <title>Bangladesh Cricket Board</title>
# <!-- bootstrap link -->
# <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" rel="stylesheet"/>
# <!-- CSS link -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <script src="https://kit.fontawesome.com/a076d05399.js"></script>
# <!--Get y
# 	<!-- CSS link -->
# <link href="BCB.css" rel="stylesheet" type="text/css"/>
# </head>

# %%
B_soup.body
# Out:
# <body>
# <div>
# <header>
# <nav class="navbar navbar-expand-lg navbar-light bg-info fixed-top">
# <!-- Image and text -->
# <a class="navbar-brand" href="#">
# <img alt="" class="d-inline-block align-top" height="70" src="img/BCB.png" width="70"/>
# </a>
# <!-- toggle -->
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <!-- toggle div-->
# <div class="collapse navbar-collapse" id="navbarSupportedContent">
# <ul class="navbar-nav ml-auto">
# <li class="nav-item"> <a class="nav-link" href="#"> About BCB</a></li>
# <li class="nav-item"> <a class="nav-link" href="#"> News</a></li>
# <li class="nav-item"> <a class="nav-link" href="#">Fixtures</a></li>
# <li class="nav-item"> <a class="nav-link" href="#">Domestic</a>
# </li>
# <li class="nav-item"> <a class="nav-link" href="#">International</a></li>
# <li class="nav-item"> <a class="nav-link" href="#"> Gallary</a></li>
# </ul>
# <!-- Search bar-->
# <form class="form-inline my-2 my-lg-0">
# <input aria-label="Searc" class="form-control mr-sm-2" placeholder="Search" type="search"/>
# <button class="btn btn-outline-light my-2 my-sm-0" type="submit">Search</button>
# </form>
# </div>
# </nav>
# </header>
# </div>
# <!------carasol---->
# <div>
# <div class="carousel slide" data-ride="carousel" id="carouselExampleIndicators">
# <ol class="carousel-indicators">
# <li class="active" data-slide-to="0" data-target="#carouselExampleIndicators"></li>
# <li data-slide-to="1" data-target="#carouselExampleIndicators"></li>
# <li data-slide-to="2" data-target="#carouselExampleIndicators"></li>
# </ol>
# <div class="carousel-inner">
# <div class="carousel-item active">
# <img alt="photo" class="d-block w-100" src="img/1.jpg"/>
# </div>
# <div class="carousel-item">
# <img alt="photo" class="d-block w-100" src="img/2.jpg"/>
# </div>
# <div class="carousel-item">
# <img alt="photo" class="d-block w-100" src="img/3.jpg"/>
# </div>
# </div>
# <a class="carousel-control-prev" data-slide="prev" href="#carouselExampleIndicators" role="button">
# <span aria-hidden="true" class="carousel-control-prev-icon"></span>
# <span class="sr-only">Previous</span>
# </a>
# <a class="carousel-control-next" data-slide="next" href="#carouselExampleIndicators" role="button">
# <span aria-hidden="true" class="carousel-control-next-icon"></span>
# <span class="sr-only">Next</span>
# </a>
# </div>
# </div>
# <div class="container">
# <div class="row">
# <div>
# <div class="container">
# <h2>Update Notice   <div class="spinner-border text-danger"></div>
# </h2>
# <!-- Button to Open the Modal -->
# <button class="btn btn-outline-danger" data-target="#myModal" data-toggle="modal" type="button">
#     Open Notice
#   </button>
# <!-- The Modal -->
# <div class="modal" id="myModal">
# <div class="modal-dialog">
# <div class="modal-content">
# <!-- Modal Header -->
# <div class="modal-header">
# <h2 class="modal-title">Bangladesh vs Zimbabwe</h2>
# <button class="close" data-dismiss="modal" type="button">Ã—</button>
# </div>
# <!-- Modal body -->
# <div class="modal-body">
# <h4>Clinical Tigers clean sweep series 3-0</h4>
# <p>Bangladesh have wrapped up the ODI series against Zimbabwe with a stunning victory in Sylhet thanks to Liton Das and Tamim Iqbalâ€™s heroics. Reduced to a 43 overs match due to rain, Tigers defeated the visitors by 123 runs. With this match, Mashrafe Bin Mortaza ended his stint as the ODI skipper as the most successful captain in this format. It was Mashrafeâ€™s 50th win as the ODI captain.</p>
# <p>
#           Earlier, Zimbabwe put Bangladesh into bat first after winning the toss. Four changes were made in the playing eleven from the last match. Debutans Naim Sheikh, Afif Hossain came to the side alongside Mohammad Saifuddin and Mustafizur Rahman to replace Najmul Hossain, Mushfiqur Rahim, Shafiul Islam and Al-Amin Hossain.</p>
# <p>
#       Tamim and Liton both of them were their absolute best from the beginning as the pair scored runs for fun at the both end. Rain stopped the play for a while and reduced the match to 43 overs. Tamim and Liton then resumed the innings and both went onto pick up their second century in the innings.
#     </p>
# <p>
#     Liton was more destructive as he punished the Zimbabwe bowlers to score the highest ODI knock among the Bangladeshi batsmen. Liton was finally dismissed after scoring 176 off 143 balls. Tamim on the other end remained unbeaten on 128 and powered Bangladesh to post 322 for 3 in 43 overs.
#     </p>
# <p>
#     Chasing a revised target of 342, Zimbabwe faced the first setback when they lost Tinashe in the first over by Mashrafe. Madhevere, Chkavba and Williams all got the start but failed to play the big innings which their side needed in the chase. Bowlers kept taking regular wickets as Zimbabwe never looked threatening in any stage of the innings. Sikandar put some fightback with but his knock only reduced the defeat margin.
#     </p> <p>
#     Zimbabwe were eventually all out for 218. Saifuddin garbbed 4 wickets for 41.
#     </p>
# </div>
# <!-- Modal footer -->
# <div class="modal-footer">
# <button class="btn btn-danger" data-dismiss="modal" type="button">Close</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="login">
# <button class="btn btn-outline-primary" type="button">
# <a color="green" href="Login page.html">Players panel  </a> </button>
# </div>
# </div>
# </div>
# <!----info section 1----->
# <section class="py-5" id="homeinfo">
# <div class="container">
# <div class="row">
# <div class="col-md-6 align-self-center">
# <h3>Mujib Borsho Celebration</h3>
# <p class="lead">The March 17 grand rally -- the flagship event of Mujib Borsho -- at the National Parade Ground was postponed hours after the  we are going to rearrange the programmes," he told reporters after a meeting with Prime Minister Sheikh Hasina at the Gono Bhaban.Kamal Abdul Naser
#         </p>
# <a class="btn btn-outline-dark" href="#">read more</a>
# </div>
# <div class="col-md-6 mt-sm-3">
# <img alt="pc" class="img-fluid rounded" src="icc.jpg"/>
# </div>
# </div>
# </div>
# </section>
# <!----info section 2----->
# <section class="py-5" id="homeinfo">
# <div class="container">
# <div class="row">
# <div class="col-md-6 mt-sm-3">
# <img alt="pc" class="img-fluid rounded" src="m1.jpg"/>
# </div>
# <div class="col-md-6 align-self-center">
# <h3>Mujib Borsho Celebration</h3>
# <p class="lead">The March 17 grand rally -- the flagship event of Mujib Borsho -- at the National Parade Ground was postponed hours after the  we are going to rearrange the programmes," he told reporters after a meeting with Prime Minister Sheikh Hasina at the Gono Bhaban.Kamal Abdul Naser
#         </p>
# <a class="btn btn-outline-dark" href="#">read more</a>
# </div>
# </div>
# </div>
# </section>
# <!--getbstarted-->
# <section class="py-5 text-center" id="getstarted">
# <div class="dark-overlay">
# <div class="container">
# <div class="row">
# <div class="col">
# <h3>Mujib Borsho Celebration</h3>
# <p class="lead">The March 17 grand rally -- the flagship event of Mujib Borsho -- at the National Parade Ground was postponed hours after the  we are going to rearrange the programmes," he told reporters after a meeting with Prime Minister Sheikh Hasina at the Gono Bhaban.Kamal Abdul Naser
#         </p>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!-- sponcor link -->
# <h1 align="center">Sponsor Partners</h1>
# <div class="card-deck">
# <div class="card">
# <a href="https://www.gtvlivebd.com/">
# <img alt="" class="card-img-top" src="img/GTV.png"/>
# <div class="card-body">
# <h5 class="card-title">GTV</h5>
# <p class="card-text">Broadcast Patner </p>
# </div>
# <div class="card-footer">
# </div>
# </a></div>
# <div class="card">
# <a href="https://www.bracbank.com/en/">
# <img alt="..." class="card-img-top" src="img/BRAC-BANK.jpg"/>
# <div class="card-body">
# <h5 class="card-title">BRAC-BANK</h5>
# <p class="card-text">Teamkits Sponsor</p>
# </div>
# <div class="card-footer">
# </div>
# </a></div>
# <div class="card">
# <a href="http://freshgroupbd.com/"> <img alt="..." class="card-img-top" src="img/fgresh.jpg"/>
# <div class="card-body">
# <h5 class="card-title">Fresh</h5>
# <p class="card-text">Drinking Sponsor</p>
# </div>
# <div class="card-footer">
# </div>
# </a></div>
# </div>
# <div class="foot">
# <!-- Footer -->
# <footer class="page-footer font-small mdb-color lighten-3 pt-4">
# <!-- Footer Links -->
# <div class="container text-center text-md-left">
# <!-- Grid row -->
# <div class="row">
# <!-- Grid column -->
# <div class="col-md-4 col-lg-3 mr-auto my-md-4 my-0 mt-4 mb-1">
# <!-- Content -->
# <a class="navbar-brand" href="#">
# <img alt="" class="d-inline-block align-top" height="150" src="img/BCB-LOGO.png" width="250"/><br/>
# </a>
# </div>
# <!-- Grid column -->
# <div class="col-md-4 col-lg-3 mx-auto my-md-4 my-0 mt-4 mb-1">
# <!-- Contact details -->
# <h5 class="font-weight-bold text-uppercase mb-4">Address</h5>
# <ul class="list-unstyled">
# <li><p><i class="fas fa-home mr-3"></i> Mirpur Dhaka. </p></li>
# <li> <p> <i class="fas fa-envelope mr-3"></i>info@tigercricket.com.bd</p></li>
# <li><p><i class="fas fa-phone mr-3"></i> + 01 234 567 88</p></li>
# </ul>
# </div>
# <!-- Grid column -->
# <hr class="clearfix w-100 d-md-none"/>
# <!-- Grid column -->
# <div class="col-md-2 col-lg-2 text-center mx-auto my-4">
# <!-- Social buttons -->
# <h5 class="font-weight-bold text-uppercase mb-4">Follow Us</h5><br/>
# <!-- Facebook -->
# <a class="btn-floating btn-fb" type="button">
# </a><a href="https://www.facebook.com/bcbtigercricket"> <i class="fab fa-facebook-f"></i></a>
# <br/><br/>
# <!-- Twitter -->
# <a class="btn-floating btn-tw" type="button">
# </a><a href="https://twitter.com/bcbtigers?lang=bn"><i class="fab fa-twitter"></i></a>
# <br/><br/>
# <!-- Google +-->
# <a class="btn-floating btn-gplus" type="button">
# </a><a href="http://www.tigercricket.com.bd/contact/"> <i class="fab fa-google-plus-g"></i></a>
# </div>
# <!-- Grid column -->
# </div>
# <!-- Grid row -->
# </div>
# <!-- Footer Links -->
# <!-- Copyright -->
# <div class="footer-copyright text-center py-3">Â© 2020 Copyright:
#     <i>Bangladesh Cricket Board</i>
# </div>
# <!-- Copyright -->
# </footer>
# <!-- Footer -->
# </div>
# <!-- java script link -->
# <script crossorigin="anonymous" integrity="sha384-J6qa4849blE2+poT4WnyKhv5vZF5SrPo0iEjwBvKU7imGFAV0wwj1yYfoRSJoZ+n" src="https://code.jquery.com/jquery-3.4.1.slim.min.js"></script>
# <script crossorigin="anonymous" integrity="sha384-Q6E9RHvbIyZFJoft+2mJbHaEWldlvI9IOYy5n3zV9zzTtmI3UksdQRVvoxMfooAo" src="https://cdn.jsdelivr.net/npm/popper.js@1.16.0/dist/umd/popper.min.js"></script>
# <script crossorigin="anonymous" integrity="sha384-wfSDF2E50Y2D1uUdj0O3uMBJnjuUD4Ih7YwaYd1iqfktj0Uod8GCExl3Og8ifwB6" src="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/js/bootstrap.min.js"></script>
# </body>

# %%
B_soup.find_all('link') # return multiple link
# Out:
# [<link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" rel="stylesheet"/>,
#  <link href="BCB.css" rel="stylesheet" type="text/css"/>]

# %%
for link in soup.find_all('a'): # extract all the URLs within a webpage
    print(link)
# Out:
# <a class="nav-link" href="https://www.tutorialspoint.com/index.htm"><i class="fal fa-home me-1"></i> Home</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/codingground.htm"><i class="fal fa-code me-1"></i> Coding Ground</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/questions/index.php"><i class="fal fa-comments-alt me-1"></i> Q/A</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/about/about_careers.htm"><i class="fal fa-suitcase me-1"></i> Jobs</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/whiteboard.htm"><i class="fal fa-chalkboard me-1"></i> Whiteboard</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/online_dev_tools.htm"><i class="fal fa-screwdriver-wrench me-1"></i> Tools</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/business/index.asp"><i class="fal fa-analytics me-1"></i> Business</a>
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/market/teach_with_us.jsp" target="_blank"><i class="fal fa-screen-users me-2"></i> Teach with us</a>
# <a class="px-2 nav-link" href="https://www.facebook.com/tutorialspointindia" rel="nofollow" target="_blank"><i class="fab fa-facebook"></i></a>
# <a class="px-2 nav-link" href="https://www.instagram.com/tutorialspoint_/" rel="nofollow" target="_blank"><i class="fab fa-instagram"></i></a>
# <a class="px-2 nav-link" href="https://twitter.com/tutorialspoint" rel="nofollow" target="_blank"><i class="fab fa-twitter"></i></a>
# <a class="px-2 nav-link" href="https://www.youtube.com/channel/UCVLbzhxVTiTLiVKeGV7WEBg" rel="nofollow" target="_blank"><i class="fab fa-youtube"></i></a>
# <a class="px-2 nav-link" href="https://www.linkedin.com/authwall?trk=bf&amp;trkInfo=AQEkqX2eckF__gAAAX-wMwEYvrsjBVbEtWQd4pgEdVSzkL22Nik1KEpY_ECWLKDGc41z8IOZWr2Bb0fvJplT60NPBtSw87J6QCpc7wD4qQ3iU13n6xJtBxME5o05Wmpg5JPm5YY=&amp;originalReferer=&amp;sessionRedirect=https%3A%2F%2Fwww.linkedin.com%2Fcompany%2Ftutorialspoint" rel="nofollow" target="_blank"><i class="fab fa-linkedin-in"></i></a>
# <a class="navbar-brand" href="index.htm">
# <img alt="logo" class="light-mode-item navbar-brand-item" src="/images/logo.png"/>
# <img alt="logo" class="dark-mode-item navbar-brand-item" src="/images/logo-w.png"/>
# </a>
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" data-bs-toggle="dropdown" href="#" id="categoryMenu"><i class="fal fa-th me-3 fs-5 me-xl-1 d-xl-none"></i> <i class="fal fa-th me-1 d-none d-xl-inline-block"></i><span class="d-xl-inline-block dropdown-toggle">Category</span></a>
# <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/development"><i class="fa fa-cogs cat-icons"></i> Development</a>
# <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/it_and_software"><i class="fa fa-tv cat-icons"></i>  IT and Networking</a>
# <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/data_science_and_ai_ml"><i class="fa fa-head-side-brain cat-icons"></i> Data Science and AI ML</a>
# <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/cyber_security"><i class="fa fa-camera-home cat-icons"></i> Cyber Security</a>
# <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/marketing"><i class="fa fa-bullseye-arrow cat-icons"></i> Marketing</a>
# <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/office_productivity"><i class="fa fa-camera-home cat-icons"></i> Office Productivity</a>
# <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/business"><i class="fa fa-chart-bar cat-icons"></i> Business</a>
# <a class="dropdown-item" href="https://www.tutorialspoint.com/categories/lifestyle"><i class="fa fa-person-dolly-empty cat-icons"></i> Lifestyle</a>
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/latest/prime-packs" target="_self"><i class="fal fa-cubes me-1"></i> Prime Packs</a>
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/market/index.asp" target="_self"><i class="fal fa-circle-play me-1"></i> Courses</a>
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/latest/ebooks" target="_self"><i class="fal fa-book-reader me-1"></i> eBooks</a>
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/tutorialslibrary.htm" target="_self"><i class="fal fa-books me-1"></i> Library</a>
# <a href="https://www.tutorialspoint.com/market/login.asp" target="_self"><button class="btn btn-grey-border mb-0"><i class="fal fa-sign-in-alt me-2"></i> Login</button></a>
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/latest/prime-packs" target="_self"><i class="fal fa-cubes me-1"></i> Prime Packs</a>
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/market/index.asp" target="_self"><i class="fal fa-circle-play me-1"></i> Courses</a>
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/latest/ebooks" target="_self"><i class="fal fa-book-reader me-1"></i> eBooks</a>
# <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="https://www.tutorialspoint.com/tutorialslibrary.htm" target="_self"><i class="fal fa-books me-1"></i> Library</a>
# <a class="btn btn-lg btn-green-hard me-2 mb-4 mb-sm-0" href="https://www.tutorialspoint.com/codingground.htm"><i class="fal fa-code me-1"></i> Coding Ground</a>
# <a class="ms-0 ms-sm-4" data-gallery="office-tour" data-glightbox="" href="https://www.tutorialspoint.com/market/index.asp">
# <div class="btn btn-round btn-black-shadow mb-0 me-3 align-middle"> <i class="fal fa-play"></i></div>
# <div class="align-middle d-inline-block">
# <h6 class="mb-0 fw-normal">Watch Demo Video</h6>
# </div>
# </a>
# <a class="stretched-link" href="https://www.tutorialspoint.com/categories/development"> Development</a>
# <a class="stretched-link" href="https://www.tutorialspoint.com/categories/it_and_software">IT and Networking</a>
# <a class="stretched-link" href="https://www.tutorialspoint.com/categories/data_science_and_ai_ml">Data Science and AI ML</a>
# <a class="stretched-link" href="https://www.tutorialspoint.com/categories/cyber_security">Cyber Security</a>
# <a class="stretched-link" href="https://www.tutorialspoint.com/categories/marketing">Marketing</a>
# <a class="stretched-link" href="https://www.tutorialspoint.com/categories/office_productivity">Office Productivity</a>
# <a class="stretched-link" href="https://www.tutorialspoint.com/categories/business">Business</a>
# <a class="stretched-link" href="https://www.tutorialspoint.com/categories/lifestyle">Lifestyle</a>
# <a href="https://www.tutorialspoint.com/prime-pack/complete-python-prime-pack/index.asp" title="Complete Python Prime Pack"><img alt="course image" class="card-img-top" src="https://d3mxt5v3yxgcsr.cloudfront.net/courses/4870/course_4870_image.jpg"/></a>
# <a href="https://www.tutorialspoint.com/prime-pack/complete-python-prime-pack/index.asp" title="Complete Python Prime Pack">Complete Python Prime Pack</a>
# <a class="h6 fw-light mb-0" href="https://www.tutorialspoint.com/profile/tutorialspoint_com"><i class="fal fa-user me-2"></i> Tutorialspoint</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/prime-pack/complete-python-prime-pack/index.asp"><i class="fal fa-shopping-cart me-2"></i>Add to cart</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/prime-pack/complete-python-prime-pack/index.asp"><i class="fal fa-money-check-alt me-2"></i>Buy Now</a>
# <a href="https://www.tutorialspoint.com/prime-pack/cyber-security-prime-pack/index.asp" title="Complete Python Prime Pack"><img alt="course image" class="card-img-top" src="https://d3mxt5v3yxgcsr.cloudfront.net/courses/4876/course_4876_image.jpg"/></a>
# <a href="https://www.tutorialspoint.com/prime-pack/cyber-security-prime-pack/index.asp" title="Cyber Security Prime Pack">Cyber Security Prime Pack</a>
# <a class="h6 fw-light mb-0" href="https://www.tutorialspoint.com/profile/tutorialspoint_com"><i class="fal fa-user me-2"></i> Tutorialspoint</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/prime-pack/cyber-security-prime-pack/index.asp"><i class="fal fa-shopping-cart me-2"></i>Add to cart</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/prime-pack/cyber-security-prime-pack/index.asp"><i class="fal fa-money-check-alt me-2"></i>Buy Now</a>
# <a href="https://www.tutorialspoint.com/prime-pack/fullstack-web-development-prime-pack/index.asp" title="FullStack Web Development Prime Pack"><img alt="course image" class="card-img-top" src="https://d3mxt5v3yxgcsr.cloudfront.net/courses/4982/course_4982_image.jpg"/></a>
# <a href="https://www.tutorialspoint.com/prime-pack/fullstack-web-development-prime-pack/index.asp">FullStack Web Development Prime Pack</a>
# <a class="h6 fw-light mb-0" href="https://www.tutorialspoint.com/profile/tutorialspoint_com"><i class="fal fa-user me-2"></i> Tutorialspoint</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/prime-pack/fullstack-web-development-prime-pack/index.asp"><i class="fal fa-shopping-cart me-2"></i>Add to cart</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/prime-pack/fullstack-web-development-prime-pack/index.asp"><i class="fal fa-money-check-alt me-2"></i>Buy Now</a>
# <a href="https://www.tutorialspoint.com/prime-pack/artificial-intelligence-and-machine-learning-prime-pack/index.asp" title="Artificial Intelligence &amp; Machine Learning Prime Pack"><img alt="course image" class="card-img-top" src="https://d3mxt5v3yxgcsr.cloudfront.net/courses/4874/course_4874_image.jpg"/></a>
# <a href="https://www.tutorialspoint.com/prime-pack/artificial-intelligence-and-machine-learning-prime-pack/index.asp" title="Artificial Intelligence &amp; Machine Learning Prime Pack">Artificial Intelligence &amp; Machine Learning Prime Pack</a>
# <a class="h6 fw-light mb-0" href="https://www.tutorialspoint.com/profile/tutorialspoint_com"><i class="fal fa-user me-2"></i> Tutorialspoint</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/prime-pack/artificial-intelligence-and-machine-learning-prime-pack/index.asp"><i class="fal fa-shopping-cart me-2"></i>Add to cart</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/prime-pack/artificial-intelligence-and-machine-learning-prime-pack/index.asp"><i class="fal fa-money-check-alt me-2"></i>Buy Now</a>
# <a href="https://www.tutorialspoint.com/prime-pack/javascript-prime-pack/index.asp" title="JavaScript Prime Pack"><img alt="course image" class="card-img-top" src="https://d3mxt5v3yxgcsr.cloudfront.net/courses/4986/course_4986_image.jpg"/></a>
# <a href="https://www.tutorialspoint.com/prime-pack/javascript-prime-pack/index.asp" title="JavaScript Prime Pack">JavaScript Prime Pack</a>
# <a class="h6 fw-light mb-0" href="https://www.tutorialspoint.com/profile/tutorialspoint_com"><i class="fal fa-user me-2"></i> Tutorialspoint</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/prime-pack/javascript-prime-pack/index.asp"><i class="fal fa-shopping-cart me-2"></i>Add to cart</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/prime-pack/javascript-prime-pack/index.asp"><i class="fal fa-money-check-alt me-2"></i>Buy Now</a>
# <a href="https://www.tutorialspoint.com/prime-pack/data-science-prime-pack/index.asp" title="Data Science Prime Pack"><img alt="course image" class="card-img-top" src="https://d3mxt5v3yxgcsr.cloudfront.net/courses/4873/course_4873_image.jpg"/></a>
# <a href="https://www.tutorialspoint.com/prime-pack/data-science-prime-pack/index.asp" title="Data Science Prime Pack">Data Science Prime Pack</a>
# <a class="h6 fw-light mb-0" href="https://www.tutorialspoint.com/profile/tutorialspoint_com"><i class="fal fa-user me-2"></i> Tutorialspoint</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/prime-pack/data-science-prime-pack/index.asp"><i class="fal fa-shopping-cart me-2"></i>Add to cart</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/prime-pack/data-science-prime-pack/index.asp"><i class="fal fa-money-check-alt me-2"></i>Buy Now</a>
# <a href="https://www.tutorialspoint.com/html5-and-css3-fundamentals/index.asp" title="HTML5 And CSS3 Fundamentals"><img alt="course image" class="card-img-top" src="https://d3mxt5v3yxgcsr.cloudfront.net/courses/6584/course_6584_image.jpg"/></a>
# <a href="https://www.tutorialspoint.com/html5-and-css3-fundamentals/index.asp" title="HTML5 And CSS3 Fundamentals">HTML5 And CSS3 Fundamentals</a>
# <a class="h6 fw-light mb-0" href="https://www.tutorialspoint.com/profile/stone-river-elearning-16509579258"><i class="fal fa-user me-2"></i> Stone River ELearning</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/html5-and-css3-fundamentals/index.asp"><i class="fal fa-shopping-cart me-2"></i>Add to cart</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/html5-and-css3-fundamentals/index.asp"><i class="fal fa-money-check-alt me-2"></i>Buy Now</a>
# <a href="https://www.tutorialspoint.com/tableau_online_training/index.asp" title="Tableau Online Training"><img alt="course image" class="card-img-top" src="https://d3mxt5v3yxgcsr.cloudfront.net/courses/1895/course_1895_image.png"/></a>
# <a href="https://www.tutorialspoint.com/tableau_online_training/index.asp" title="Tableau Online Training">Tableau Online Training</a>
# <a class="h6 fw-light mb-0" href="https://www.tutorialspoint.com/profile/Pavan-Lalwani"><i class="fal fa-user me-2"></i> Pavan Lalwani</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/tableau_online_training/index.asp"><i class="fal fa-shopping-cart me-2"></i>Add to cart</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/tableau_online_training/index.asp"><i class="fal fa-money-check-alt me-2"></i>Buy Now</a>
# <a href="https://www.tutorialspoint.com/learn_python_programming_from_a_z_beginner_to_expert_course/index.asp" title="Learn Python Programming From A-Z: Beginner To Expert Course"><img alt="course image" class="card-img-top" src="https://d3mxt5v3yxgcsr.cloudfront.net/courses/3903/course_3903_image.png"/></a>
# <a href="https://www.tutorialspoint.com/learn_python_programming_from_a_z_beginner_to_expert_course/index.asp" title="Learn Python Programming From A-Z: Beginner To Expert Course">Learn Python Programming From A-Z: Beginner To Expert Course</a>
# <a class="h6 fw-light mb-0" href="https://www.tutorialspoint.com/profile/juan_galvan"><i class="fal fa-user me-2"></i> Juan Galvan</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/learn_python_programming_from_a_z_beginner_to_expert_course/index.asp"><i class="fal fa-shopping-cart me-2"></i>Add to cart</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/learn_python_programming_from_a_z_beginner_to_expert_course/index.asp"><i class="fal fa-money-check-alt me-2"></i>Buy Now</a>
# <a href="https://www.tutorialspoint.com/cyber_security_go_from_zero_to_hero/index.asp" title="Cyber Security : Go From Zero To Hero"><img alt="course image" class="card-img-top" src="https://d3mxt5v3yxgcsr.cloudfront.net/courses/3187/course_3187_image.jpg"/></a>
# <a href="https://www.tutorialspoint.com/cyber_security_go_from_zero_to_hero/index.asp" title="Cyber Security : Go From Zero To Hero">Cyber Security : Go From Zero To Hero</a>
# <a class="h6 fw-light mb-0" href="https://www.tutorialspoint.com/profile/chinmay_kulkarni"><i class="fal fa-user me-2"></i> Chinmay Kulkarni</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/cyber_security_go_from_zero_to_hero/index.asp"><i class="fal fa-shopping-cart me-2"></i>Add to cart</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/cyber_security_go_from_zero_to_hero/index.asp"><i class="fal fa-money-check-alt me-2"></i>Buy Now</a>
# <a href="https://www.tutorialspoint.com/sql_masterclass_sql_for_data_analytics/index.asp" title="SQL Masterclass: SQL For Data Analytics"><img alt="course image" class="card-img-top" src="https://d3mxt5v3yxgcsr.cloudfront.net/courses/2346/course_2346_image.png"/></a>
# <a href="https://www.tutorialspoint.com/prime-pack/data-science-prime-pack/index.asp" title="SQL Masterclass: SQL For Data Analytics">SQL Masterclass: SQL For Data Analytics</a>
# <a class="h6 fw-light mb-0" href="https://www.tutorialspoint.com/profile/abhishek_and_pukhraj-14426528"><i class="fal fa-user me-2"></i> Abhishek And Pukhraj</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/sql_masterclass_sql_for_data_analytics/index.asp"><i class="fal fa-shopping-cart me-2"></i>Add to cart</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/sql_masterclass_sql_for_data_analytics/index.asp"><i class="fal fa-money-check-alt me-2"></i>Buy Now</a>
# <a href="https://www.tutorialspoint.com/full_stack_java_developer_java_plus_jsp_plus_restful_ws_plus_spring/index.asp" title="Full Stack Java Developer - Java + JSP + Restful WS + Spring"><img alt="course image" class="card-img-top" src="https://d3mxt5v3yxgcsr.cloudfront.net/courses/2705/course_2705_image.jpg"/></a>
# <a href="https://www.tutorialspoint.com/full_stack_java_developer_java_plus_jsp_plus_restful_ws_plus_spring/index.asp" title="Full Stack Java Developer - Java + JSP + Restful WS + Spring">Full Stack Java Developer - Java + JSP + Restful WS + Spring</a>
# <a class="h6 fw-light mb-0" href="https://www.tutorialspoint.com/profile/chaand_sheikh"><i class="fal fa-user me-2"></i> Chaand Sheikh</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/full_stack_java_developer_java_plus_jsp_plus_restful_ws_plus_spring/index.asp"><i class="fal fa-shopping-cart me-2"></i>Add to cart</a>
# <a class="btn-sm btn-grey-border item-show-hover" href="https://www.tutorialspoint.com/full_stack_java_developer_java_plus_jsp_plus_restful_ws_plus_spring/index.asp"><i class="fal fa-money-check-alt me-2"></i>Buy Now</a>
# <a class="btn btn-grey-border mb-0" href="https://www.tutorialspoint.com/market/index.asp" target="_blank">View more<i class="fal fa-sync ms-2"></i></a>
# <a href="https://www.tutorialspoint.com/bitcoin/index.htm" target="_blank" title="Bitcoin Tutorial">
# <div class="image-title white-title">Bitcoin Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/blockchain/index.htm" target="_blank" title="Blockchain Tutorial">
# <div class="image-title white-title">Blockchain Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/blue_prism/index.htm" target="_blank" title="Blue Prism Tutorial">
# <div class="image-title white-title">Blue Prism Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/ethereum/index.htm" target="_blank" title="Ethereum Tutorial">
# <div class="image-title white-title">Ethereum Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/python_blockchain/index.htm" target="_blank" title="Python Blockchain Tutorial">
# <div class="image-title white-title">Python Blockchain</div>
# </a>
# <a href="https://www.tutorialspoint.com/openshift/index.htm" target="_blank" title="OpenShift Tutorial">
# <div class="image-title white-title">OpenShift Tutorial</div>
# </a>
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/latest_technologies.htm">View more<i class="fal fa-sync ms-2"></i></a>
# <a href="https://www.tutorialspoint.com/machine_learning/index.htm" target="_blank" title="Machine Learning Tutorial">
# <div class="image-title white-title">Machine Learning</div>
# </a>
# <a href="https://www.tutorialspoint.com/tensorflow/index.htm" target="_blank" title="TensorFlow Tutorial">
# <div class="image-title white-title">TensorFlow Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/machine_learning_with_python/index.htm" target="_blank" title="Machine Learning with Python Tutorial">
# <div class="image-title white-title">ML with Python</div>
# </a>
# <a href="https://www.tutorialspoint.com/artificial_intelligence_with_python/index.htm" target="_blank" title="AI with Python Tutorial">
# <div class="image-title white-title">AI with Python</div>
# </a>
# <a href="https://www.tutorialspoint.com/time_series/index.htm" target="_blank" title="Python Blockchain Tutorial">
# <div class="image-title white-title">Time Series Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/pytorch/index.htm" target="_blank" title="PyTorch Tutorial">
# <div class="image-title white-title">PyTorch Tutorial</div>
# </a>
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/machine_learning_tutorials.htm">View more<i class="fal fa-sync ms-2"></i></a>
# <a href="https://www.tutorialspoint.com/computer_fundamentals/index.htm" target="_blank" title="Computer-Fundamentals Tutorial">
# <div class="image-title white-title">Computer <span>Fundamentals</span></div>
# </a>
# <a href="https://www.tutorialspoint.com/compiler_design/index.htm" target="_blank" title="Compiler-Design Tutorial">
# <div class="image-title white-title">Compiler Design</div>
# </a>
# <a href="https://www.tutorialspoint.com/operating_system/index.htm" target="_blank" title="Operating-System Tutorial">
# <div class="image-title white-title">Operating System</div>
# </a>
# <a href="https://www.tutorialspoint.com/data_structures_algorithms/index.htm" target="_blank" title="Data Structure Tutorial">
# <div class="image-title white-title">Data Structure</div>
# </a>
# <a href="https://www.tutorialspoint.com/dbms/index.htm" target="_blank" title="DBMS Tutorial">
# <div class="image-title white-title">DBMS Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/data_communication_computer_network/index.htm" target="_blank" title="Networking Tutorial">
# <div class="image-title white-title">Networking Tutorial</div>
# </a>
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/computer_science_tutorials.htm">View more<i class="fal fa-sync ms-2"></i></a>
# <a href="https://www.tutorialspoint.com/html/index.htm" target="_blank" title="html Tutorial">
# <div class="image-title white-title">HTML Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/css/index.htm" target="_blank" title="css Tutorial">
# <div class="image-title white-title">css Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/javascript/index.htm" target="_blank" title="Javascript Tutorial">
# <div class="image-title white-title">Javascript Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/php/index.htm" target="_blank" title="PHP Tutorial">
# <div class="image-title white-title">PHP Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/angular4/index.htm" target="_blank" title="Angular JS 4 Tutorial">
# <div class="image-title white-title">Angular JS 4 Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/mysql/index.htm" target="_blank" title="MySQL Tutorial">
# <div class="image-title white-title">MySQL Tutorial</div>
# </a>
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/web_development_tutorials.htm">View more<i class="fal fa-sync ms-2"></i></a>
# <a href="https://www.tutorialspoint.com/html/index.htm" target="_blank" title="html Tutorial">
# <div class="image-title white-title">HTML Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/cplusplus/index.htm" target="_blank" title="C++  Tutorial">
# <div class="image-title white-title">C++ Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/java8/index.htm" target="_blank" title="Java 8 Tutorial">
# <div class="image-title white-title">Java 8 Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/python/index.htm" target="_blank" title="Python Tutorial">
# <div class="image-title white-title">Python Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/scala/index.htm" target="_blank" title="Scala Tutorial">
# <div class="image-title white-title">Scala Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/csharp/index.htm" target="_blank" title="C# Tutorial">
# <div class="image-title white-title">C# Tutorial</div>
# </a>
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/computer_programming_tutorials.htm">View more<i class="fal fa-sync ms-2"></i></a>
# <a href="https://www.tutorialspoint.com/java8/index.htm" target="_blank" title="Java 8 Tutorial">
# <div class="image-title white-title">Java 8 Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/jdbc/index.htm" target="_blank" title="JDBC  Tutorial">
# <div class="image-title white-title">JDBC Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/swing/index.htm" target="_blank" title="Swing Tutorial">
# <div class="image-title white-title">Swing Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/servlets/index.htm" target="_blank" title="Servlets Tutorial">
# <div class="image-title white-title">Servlets Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/spring/index.htm" target="_blank" title="Spring Tutorial">
# <div class="image-title white-title">Spring Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/hibernate/index.htm" target="_blank" title="Hibernate Tutorial">
# <div class="image-title white-title">Hibernate Tutorial</div>
# </a>
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/java_technology_tutorials.htm">View more<i class="fal fa-sync ms-2"></i></a>
# <a href="https://www.tutorialspoint.com/android/index.htm" target="_blank" title="Android Tutorial">
# <div class="image-title white-title">Android Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/swift/index.htm" target="_blank" title="Swift Tutorial">
# <div class="image-title white-title">Swift Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/ios/index.htm" target="_blank" title="IOS Tutorial">
# <div class="image-title white-title">IOS Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/kotlin/index.htm" target="_blank" title="Kotlin Tutorial">
# <div class="image-title white-title">Kotlin Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/xamarin/index.htm" target="_blank" title="Xamarian Tutorial">
# <div class="image-title white-title">Xamarian Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/react_native/index.htm" target="_blank" title="React Native Tutorial">
# <div class="image-title white-title">React Native Tutorial</div>
# </a>
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/mobile_development_tutorials.htm">View more<i class="fal fa-sync ms-2"></i></a>
# <a href="https://www.tutorialspoint.com/mongodb/index.htm" target="_blank" title="Mongo DB Tutorial">
# <div class="image-title white-title">Mongo DB Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/plsql/index.htm" target="_blank" title="PL / SQL Tutorial">
# <div class="image-title white-title">PL / SQL Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/sql/index.htm" target="_blank" title="SQL Tutorial">
# <div class="image-title white-title">SQL Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/db2/index.htm" target="_blank" title="DB2 Tutorial">
# <div class="image-title white-title">DB2 Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/mysql/index.htm" target="_blank" title="MySQL Tutorial">
# <div class="image-title white-title">MySQL Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/memcached/index.htm" target="_blank" title="Memcached Tutorial">
# <div class="image-title white-title">Memcached Tutorial</div>
# </a>
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/database_tutorials.htm">View more<i class="fal fa-sync ms-2"></i></a>
# <a href="https://www.tutorialspoint.com/asp.net/index.htm" target="_blank" title="ASP.NET Tutorial">
# <div class="image-title white-title">ASP.NET</div>
# </a>
# <a href="https://www.tutorialspoint.com/entity_framework/index.htm" target="_blank" title="Entity Framework Tutorial">
# <div class="image-title white-title">Entity Framework</div>
# </a>
# <a href="https://www.tutorialspoint.com/vb.net/index.htm" target="_blank" title="VB.NET Tutorial">
# <div class="image-title white-title">VB.NET Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/ms_project/index.htm" target="_blank" title="Microsoft Project Tutorial">
# <div class="image-title white-title">Microsoft Project</div>
# </a>
# <a href="https://www.tutorialspoint.com/excel/index.htm" target="_blank" title="Microsoft Excel Tutorial">
# <div class="image-title white-title">Microsoft Excel</div>
# </a>
# <a href="https://www.tutorialspoint.com/word/index.htm" target="_blank" title="Microsoft Word Tutorial">
# <div class="image-title white-title">Microsoft Word</div>
# </a>
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/microsoft_technologies_tutorials.htm">View more<i class="fal fa-sync ms-2"></i></a>
# <a href="https://www.tutorialspoint.com/big_data_analytics/index.htm" target="_blank" title="Big Data Analytics Tutorial">
# <div class="image-title white-title">Big Data Analytics</div>
# </a>
# <a href="https://www.tutorialspoint.com/hadoop/index.htm" target="_blank" title="Hadoop Tutorial">
# <div class="image-title white-title">Hadoop Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/sas/index.htm" target="_blank" title="SAS Tutorial">
# <div class="image-title white-title">SAS Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/qlikview/index.htm" target="_blank" title="QlikView Tutorial">
# <div class="image-title white-title">QlikView Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/power_bi/index.htm" target="_blank" title="Power BI Tutorial">
# <div class="image-title white-title">Power BI Tutorial</div>
# </a>
# <a href="https://www.tutorialspoint.com/tableau/index.htm" target="_blank" title="Tableau Tutorial">
# <div class="image-title white-title">Tableau Tutorial</div>
# </a>
# <a class="btn btn-white-soft" href="https://www.tutorialspoint.com/big_data_tutorials.htm">View more<i class="fal fa-sync ms-2"></i></a>
# <a class="btn btn-primary mb-0" href="https://www.tutorialspoint.com/market/teach_with_us.jsp" target="_blank">Start Now</a>
# <a class="btn btn-warning mb-0" href="https://www.tutorialspoint.com/bestseller/courses" target="_blank">View Courses</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/developers_best_practices/index.htm" title="Developer's Best Practices">
# <i class="fal fa-display-code fa-3x w-lg-80px w-sm-50px mb-3"></i>
# <p class="text-secondary">Developers <br/><b>Best Practices</b></p>
# </a>
# <a class="nav-link" href="https://www.tutorialspoint.com/effective_resume_writing.htm" title="Effective Resume Writing">
# <i class="fal fa-pen-field fa-3x w-lg-80px w-sm-50px mb-3"></i>
# <p class="text-secondary">Effective <br/><b>Resume Writing</b></p>
# </a>
# <a class="nav-link" href="https://www.tutorialspoint.com/computer_glossary.htm" title="Computer Glossary">
# <i class="fal fa-notebook fa-3x w-lg-80px w-sm-50px mb-3"></i>
# <p class="text-secondary">Computer <br/><b>Glossary</b></p>
# </a>
# <a class="nav-link" href="https://www.tutorialspoint.com/computer_whoiswho.htm" title="Who is Who in Computer Science">
# <i class="fal fa-users fa-3x w-lg-80px w-sm-50px mb-3"></i>
# <p class="text-secondary">Who is Who <br/><b>in Computer</b></p>
# </a>
# <a class="nav-link" href="https://www.tutorialspoint.com/questions_and_answers.htm" title="Technical Questions and Answers">
# <i class="fal fa-comments-question-check fa-3x w-lg-80px w-sm-50px mb-3"></i>
# <p class="text-secondary">Technical <br/><b>Q &amp; A</b></p>
# </a>
# <a class="nav-link" href="https://www.tutorialspoint.com/multi_language_tutorials.htm" title="Multi-Lingual Tutorials">
# <i class="fal fa-globe fa-3x w-lg-80px w-sm-50px mb-3"></i>
# <p class="text-secondary">Multi-Lingual <br/><b>Tutorials</b></p>
# </a>
# <a class="me-0" href="index.htm">
# <img alt="Tutorials Point" class="light-mode-item h-60px" src="/images/logo.png"/>
# <img alt="Tutorials Point" class="dark-mode-item h-60px" src="/images/logo-white.png"/>
# </a>
# <a href="https://play.google.com/store/apps/details?id=com.tutorialspoint.onlineviewer" target="_blank"><img alt="" src="static/images/client/google-play.svg"/> </a>
# <a href="https://itunes.apple.com/us/app/tutorials-point/id914891263?ls=1&amp;mt=8" target="_blank"> <img alt="app-store" src="static/images/client/app-store.svg"/></a>
# <a class="nav-link" href="/about/index.htm"><i class="fal fa-check"></i>  Company</a>
# <a class="nav-link" href="/about/about_team.htm"><i class="fal fa-check"></i> Our Team</a>
# <a class="nav-link" href="/about/about_careers.htm"><i class="fal fa-check"></i> Careers</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/about/about_helping.htm"><i class="fal fa-check"></i> Helping</a>
# <a class="nav-link" href="#"><i class="fal fa-check"></i> Become a teacher</a>
# <a class="nav-link" href="/about/about_terms_of_use.htm"><i class="fal fa-check"></i> Terms of use</a>
# <a class="nav-link" href="/about/about_privacy.htm"><i class="fal fa-check"></i> Privacy Policy</a>
# <a class="nav-link" href="/about/about_cookies.htm"><i class="fal fa-check"></i> Cookies Policy</a>
# <a class="nav-link" href="/about/return_refund_policy.htm"><i class="fal fa-check"></i> Refund Policy</a>
# <a class="nav-link" href="/about/faq.htm"><i class="fal fa-check"></i> FAQ</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/online_dev_tools.htm"><i class="fal fa-check"></i> Dev Tools</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/free_web_graphics.htm"><i class="fal fa-check"></i> Free Graphics</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/online_file_conversion.htm"><i class="fal fa-check"></i> File Conversion</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/netmeeting.php"><i class="fal fa-check"></i> NetMeeting</a>
# <a class="nav-link" href="https://www.tutorialspoint.com/free_online_whiteboard.htm"><i class="fal fa-check"></i> Whiteboard</a>
# <a href="about/contact_us.htm" title="Contact Form">Contact Form <i class="fal fa-envelope"></i></a>
# <a class="btn btn-white btn-sm shadow px-2 text-facebook" href="https://www.facebook.com/tutorialspointindia" rel="nofollow" target="_blank"><i class="fab fa-fw fa-facebook-f fa-xl"></i></a>
# <a class="btn btn-white btn-sm shadow px-2 text-instagram" href="https://www.instagram.com/tutorialspoint_/" rel="nofollow" target="_blank"><i class="fab fa-fw fa-instagram fa-xl"></i></a>
# <a class="btn btn-white btn-sm shadow px-2 text-youtube" href="https://www.youtube.com/channel/UCVLbzhxVTiTLiVKeGV7WEBg" rel="nofollow" target="_blank"><i class="fab fa-fw fa-youtube fa-xl"></i></a>
# <a class="btn btn-white btn-sm shadow px-2 text-twitter" href="https://twitter.com/tutorialspoint" rel="nofollow" target="_blank"><i class="fab fa-fw fa-twitter fa-xl"></i></a>
# <a class="btn btn-white btn-sm shadow px-2 text-linkedin" href="https://www.linkedin.com/authwall?trk=bf&amp;trkInfo=AQEkqX2eckF__gAAAX-wMwEYvrsjBVbEtWQd4pgEdVSzkL22Nik1KEpY_ECWLKDGc41z8IOZWr2Bb0fvJplT60NPBtSw87J6QCpc7wD4qQ3iU13n6xJtBxME5o05Wmpg5JPm5YY=&amp;originalReferer=&amp;sessionRedirect=https%3A%2F%2Fwww.linkedin.com%2Fcompany%2Ftutorialspoint" rel="nofollow" target="_blank"><i class="fab fa-fw fa-linkedin-in fa-xl"></i></a>
# <a class="text-body" href="#">© 2022 Tutorials Point</a>
# <a class="nav-link" href="/about/return_refund_policy.htm"><i class="fal fa-map-marker-alt me-1"></i>Refund Policy</a>
# <a class="nav-link" href="/about/about_terms_of_use.htm"><i class="fal fa-file-signature me-1"></i> Terms of use</a>
# <a class="nav-link pe-0" href="/about/about_privacy.htm"><i class="fal fa-shield-check me-1"></i> Privacy policy</a>

# %% [markdown]
# | Tag Objects |
#
# A HTML tag is used to define various types of content. A tag object in BeautifulSoup corresponds to an HTML or XML tag in the actual page or document.
#
# Tags contain lot of attributes and methods and two important features of a tag are its name and attributes.

# %%
soup = BeautifulSoup('<b class="boldest">TutorialsPoint</b>')
soup
# Out:
# <html><body><b class="boldest">TutorialsPoint</b></body></html>

# %%
tag2 = soup.b  # access class of a specific tag
tag2['class']
# Out:
# ['boldest']

# %%
tag = soup.html
type(tag)
# Out:
# bs4.element.Tag

# %%
tag
# Out:
# <html><body><b class="boldest">TutorialsPoint</b></body></html>

# %%
tag.name # Return tah name
# Out:
# 'html'

# %%
tag.name = "Rasel" # Change the tag name
tag
# Out:
# <Rasel><body><b class="boldest">TutorialsPoint</b></body></Rasel>

# %% [markdown]
# | Attributes (tag.attrs) |
#
# A tag object can have any number of attributes. The tag <b class=”boldest”> has an attribute ‘class’ whose value is “boldest”. Anything that is NOT tag, is basically an attribute and must contain a value. You can access the attributes either through accessing the keys (like accessing “class” in above example) or directly accessing through “.attrs”

# %%
soup = BeautifulSoup("<div class='tutorial'>Hello, Bangladesh!</div>",'lxml')
tag2 = soup.div
tag2['class']
# Out:
# ['tutorial']

# %%
type(soup) # checkig type
# Out:
# bs4.BeautifulSoup

# %%
soup.name # checking name
# Out:
# '[document]'

# %%
soup.string # To access the contents, use “.string”
# Out:
# 'Hello, Bangladesh!'

# %%
type(soup.string) # checking type
# Out:
# bs4.element.NavigableString

# %%
soup.string.replace_with("Hello World!") # replace the string with another string but you can’t edit the existing string.
# Out:
# 'Hello, Bangladesh!'

# %%
soup.div['class'] # access class name
# Out:
# ['tutorial']

# %% [markdown]
# We can do all kind of modifications to our tag’s attributes (add/remove/modify).

# %%
tag2['class']= 'Online-Learning' # Change class name
tag2['class']
# Out:
# 'Online-Learning'

# %%
soup.div['class'] = 'Online-Learning' # same | Change class name

# %%
tag2['style']='2007' # Adding tah style
tag2
# Out:
# <div class="Online-Learning" style="2007">Hello World!</div>

# %%
del tag2['style'] # delete tag style
tag2
# Out:
# <div class="Online-Learning">Hello World!</div>

# %%
del soup.div['style'] # Same | delete tag style
soup
# Out:
# <html><body><div class="Online-Learning">Hello World!</div></body></html>

# %%
del tag2['class']
tag2
# Out:
# <div>Hello World!</div>

# %% [markdown]
# | Comments |

# %%
soup = BeautifulSoup('<p><!-- Everything inside it is COMMENTS --></p>')
comment = soup.p.string # return comment
comment
# Out:
# ' Everything inside it is COMMENTS '

# %%
type(comment) # return type
# Out:
# bs4.element.Comment

# %%
print(soup.p.prettify()) # return comment with tag
# Out:
# <p>
#  <!-- Everything inside it is COMMENTS -->
# </p>

# %% [markdown]
# # Step-2
# Here’s an HTML document I’ll be using as an example throughout this document.

# %%
import requests
from bs4 import BeautifulSoup

# %%
html_doc = """
<html>
<head>
<title>The Dormouse's story</title>
</head>

<body>
<p class="title">
<b> The Dormouse's story </b>
</p>

<p class="story">

 Once upon a time there were three little sisters; and their names were

<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;

and they lived at the bottom of a well.

</p>

<p class="story">... </p>
"""

# %%
soup = BeautifulSoup(html_doc, 'html.parser')
print(soup)
# Out:
# <html>
# <head>
# <title>The Dormouse's story</title>
# </head>
# <body>
# <p class="title">
# <b> The Dormouse's story </b>
# </p>
# <p class="story">
#
#  Once upon a time there were three little sisters; and their names were
#
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#
# and they lived at the bottom of a well.
#
# </p>
# <p class="story">... </p>
# </body></html>

# %%
print(soup.prettify()) # Return whole code HTML formet
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
#
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
soup.title # return title
# Out:
# <title>The Dormouse's story</title>

# %%
soup.title.name    # return title name
# Out:
# 'title'

# %%
soup.title.string #  return title string
# Out:
# "The Dormouse's story"

# %%
soup.title.parent  # return parent
# Out:
# <head>
# <title>The Dormouse's story</title>
# </head>

# %%
soup.title.parent.name #return parent name
# Out:
# 'head'

# %%
soup.p # return whole p tag
# Out:
# <p class="title">
# <b> The Dormouse's story </b>
# </p>

# %%
soup.find_all('p') # return all p tag
# Out:
# [<p class="title">
#  <b> The Dormouse's story </b>
#  </p>,
#  <p class="story">
#
#   Once upon a time there were three little sisters; and their names were
#
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#
#  and they lived at the bottom of a well.
#
#  </p>,
#  <p class="story">... </p>]

# %%
soup.p['class'] # return class of p tag
# Out:
# ['title']

# %%
soup.a # return a tag
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.find_all('a') # return all a tag
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find(id="link,") # return whole tag link of id="link3"

# %%
# extracting all the URLs found within a page’s <a> tags

for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
# extracting all the text from a page:
print(soup.get_text())
# Out:
# The Dormouse's story
#
#
#
#  The Dormouse's story
#
#
#
#  Once upon a time there were three little sisters; and their names were
#
# Elsie,
# Lacie and
# Tillie;
#
# and they lived at the bottom of a well.
#
#
# ...

# %% [markdown]
# # Task-1: | Making the soup |
#
# To parse a document, pass it into the BeautifulSoup constructor. You can pass in a string or an open filehandle:
#
# Beautiful Soup then parses the document using the best available parser. It will use an HTML parser unless you specifically tell it to use an XML parser. (See Parsing XML.)

# %%
with open("BCB.html") as fp:
    soup = BeautifulSoup(fp, 'html.parser') # Making the soup To parse a document
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>Bangladesh Cricket Board</title>
# <!-- bootstrap link -->
# <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" rel="stylesheet"/>
# <!-- CSS link -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <script src="https://kit.fontawesome.com/a076d05399.js"></script>
# <!--Get y
# 	<!-- CSS link -->
# <link href="BCB.css" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div>
# <header>
# <nav class="navbar navbar-expand-lg navbar-light bg-info fixed-top">
# <!-- Image and text -->
# <a class="navbar-brand" href="#">
# <img alt="" class="d-inline-block align-top" height="70" src="img/BCB.png" width="70"/>
# </a>
# <!-- toggle -->
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <!-- toggle div-->
# <div class="collapse navbar-collapse" id="navbarSupportedContent">
# <ul class="navbar-nav ml-auto">
# <li class="nav-item"> <a class="nav-link" href="#"> About BCB</a></li>
# <li class="nav-item"> <a class="nav-link" href="#"> News</a></li>
# <li class="nav-item"> <a class="nav-link" href="#">Fixtures</a></li>
# <li class="nav-item"> <a class="nav-link" href="#">Domestic</a>
# </li>
# <li class="nav-item"> <a class="nav-link" href="#">International</a></li>
# <li class="nav-item"> <a class="nav-link" href="#"> Gallary</a></li>
# </ul>
# <!-- Search bar-->
# <form class="form-inline my-2 my-lg-0">
# <input aria-label="Searc" class="form-control mr-sm-2" placeholder="Search" type="search"/>
# <button class="btn btn-outline-light my-2 my-sm-0" type="submit">Search</button>
# </form>
# </div>
# </nav>
# </header>
# </div>
# <!------carasol---->
# <div>
# <div class="carousel slide" data-ride="carousel" id="carouselExampleIndicators">
# <ol class="carousel-indicators">
# <li class="active" data-slide-to="0" data-target="#carouselExampleIndicators"></li>
# <li data-slide-to="1" data-target="#carouselExampleIndicators"></li>
# <li data-slide-to="2" data-target="#carouselExampleIndicators"></li>
# </ol>
# <div class="carousel-inner">
# <div class="carousel-item active">
# <img alt="photo" class="d-block w-100" src="img/1.jpg"/>
# </div>
# <div class="carousel-item">
# <img alt="photo" class="d-block w-100" src="img/2.jpg"/>
# </div>
# <div class="carousel-item">
# <img alt="photo" class="d-block w-100" src="img/3.jpg"/>
# </div>
# </div>
# <a class="carousel-control-prev" data-slide="prev" href="#carouselExampleIndicators" role="button">
# <span aria-hidden="true" class="carousel-control-prev-icon"></span>
# <span class="sr-only">Previous</span>
# </a>
# <a class="carousel-control-next" data-slide="next" href="#carouselExampleIndicators" role="button">
# <span aria-hidden="true" class="carousel-control-next-icon"></span>
# <span class="sr-only">Next</span>
# </a>
# </div>
# </div>
# <div class="container">
# <div class="row">
# <div>
# <div class="container">
# <h2>Update Notice   <div class="spinner-border text-danger"></div>
# </h2>
# <!-- Button to Open the Modal -->
# <button class="btn btn-outline-danger" data-target="#myModal" data-toggle="modal" type="button">
#     Open Notice
#   </button>
# <!-- The Modal -->
# <div class="modal" id="myModal">
# <div class="modal-dialog">
# <div class="modal-content">
# <!-- Modal Header -->
# <div class="modal-header">
# <h2 class="modal-title">Bangladesh vs Zimbabwe</h2>
# <button class="close" data-dismiss="modal" type="button">Ã—</button>
# </div>
# <!-- Modal body -->
# <div class="modal-body">
# <h4>Clinical Tigers clean sweep series 3-0</h4>
# <p>Bangladesh have wrapped up the ODI series against Zimbabwe with a stunning victory in Sylhet thanks to Liton Das and Tamim Iqbalâ€™s heroics. Reduced to a 43 overs match due to rain, Tigers defeated the visitors by 123 runs. With this match, Mashrafe Bin Mortaza ended his stint as the ODI skipper as the most successful captain in this format. It was Mashrafeâ€™s 50th win as the ODI captain.</p>
# <p>
#           Earlier, Zimbabwe put Bangladesh into bat first after winning the toss. Four changes were made in the playing eleven from the last match. Debutans Naim Sheikh, Afif Hossain came to the side alongside Mohammad Saifuddin and Mustafizur Rahman to replace Najmul Hossain, Mushfiqur Rahim, Shafiul Islam and Al-Amin Hossain.</p>
# <p>
#       Tamim and Liton both of them were their absolute best from the beginning as the pair scored runs for fun at the both end. Rain stopped the play for a while and reduced the match to 43 overs. Tamim and Liton then resumed the innings and both went onto pick up their second century in the innings.
#     </p>
# <p>
#     Liton was more destructive as he punished the Zimbabwe bowlers to score the highest ODI knock among the Bangladeshi batsmen. Liton was finally dismissed after scoring 176 off 143 balls. Tamim on the other end remained unbeaten on 128 and powered Bangladesh to post 322 for 3 in 43 overs.
#     </p>
# <p>
#     Chasing a revised target of 342, Zimbabwe faced the first setback when they lost Tinashe in the first over by Mashrafe. Madhevere, Chkavba and Williams all got the start but failed to play the big innings which their side needed in the chase. Bowlers kept taking regular wickets as Zimbabwe never looked threatening in any stage of the innings. Sikandar put some fightback with but his knock only reduced the defeat margin.
#     </p> <p>
#     Zimbabwe were eventually all out for 218. Saifuddin garbbed 4 wickets for 41.
#     </p>
# </div>
# <!-- Modal footer -->
# <div class="modal-footer">
# <button class="btn btn-danger" data-dismiss="modal" type="button">Close</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="login">
# <button class="btn btn-outline-primary" type="button">
# <a color="green" href="Login page.html">Players panel  </a> </button>
# </div>
# </div>
# </div>
# <!----info section 1----->
# <section class="py-5" id="homeinfo">
# <div class="container">
# <div class="row">
# <div class="col-md-6 align-self-center">
# <h3>Mujib Borsho Celebration</h3>
# <p class="lead">The March 17 grand rally -- the flagship event of Mujib Borsho -- at the National Parade Ground was postponed hours after the  we are going to rearrange the programmes," he told reporters after a meeting with Prime Minister Sheikh Hasina at the Gono Bhaban.Kamal Abdul Naser
#         </p>
# <a class="btn btn-outline-dark" href="#">read more</a>
# </div>
# <div class="col-md-6 mt-sm-3">
# <img alt="pc" class="img-fluid rounded" src="icc.jpg"/>
# </div>
# </div>
# </div>
# </section>
# <!----info section 2----->
# <section class="py-5" id="homeinfo">
# <div class="container">
# <div class="row">
# <div class="col-md-6 mt-sm-3">
# <img alt="pc" class="img-fluid rounded" src="m1.jpg"/>
# </div>
# <div class="col-md-6 align-self-center">
# <h3>Mujib Borsho Celebration</h3>
# <p class="lead">The March 17 grand rally -- the flagship event of Mujib Borsho -- at the National Parade Ground was postponed hours after the  we are going to rearrange the programmes," he told reporters after a meeting with Prime Minister Sheikh Hasina at the Gono Bhaban.Kamal Abdul Naser
#         </p>
# <a class="btn btn-outline-dark" href="#">read more</a>
# </div>
# </div>
# </div>
# </section>
# <!--getbstarted-->
# <section class="py-5 text-center" id="getstarted">
# <div class="dark-overlay">
# <div class="container">
# <div class="row">
# <div class="col">
# <h3>Mujib Borsho Celebration</h3>
# <p class="lead">The March 17 grand rally -- the flagship event of Mujib Borsho -- at the National Parade Ground was postponed hours after the  we are going to rearrange the programmes," he told reporters after a meeting with Prime Minister Sheikh Hasina at the Gono Bhaban.Kamal Abdul Naser
#         </p>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!-- sponcor link -->
# <h1 align="center">Sponsor Partners</h1>
# <div class="card-deck">
# <div class="card">
# <a href="https://www.gtvlivebd.com/">
# <img alt="" class="card-img-top" src="img/GTV.png"/>
# <div class="card-body">
# <h5 class="card-title">GTV</h5>
# <p class="card-text">Broadcast Patner </p></div></a>
# </div>
# <div class="card-footer">
# </div>
# </div>
# <div class="card">
# <a href="https://www.bracbank.com/en/">
# <img alt="..." class="card-img-top" src="img/BRAC-BANK.jpg"/>
# <div class="card-body">
# <h5 class="card-title">BRAC-BANK</h5>
# <p class="card-text">Teamkits Sponsor</p></div></a>
# </div>
# <div class="card-footer">
# </div>
#
# <div class="card">
# <a href="http://freshgroupbd.com/"> <img alt="..." class="card-img-top" src="img/fgresh.jpg"/>
# <div class="card-body">
# <h5 class="card-title">Fresh</h5>
# <p class="card-text">Drinking Sponsor</p></div></a>
# </div>
# <div class="card-footer">
# </div>
#
#
# <div class="foot">
# <!-- Footer -->
# <footer class="page-footer font-small mdb-color lighten-3 pt-4">
# <!-- Footer Links -->
# <div class="container text-center text-md-left">
# <!-- Grid row -->
# <div class="row">
# <!-- Grid column -->
# <div class="col-md-4 col-lg-3 mr-auto my-md-4 my-0 mt-4 mb-1">
# <!-- Content -->
# <a class="navbar-brand" href="#">
# <img alt="" class="d-inline-block align-top" height="150" src="img/BCB-LOGO.png" width="250"/><br/>
# </a>
# </div>
# <!-- Grid column -->
# <div class="col-md-4 col-lg-3 mx-auto my-md-4 my-0 mt-4 mb-1">
# <!-- Contact details -->
# <h5 class="font-weight-bold text-uppercase mb-4">Address</h5>
# <ul class="list-unstyled">
# <li><p><i class="fas fa-home mr-3"></i> Mirpur Dhaka. </p></li>
# <li> <p> <i class="fas fa-envelope mr-3"></i>info@tigercricket.com.bd</p></li>
# <li><p><i class="fas fa-phone mr-3"></i> + 01 234 567 88</p></li>
# </ul>
# </div>
# <!-- Grid column -->
# <hr class="clearfix w-100 d-md-none"/>
# <!-- Grid column -->
# <div class="col-md-2 col-lg-2 text-center mx-auto my-4">
# <!-- Social buttons -->
# <h5 class="font-weight-bold text-uppercase mb-4">Follow Us</h5><br/>
# <!-- Facebook -->
# <a class="btn-floating btn-fb" type="button">
# <a href="https://www.facebook.com/bcbtigercricket"> <i class="fab fa-facebook-f"></i></a>
# </a><br/><br/>
# <!-- Twitter -->
# <a class="btn-floating btn-tw" type="button">
# <a href="https://twitter.com/bcbtigers?lang=bn"><i class="fab fa-twitter"></i></a>
# </a><br/><br/>
# <!-- Google +-->
# <a class="btn-floating btn-gplus" type="button">
# <a href="http://www.tigercricket.com.bd/contact/"> <i class="fab fa-google-plus-g"></i></a>
# </a>
# </div>
# <!-- Grid column -->
# </div>
# <!-- Grid row -->
# </div>
# <!-- Footer Links -->
# <!-- Copyright -->
# <div class="footer-copyright text-center py-3">Â© 2020 Copyright:
#     <i>Bangladesh Cricket Board</i>
# </div>
# <!-- Copyright -->
# </footer>
# <!-- Footer -->
# </div>
# <!-- java script link -->
# <script crossorigin="anonymous" integrity="sha384-J6qa4849blE2+poT4WnyKhv5vZF5SrPo0iEjwBvKU7imGFAV0wwj1yYfoRSJoZ+n" src="https://code.jquery.com/jquery-3.4.1.slim.min.js"></script>
# <script crossorigin="anonymous" integrity="sha384-Q6E9RHvbIyZFJoft+2mJbHaEWldlvI9IOYy5n3zV9zzTtmI3UksdQRVvoxMfooAo" src="https://cdn.jsdelivr.net/npm/popper.js@1.16.0/dist/umd/popper.min.js"></script>
# <script crossorigin="anonymous" integrity="sha384-wfSDF2E50Y2D1uUdj0O3uMBJnjuUD4Ih7YwaYd1iqfktj0Uod8GCExl3Og8ifwB6" src="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/js/bootstrap.min.js"></script>
# </body>
# </html>

# %%
soup = BeautifulSoup("<html>a web page</html>", 'html.parser')  # Same | # Making the soup To parse a document
soup
# Out:
# <html>a web page</html>

# %%
# Same 
print(BeautifulSoup("<html><head></head><body>Sacr&eacute; bleu!</body></html>", "html.parser")) # Same
# Out:
# <html><head></head><body>Sacré bleu!</body></html>

# %% [markdown]
# | Parsing XML |

# %%
soup = BeautifulSoup("<html>a web page</html>", 'xml')  # Same | # Making the soup To parse a document
soup
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <html>a web page</html>

# %% [markdown]
# # Task-2 | Kinds of objects |
#
# Beautiful Soup transforms a complex HTML document into a complex tree of Python objects. But you’ll only ever have to deal with about four kinds of objects: Tag, NavigableString, BeautifulSoup, and Comment.

# %% [markdown]
# | Tag |
#
# A Tag object corresponds to an XML or HTML tag in the original document:
#
# Tags have a lot of attributes and methods, and I’ll cover most of them in Navigating the tree and Searching the tree. For now, the most important features of a tag are its name and attributes.

# %%
soup = BeautifulSoup('<b class="boldest">Extremely bold</b>', 'html.parser')
tag = soup.b
type(tag)
# Out:
# bs4.element.Tag

# %% [markdown]
# | Name |

# %%
tag.name #Every tag has a name, accessible as .name:
# Out:
# 'b'

# %%
tag.name = "Rasel" # If you change a tag’s name, the change will be reflected in any HTML markup generated by Beautiful Soup:
tag
# Out:
# <Rasel class="boldest">Extremely bold</Rasel>

# %%
tag['class'] # Access only class name
# Out:
# ['boldest']

# %% [markdown]
# | Attributes |
#
# A tag may have any number of attributes. The tag <b id="boldest"> has an attribute “id” whose value is “boldest”. You can access a tag’s attributes by treating the tag like a dictionary:

# %%
tag = BeautifulSoup('<b id="boldest">bold</b>', 'html.parser').b
tag['id']
# Out:
# 'boldest'

# %%
tag.attrs  # access that dictionary directly as .attrs:
# Out:
# {'id': 'boldest'}

# %% [markdown]
# || add, remove, and modify a tag’s attributes. Again, this is done by treating the tag as a dictionary:

# %%
tag['id'] = 'verybold' # update id name
tag
# Out:
# <b id="verybold">bold</b>

# %%
tag['another-attribute'] = 1 # add another attribute
tag
# Out:
# <b another-attribute="1" id="verybold">bold</b>

# %%
del tag['another-attribute']
tag
# Out:
# <b id="verybold">bold</b>

# %%
tag.get('id') #  get id name
# Out:
# 'verybold'

# %% [markdown]
# | Multi-valued attributes |
#
# HTML 4 defines a few attributes that can have multiple values. HTML 5 removes a couple of them, but defines a few more. The most common multi-valued attribute is class (that is, a tag can have more than one CSS class). Others include rel, rev, accept-charset, headers, and accesskey. Beautiful Soup presents the value(s) of a multi-valued attribute as a list:

# %%
css_soup = BeautifulSoup('<p class="body"></p>', 'html.parser')
css_soup.p['class']   # return single value attributes
# Out:
# ['body']

# %%
css_soup = BeautifulSoup('<p class="body strikeout"></p>', 'html.parser')
css_soup.p['class'] # return mult-valued attributes
# Out:
# ['body', 'strikeout']

# %%
id_soup = BeautifulSoup('<p id="my name"></p>', 'html.parser')
id_soup.p['id'] # If an attribute looks like it has more than one value, but it’s not a multi-valued attribute as defined by any version of the HTML standard, Beautiful Soup will leave the attribute alone:
# Out:
# 'my name'

# %% [markdown]
# | Turn a tag back into a string |
#
# When you turn a tag back into a string, multiple attribute values are consolidated:

# %%
rel_soup = BeautifulSoup('<p>Back to the <a rel="index">homepage</a></p>', 'html.parser')
rel_soup.a['rel']
# Out:
# ['index']

# %%
rel_soup.a['rel'] = ['index', 'contents']
print(rel_soup.p)
# Out:
# <p>Back to the <a rel="index contents">homepage</a></p>

# %% [markdown]
# | multi_valued_attributes=None |
#
# You can disable this by passing multi_valued_attributes=None as a keyword argument into the BeautifulSoup constructor:

# %%
no_list_soup = BeautifulSoup('<p class="body strikeout"></p>', 'html.parser', multi_valued_attributes=None)
no_list_soup.p['class']
# Out:
# 'body strikeout'

# %% [markdown]
# | get_attribute_list |
#
# You can use get_attribute_list to get a value that’s always a list, whether or not it’s a multi-valued atribute:

# %%
id_soup.p.get_attribute_list('id')
# Out:
# ['my name']

# %% [markdown]
# | Note |
#
# If you parse a document as XML, there are no multi-valued attributes:

# %%
xml_soup = BeautifulSoup('<p class="body strikeout"></p>', 'xml')
xml_soup.p['class']
# Out:
# 'body strikeout'

# %% [markdown]
# | multi_valued_attributes |
#
# Again, you can configure this using the multi_valued_attributes argument:

# %%
class_is_multi= { '*' : 'class'}
xml_soup = BeautifulSoup('<p class="body strikeout"></p>', 'xml', multi_valued_attributes=class_is_multi)
xml_soup.p['class']
# Out:
# ['body', 'strikeout']

# %% [markdown]
# | Note |
#
# You probably won’t need to do this, but if you do, use the defaults as a guide. They implement the rules described in the HTML specification:

# %%
from bs4.builder import builder_registry
builder_registry.lookup('html').DEFAULT_CDATA_LIST_ATTRIBUTES
# Out:
# {'*': ['class', 'accesskey', 'dropzone'],
#  'a': ['rel', 'rev'],
#  'link': ['rel', 'rev'],
#  'td': ['headers'],
#  'th': ['headers'],
#  'form': ['accept-charset'],
#  'object': ['archive'],
#  'area': ['rel'],
#  'icon': ['sizes'],
#  'iframe': ['sandbox'],
#  'output': ['for']}

# %% [markdown]
# # Task-3: | NavigableString |
# A string corresponds to a bit of text within a tag. Beautiful Soup uses the NavigableString class to contain these bits of text:

# %%
soup = BeautifulSoup('<b class="boldest">Extremely bold</b>', 'html.parser')
tag = soup.b
tag.string
# Out:
# 'Extremely bold'

# %%
type(tag.string) # checking type
# Out:
# bs4.element.NavigableString

# %% [markdown]
# | Note |
#
# A NavigableString is just like a Python Unicode string, except that it also supports some of the features described in Navigating the tree and Searching the tree. You can convert a NavigableString to a Unicode string with str:

# %%
unicode_string = str(tag.string) # convert a NavigableString to a Unicode string with str:
unicode_string
# Out:
# 'Extremely bold'

# %%
type(unicode_string) # checking type
# Out:
# str

# %% [markdown]
# | Note:
#
# You can’t edit a string in place, but you can replace one string with another, using replace_with():

# %%
tag.string.replace_with("No longer bold") # replace one string with another
tag
# Out:
# <b class="boldest">No longer bold</b>

# %% [markdown]
# # Task-4: | BeautifulSoup |
# The BeautifulSoup object represents the parsed document as a whole. For most purposes, you can treat it as a Tag object. This means it supports most of the methods described in Navigating the tree and Searching the tree.
#
# You can also pass a BeautifulSoup object into one of the methods defined in Modifying the tree, just as you would a Tag. This lets you do things like combine two parsed documents:

# %%
doc = BeautifulSoup("<document><content/>INSERT FOOTER HERE</document", "xml")
doc
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <document><content/>INSERT FOOTER HERE</document>

# %%
footer = BeautifulSoup("<footer>Here's the footers </footer>", "xml")
footer
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <footer>Here's the footers </footer>

# %%
doc.find(text="INSERT FOOTER HERE").replace_with(footer)
print(doc)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <document><content/><footer>Here's the footers </footer></document>

# %% [markdown]
# | Note:
#
# Since the BeautifulSoup object doesn’t correspond to an actual HTML or XML tag, it has no name and no attributes. But sometimes it’s useful to look at its .name, so it’s been given the special .name “[document]”:

# %%
doc.name
footer.name
soup.name
# Out:
# '[document]'

# %% [markdown]
# # Task-5: | Comments and special strings |
# Tag, NavigableString, and BeautifulSoup cover almost everything you’ll see in an HTML or XML file, but there are a few leftover bits. The main one you’ll probably encounter is the comment:
#
# The Comment object is just a special type of NavigableString:

# %%
markup = "<b><!--Hey, buddy. Want to buy a used parser?--></b>"
soup = BeautifulSoup(markup, 'html.parser') # Return comment string 
comment = soup.b.string
comment
# Out:
# 'Hey, buddy. Want to buy a used parser?'

# %%
type(comment)
# Out:
# bs4.element.Comment

# %%
print(soup.b.prettify()) # Comment is displayed with special formatting:
# Out:
# <b>
#  <!--Hey, buddy. Want to buy a used parser?-->
# </b>

# %% [markdown]
# # Task-5: Navigating the tree
#
# I’ll use this as an example to show you how to move from one part of a document to another.

# %%
# Here’s the “Three sisters” HTML document again:
html_doc = """
<html><head><title>The Dormouse's storys</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
soup = BeautifulSoup(html_doc, 'html.parser')

# %% [markdown]
# | Note:
#
#  that Beautiful Soup strings don’t support any of these attributes, because a string can’t have children.

# %% [markdown]
# | Navigating using tag names |
#
# The simplest way to navigate the parse tree is to say the name of the tag you want.

# %%
soup.head # If you want the <head> tag, just say soup.head:
# Out:
# <head><title>The Dormouse's storys</title></head>

# %%
soup.title # return title
# Out:
# <title>The Dormouse's storys</title>

# %%
soup.title.string # return title string
# Out:
# "The Dormouse's storys"

# %%
soup.body.b
# Out:
# <b>The Dormouse's story</b>

# %%
soup.find_all('a') # return a tag
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
for b in soup.find_all('a'): # return link of a tag
    print(b.get('href'))
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %% [markdown]
# | .contents and .children |
#
# A tag’s children are available in a list called .contents:
#
# The .contents and .children attributes only consider a tag’s direct children. For instance, the <head> tag has a single direct child–the <title> tag:

# %%
soup.head.contents # return content of head
# Out:
# [<title>The Dormouse's storys</title>]

# %%
soup.body.contents # return content of body
# Out:
# ['\n',
#  <p class="title"><b>The Dormouse's story</b></p>,
#  '\n',
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  '\n',
#  <p class="story">...</p>,
#  '\n']

# %%
st=soup.head.contents[0] # return content of head
st
# Out:
# <title>The Dormouse's storys</title>

# %%
st.contents # return string
# Out:
# ["The Dormouse's storys"]

# %% [markdown]
# | note:
#
# The BeautifulSoup object itself has children. In this case, the <html> tag is the child of the BeautifulSoup object.:
#
# A string does not have .contents, because it can’t contain anything:

# %%
len(soup.contents)
# Out:
# 2

# %%
for child in soup.head.contents[0].children: # Instead of getting them as a list, you can iterate over a tag’s children using the .children generator:
    print(child)     # return all children of head
# Out:
# The Dormouse's storys

# %%
for child in soup.head.descendants: # return all descendants of head
    print(child)
# Out:
# <title>The Dormouse's storys</title>
# The Dormouse's storys

# %%
for child in soup.body.descendants: # return all descendants of body
    print(child)
# Out:
# <p class="title"><b>The Dormouse's story</b></p>
# <b>The Dormouse's story</b>
# The Dormouse's story
#
#
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# Once upon a time there were three little sisters; and their names were
#
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# Elsie
# ,
#
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
# Lacie
#  and
#
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# Tillie
# ;
# and they lived at the bottom of a well.
#
#
# <p class="story">...</p>
# ...

# %% [markdown]
# | note:
#
# The head tag has only one child, but it has two descendants: the title tag and the title tag’s child. The BeautifulSoup object only has one direct child (the <html> tag), but it has a whole lot of descendants:

# %%
len(list(soup.children)) # Return number of child of  BeautifulSoup
# Out:
# 2

# %%
len(list(soup.descendants)) # Return number of descendants of  BeautifulSoup
# Out:
# 27

# %% [markdown]
# | .string |

# %%
soup.head.string
# Out:
# "The Dormouse's storys"

# %%
soup.b.string
# Out:
# "The Dormouse's story"

# %%
print(soup.html.string) # If a tag contains more than one thing, then it’s not clear what .string should refer to, so .string is defined to be None:
# Out:
# None

# %% [markdown]
# | .strings and stripped_strings |
#
# If there’s more than one thing inside a tag, you can still look at just the strings. Use the .strings generator:
#
# These strings tend to have a lot of extra whitespace, which you can remove by using the .stripped_strings generator instead:

# %%
for string in soup.strings: # return all string of BeautifulSoup
    print(repr(string))
# Out:
# '\n'
# "The Dormouse's storys"
# '\n'
# '\n'
# "The Dormouse's story"
# '\n'
# 'Once upon a time there were three little sisters; and their names were\n'
# 'Elsie'
# ',\n'
# 'Lacie'
# ' and\n'
# 'Tillie'
# ';\nand they lived at the bottom of a well.'
# '\n'
# '...'
# '\n'

# %%
for string in soup.stripped_strings: # return all string of BeautifulSoup without whitespace
    print(repr(string))
# Out:
# "The Dormouse's storys"
# "The Dormouse's story"
# 'Once upon a time there were three little sisters; and their names were'
# 'Elsie'
# ','
# 'Lacie'
# 'and'
# 'Tillie'
# ';\nand they lived at the bottom of a well.'
# '...'

# %% [markdown]
# | .parent and .parents |
#
# Continuing the “family tree” analogy, every tag and every string has a parent: the tag that contains it.
#
# You can access an element’s parent with the .parent attribute. In the example “three sisters” document, the <head> tag is the parent of the <title> tag:

# %%
soup.title.parent # return parent of title
# Out:
# <head><title>The Dormouse's storys</title></head>

# %%
soup.head.string.parent  # return parent of string
# Out:
# <title>The Dormouse's storys</title>

# %%
print(soup.html.parent)
# Out:
# <html><head><title>The Dormouse's storys</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html>

# %%
html_tag = soup.html
type(html_tag.parent)
# Out:
# bs4.BeautifulSoup

# %%
print(soup.parent) # the .parent of a BeautifulSoup object is defined as None:
# Out:
# None

# %%
link = soup.a # iterate over all of an element’s parents with .parents
for parent in link.parents:
    print(parent.name)
# Out:
# p
# body
# html
# [document]

# %% [markdown]
# | Going sideways |

# %% [markdown]
# The <b> tag and the <c> tag are at the same level: they’re both direct children of the same tag. We call them siblings.

# %%
sibling_soup = BeautifulSoup("<a><b>text1</b><c>text2</c></a>", 'html.parser')
print(sibling_soup.prettify())
# Out:
# <a>
#  <b>
#   text1
#  </b>
#  <c>
#   text2
#  </c>
# </a>

# %% [markdown]
# | .next_sibling and .previous_sibling  |
#
# You can use .next_sibling and .previous_sibling to navigate between page elements that are on the same level of the parse tree:

# %%
sibling_soup.b.next_sibling # move tag b to tag c
# Out:
# <c>text2</c>

# %%
sibling_soup.c.previous_sibling # return tag c to tag ab
# Out:
# <b>text1</b>

# %% [markdown]
# || Note:
#
# The <b> tag has a .next_sibling, but no .previous_sibling, because there’s nothing before the <b> tag on the same level of the tree. For the same reason, the <c> tag has a .previous_sibling but no .next_sibling:

# %%
print(sibling_soup.b.previous_sibling)
print(sibling_soup.c.next_sibling)
# Out:
# None
# None

# %% [markdown]
# || Note:
#
# The strings “text1” and “text2” are not siblings, because they don’t have the same parent:

# %%
print(sibling_soup.b.string.next_sibling)

sibling_soup.b.string
# Out:
# None
# 'text1'

# %%
link = soup.a
link

link.next_sibling # next sibling of a
# Out:
# ',\n'

# %%
link.next_sibling.next_sibling # next sibling of \n
# Out:
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>

# %% [markdown]
# | .next_siblings and .previous_siblings |
#
# iterate over a tag’s siblings with .next_siblings or .previous_siblings:

# %%
for sibling in soup.a.next_siblings: # iterate next_siblings
    print(repr(sibling))
# Out:
# ',\n'
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
# ' and\n'
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# ';\nand they lived at the bottom of a well.'

# %%
for sibling in soup.find(id="link3").previous_siblings: # iterate previous_siblings
    print(repr(sibling))
# Out:
# ' and\n'
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
# ',\n'
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# 'Once upon a time there were three little sisters; and their names were\n'

# %% [markdown]
# | .next_element and .previous_element |
#
# The .next_element attribute of a string or tag points to whatever was parsed immediately afterwards. It might be the same as .next_sibling, but it’s usually drastically different.

# %%
last_a_tag = soup.find("a", id="link3")
last_a_tag
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
last_a_tag.next_sibling
# Out:
# ';\nand they lived at the bottom of a well.'

# %%
last_a_tag.next_element # .next_element of that <a> tag, the thing that was parsed immediately after the <a> tag, is not the rest of that sentence: it’s the word “Tillie”
# Out:
# 'Tillie'

# %%
last_a_tag.previous_element # return previous_element of a tag
# Out:
# ' and\n'

# %%
last_a_tag.previous_element.next_element #  previous_element nad next_element work same time
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %% [markdown]
# | .next_elements and .previous_elements |

# %%
for element in last_a_tag.next_elements: # iterate next_elements  
    print(repr(element))
# Out:
# 'Tillie'
# ';\nand they lived at the bottom of a well.'
# '\n'
# <p class="story">...</p>
# '...'
# '\n'

# %%
for element in last_a_tag.previous_elements: # iterate next_elements  
    print(repr(element))
# Out:
# ' and\n'
# 'Lacie'
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
# ',\n'
# 'Elsie'
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# 'Once upon a time there were three little sisters; and their names were\n'
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# '\n'
# "The Dormouse's story"
# <b>The Dormouse's story</b>
# <p class="title"><b>The Dormouse's story</b></p>
# '\n'
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>
# '\n'
# "The Dormouse's storys"
# <title>The Dormouse's storys</title>
# <head><title>The Dormouse's storys</title></head>
# <html><head><title>The Dormouse's storys</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html>
# '\n'

# %% [markdown]
# # Task-5: | Searching the tree |

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

soup = BeautifulSoup(html_doc, 'html.parser')

# %% [markdown]
# || Note:
#
# If you pass in a byte string, Beautiful Soup will assume the string is encoded as UTF-8. You can avoid this by passing in a Unicode string instead.

# %%
soup.find_all('b')  #  This code finds all the <b> tags in the document:
# Out:
# [<b>The Dormouse's story</b>]

# %% [markdown]
# | A regular expression |
#
# If you pass in a regular expression object, Beautiful Soup will filter against that regular expression using its search() method.

# %%
import re
for tag in soup.find_all(re.compile("^b")):  # This code finds all the tags whose names start with the letter “b”; in this case, the <body> tag and the <b> tag:
    print(tag.name)
# Out:
# body
# b

# %%
for tag in soup.find_all(re.compile("t")): # This code finds all the tags whose names contain with the letter “t”
    print(tag.name)
# Out:
# html
# head

# %%
for tag in soup.find_all(re.compile("h ")): # This code finds all the tags whose names contain with the letter “h”
    print(tag.name)

# %% [markdown]
# | A list |
#
# If you pass in a list, Beautiful Soup will allow a string match against any item in that list. This code finds all the <a> tags and all the <b> tags:

# %%
soup.find_all(["a", "b"])
# Out:
# [<b>The Dormouse's story</b>,
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %% [markdown]
# | True |
#
# The value True matches everything it can. This code finds all the tags in the document, but none of the text strings:

# %%
for tag in soup.find_all(True):
    print(tag.name)
# Out:
# html
# head
# title
# body
# p
# b
# p
# a
# a
# a
# p

# %%
def has_class_but_no_id(tag):
    return tag.has_attr('class') and not tag.has_attr('id')
